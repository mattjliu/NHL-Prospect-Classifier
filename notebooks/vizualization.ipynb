# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
train_predict = pd.read_csv('../predictions/long/all_train.csv')
valid_predict = pd.read_csv('../predictions/long/all_valid.csv')

# %%
def adj_proba(row):
    if row.prediction == True:
        return row.confidence
    else:
        return 1 - row.confidence

# %%
train_predict['adj_conf'] = train_predict.apply(lambda row:adj_proba(row),axis=1)
valid_predict['adj_conf'] = valid_predict.apply(lambda row:adj_proba(row),axis=1)

# %%
fig = plt.figure(figsize=(18,10))
ax = fig.gca()
plt.scatter(x=train_predict['adj_conf'],y=train_predict['GP'])
plt.xticks(np.arange(0,1.1,step=0.1))
plt.xlabel('Model Confidence')
plt.ylabel('Games Played')
plt.grid()
plt.show()

# %%
train_predict['n_words'] = train_predict['report'].str.split().apply(len)

# %%
fig = plt.figure(figsize=(18,10))
ax = fig.gca()
plt.scatter(x=train_predict['adj_conf'],y=train_predict['n_words'])
plt.xticks(np.arange(0,1.1,step=0.1))
plt.xlabel('Model Confidence')
plt.ylabel('Word Count')
plt.grid()
plt.show()

# %%
fig = plt.figure(figsize=(18,10))
ax = fig.gca()
plt.scatter(x=train_predict['n_words'],y=train_predict['GP'])
plt.xlabel('Word Count')
plt.ylabel('Games Played')
plt.grid()
plt.show()

# %%
train_predict.sort_values(by='adj_conf',ascending=False)
# Out:
#      draft_num  draft_year                                             report  \
# 757          1        2013  Dominant player with outstanding vision and na...
# 204          1        2015  One of the most talked about prospects in awhi...
# 701         69        2013  Big wing who moves well and plays strong down ...
# 712         55        2013  Under six footer with good speed, hands, and h...
# 218          1        2017  The best Swiss player in the 2016 World U-18s,...
# 680         90        2013  One of the younger players in the Swedish Elit...
# 374          2        2014  Bloodlines are where Sam Reinhardt's resume st...
# 693         75        2013  Stood out in international competitions with h...
# 659          3        2012  Some might try and say that the Milwaukee-born...
# 755          3        2013  Undersized play-making left winger with excell...
# 36           7        2016  Smaller with a high skill set. A high speed pl...
# 186         21        2015  Possesses average size, but high end skills an...
# 564         59        2012  Big College Freshman who already has pro-style...
# 46           3        2018  Is he your future power winger or your big cen...
# 206          2        2015  The US born centre may not be as good as the t...
# 728         32        2013  Smart six foot offenseman who is able to lead,...
# 605        118        2013  Strong skating high character power wing who c...
# 491          8        2011  May have become Angelo Esposito-like in his fa...
# 497          1        2011  After tiny Rocco Grimaldi, he is the best skil...
# 217          5        2017  Top scorer on his team  on a point a game pace...
# 746         17        2013  Skilled physical center who combines good play...
# 205          6        2015  Big man who has a strong physical game, excell...
# 201          7        2015  A strong elusive skating puck carrier who is a...
# 367          8        2014  Small lightweight centre who upper level skill...
# 35          12        2016  A centre who wants the puck on his stick. He d...
# 202         10        2015  Displays a strong game on the wall and dominan...
# 647         14        2012  A tough, skilled center who has an excellent s...
# 362         15        2014  Two-way player at the centre position who disp...
# 344         28        2014  The Jamacian-Canadian is an all-compass skater...
# 598        123        2013  Skilled defenseman whose stick-handling, skati...
# ..         ...         ...                                                ...
# 602        117        2013  Ice-water Swedish goaler with size and confide...
# 63         187        2015  Intriguing prospect on the backline with excel...
# 506        200        2013  Agile netminder who made his debut this year i...
# 818         71        2011  Big, quick-legged goalie who is a butterfly 't...
# 709         59        2013  Developing goaler with strong glove, good late...
# 231        179        2014   A third year eligible with good feet, glove a...
# 67         176        2015  Does most things well, but at this juncture hi...
# 283         96        2014  Son of Glenn doesn’t have makings of an up-siz...
# 415        188        2012  Undersized winger with good shot. Committed to...
# 111        111        2015  Tall hybrid goal with a solid glove an blocker...
# 66         177        2015  Averaged sized QMJHL defender who is have disp...
# 775        163        2011  An ice-water player whose game is still in dev...
# 148         66        2015  Captain’s a weak Titan team and is good at bot...
# 59         195        2015  He has committed to the University of Wisconsin..
# 380        201        2012  Raw Russian prospect who has good feet, althou...
# 76         156        2015  Lanky defender who at this juncture projects a...
# 631         32        2012  Tough, good skating wing who is always ready t...
# 87         145        2015  Big goaltender who plays big as he anchors the...
# 555         68        2012  Big solid prep school defender with good reach...
# 400        184        2012  Butterfly goalie with a quick glove and strong...
# 547         80        2012  Good size, great glove, quick movement and a g...
# 399        185        2012  Developing prospect with a good overall game. ...
# 388        197        2012  Rangy, physically mature defender who is defen...
# 571        178        2013  Improving two-way defenseman whose offensive s...
# 80         154        2015  USA defender with good size who displays decen...
# 83         146        2015  Intriguing USA Developmental goaltender from E...
# 241        164        2014  Russian youngster with good offensive talent, ...
# 99         129        2015  Big Western League defender with a good compet...
# 132         86        2015  Huge goalie prospect who has displayed excelle...
# 52         206        2015  Another USA developmental goalie prospect with...
#
#        A    G   GP  PIM  Pts    draft_team  \
# 757  247  155  456  185  402      Colorado
# 204  244  128  287   90  372      Edmonton
# 701    3    7   47   20   10       Buffalo
# 712   39   41  221   60   80      Montreal
# 218   62   37  151   50   99    New Jersey
# 680    5    5   37    8   10        Boston
# 374  118   87  331   60  205       Buffalo
# 693   58   43  179   46  101    NY Rangers
# 659  169  127  490  185  296      Montreal
# 755  134   60  322  110  194     Tampa Bay
# 36    77   37  167   48  114       Arizona
# 186   31   16   94   32   47        Ottawa
# 564   14    5   72   20   19    NY Rangers
# 46    23   11   79   26   34      Montreal
# 206  158  101  286  102  259       Buffalo
# 728    3    1   46   18    4      Colorado
# 605    2    1   22    8    3   Los Angeles
# 491  209  134  578  225  343  Philadelphia
# 497  235  147  539  168  382      Edmonton
# 217   38   28   71   12   66     Vancouver
# 746   36   15  246   59   51        Ottawa
# 205   47   29  201   64   76    New Jersey
# 201   67   30  246   86   97  Philadelphia
# 367  107   55  239   62  162       Toronto
# 35     3    0   21   13    3    New Jersey
# 202  129   80  239  112  209      Colorado
# 647   70   49  420  120  119       Buffalo
# 362  125   88  318  207  213       Detroit
# 344   17    7   53   20   24  NY Islanders
# 598   65    9  159   26   74      Colorado
# ..   ...  ...  ...  ...  ...           ...
# 602    0    0    0    0    0      San Jose
# 63     0    0    0    0    0   Los Angeles
# 506    0    0    0    0    0     Minnesota
# 818    0    0    0    0    0     Vancouver
# 709    0    0    5    0    0      Winnipeg
# 231    0    0    0    0    0       Chicago
# 67     0    0    0    0    0     St. Louis
# 283    0    0    0    0    0      Carolina
# 415    0    0    0    0    0     Minnesota
# 111    0    0    0    0    0     Minnesota
# 66     0    0    0    0    0      Montreal
# 775    0    0    0    0    0      Carolina
# 148    0    0    8    0    0     Vancouver
# 59     0    0    0    0    0        Boston
# 380    0    0    0    0    0  Philadelphia
# 76     0    0    0    0    0      Carolina
# 631    0    0    0    0    0      Edmonton
# 87     0    0    0    0    0     Nashville
# 555    0    0    0    0    0     Minnesota
# 400    0    0    2    0    0       Phoenix
# 547    0    0    0    0    0       Detroit
# 399    0    0    0    0    0  NY Islanders
# 388    0    0    0    0    0    Washington
# 571    0    0    0    0    0   Los Angeles
# 80     0    0    0    0    0      Edmonton
# 83     0    0    0    0    0     St. Louis
# 241    0    0    0    0    0      Winnipeg
# 99     0    0    0    0    0      Columbus
# 132    0    0    0    0    0      San Jose
# 52     0    0    0    0    0       Florida
#
#                                junior_team                  name pos  \
# 757             Halifax Mooseheads [QMJHL]      Nathan_MacKinnon   C
# 204                      Erie Otters [OHL]        Connor_McDavid   C
# 701                   Sudbury Wolves [OHL]         Nick_Baptiste   R
# 712                KalPa Kuopio [SM-liiga]      Artturi_Lehkonen   L
# 218             Halifax Mooseheads [QMJHL]         Nico_Hischier   C
# 680                    Lulea Jrs. (Sweden)        Peter_Cehlarik   L
# 374                     Kootenay Ice [WHL]          Sam_Reinhart   C
# 693              Cherepovets Jrs. (Russia)      Pavel_Buchnevich   R
# 659                     Sarnia Sting [OHL]       Alex_Galchenyuk   C
# 755             Halifax Mooseheads [QMJHL]       Jonathan_Drouin   L
# 36   U.S. National Development Team [USHL]        Clayton_Keller   C
# 186  U.S. National Development Team [USHL]           Colin_White   C
# 564               Kent School [Conn. H.S.]  Cristoval_Boo_Nieves   C
# 46                   Assat Pori [SM-liiga]    Jesperi_Kotkaniemi   C
# 206             Boston University [H-East]           Jack_Eichel   C
# 728                Owen Sound Attack [OHL]          Chris_Bigras   D
# 605  U.S. National Development Team [USHL]       Hudson_Fasching   R
# 491       Drummondville Voltigeurs [QMJHL]        Sean_Couturier   C
# 497                  Red Deer Rebels [WHL]   Ryan_Nugent-Hopkins   C
# 217                       Timra IK [Swe-1]      Elias_Pettersson   C
# 746               Edmonton Oil Kings [WHL]          Curtis_Lazar   C
# 205                     Sarnia Sting [OHL]           Pavel_Zacha   C
# 201              Brandon Wheat Kings [WHL]         Ivan_Provorov   D
# 367       MODO Hockey Ornskoldsvik [SweHL]      William_Nylander   R
# 35            Mississauga Steelheads [OHL]        Michael_McLeod   C
# 202                   TPS Turku [SM-liiga]        Mikko_Rantanen   R
# 647         Dubuque Fighting Saints [USHL]     Zemgus_Girgensons   C
# 362     U.S. National Under-18 Team [USHL]          Dylan_Larkin   C
# 344                Windsor Spitfires [OHL]          Josh_Ho-Sang   R
# 598  U.S. National Development Team [USHL]          Will_Butcher   D
# ..                                     ...                   ...  ..
# 602                 Frolunda Jrs. (Sweden)       Fredrik_Bergvik   G
# 63                   Victoria Royals [WHL]        Chaz_Reddekopp   D
# 506          Rouyn-Noranda Huskies [QMJHL]    Alexandre_Belanger   G
# 818           Victoriaville Tigres [QMJHL]          David_Honzik   G
# 709               Tri-City Americans [WHL]           Eric_Comrie   G
# 231       SKA St. Petersburg (Russia Jrs.)          Ivan_Nalimov   G
# 67                 Owen Sound Attack [OHL]            Liam_Dunda   R
# 283                 Plymouth Whalers [OHL]           Josh_Wesley   D
# 415                Edina H.S. [Minn. H.S.]           Louis_Nanne   L
# 111              Liberic Jrs. (Czech Rep.)           Ales_Stezka   G
# 66                Rimouski Oceanic [QMJHL]         Simon_Bourque   D
# 775                 Plymouth Whalers [OHL]          Matt_Mahalak   G
# 148          Acadie-Bathurst Titan [QMJHL]   Guillaume_Brisebois   D
# 59                  Mahtomedi (Minn. H.S.)           Jack_Becker   C
# 380                  Spartak Jrs. [Russia]       Valeri_Vasiliev   D
# 76               Kimball Union (N.H. H.S.)           Jake_Massie   D
# 631               Edmonton Oil Kings [WHL]           Mitch_Moroz   L
# 87             Pardubice Jrs. (Czech Rep.)        Karel_Vejmelka   G
# 555       Shattuck St. Mary's [Minn. H.S.]          John_Draeger   D
# 400            Pardubice Jrs. [Czech Rep.]       Marek_Langhamer   G
# 547                   Saginaw Spirit [OHL]         Jake_Paterson   G
# 399         Grand Rapids H.S. [Minn. H.S.]         Jake_Bischoff   D
# 388                   Calgary Hitmen [WHL]       Jaynen_Rissling   D
# 571                     Guelph Storm [OHL]            Zac_Leslie   D
# 80            South Shore Kings [USPHL-Pr]           John_Marino   D
# 83   U.S. National Development Team [USHL]           Luke_Opilka   G
# 241                Yaroslavl (Russia Jrs.)      Pavel_Kraskovsky   F
# 99             Prince George Cougars [WHL]             Sam_Ruopp   D
# 132           Lawrence Academy (Mass H.S.)         Mike_Robinson   G
# 52              Johnstown Tomahawks [NAHL]          Ryan_Bednard   G
#
#      round_num    NHL  prediction  confidence  adj_conf  n_words
# 757          1   True        True    0.819128  0.819128      212
# 204          1   True        True    0.781667  0.781667      159
# 701          3   True        True    0.745342  0.745342       79
# 712          2   True        True    0.739234  0.739234      104
# 218          1   True        True    0.732866  0.732866      266
# 680          3   True        True    0.732829  0.732829       81
# 374          1   True        True    0.732821  0.732821      171
# 693          3   True        True    0.731859  0.731859      129
# 659          1   True        True    0.731301  0.731301      284
# 755          1   True        True    0.730153  0.730153      103
# 36           1   True        True    0.724529  0.724529       85
# 186          1   True        True    0.720925  0.720925      105
# 564          2   True        True    0.719599  0.719599      138
# 46           1   True        True    0.718413  0.718413      178
# 206          1   True        True    0.717553  0.717553      287
# 728          2   True        True    0.716905  0.716905      113
# 605          4   True        True    0.716493  0.716493      108
# 491          1   True        True    0.714335  0.714335      182
# 497          1   True        True    0.714107  0.714107      143
# 217          1   True        True    0.714079  0.714079      114
# 746          1   True        True    0.711836  0.711836      133
# 205          1   True        True    0.700945  0.700945      238
# 201          1   True        True    0.698913  0.698913       93
# 367          1   True        True    0.698678  0.698678       94
# 35           1   True        True    0.697859  0.697859      115
# 202          1   True        True    0.697449  0.697449      186
# 647          1   True        True    0.694665  0.694665      127
# 362          1   True        True    0.693274  0.693274       76
# 344          1   True        True    0.692434  0.692434      176
# 598          5   True        True    0.692319  0.692319       78
# ..         ...    ...         ...         ...       ...      ...
# 602          4  False       False    0.804285  0.195715       13
# 63           7  False       False    0.804493  0.195507       82
# 506          7  False       False    0.805615  0.194385       24
# 818          3  False       False    0.807588  0.192412       27
# 709          2  False       False    0.807771  0.192229       49
# 231          6  False       False    0.812474  0.187526       26
# 67           6  False       False    0.814755  0.185245       20
# 283          4  False       False    0.815558  0.184442       67
# 415          7  False       False    0.818712  0.181288       11
# 111          4  False       False    0.820104  0.179896       39
# 66           6  False       False    0.821373  0.178627       35
# 775          6  False       False    0.821731  0.178269       20
# 148          3  False       False    0.822328  0.177672       56
# 59           7  False       False    0.822536  0.177464        8
# 380          7  False       False    0.827340  0.172660       84
# 76           6  False       False    0.829132  0.170868       50
# 631          2  False       False    0.829382  0.170618       45
# 87           5  False       False    0.831022  0.168978       30
# 555          3  False       False    0.833672  0.166328       33
# 400          7  False       False    0.836403  0.163597       54
# 547          3  False       False    0.838316  0.161684       18
# 399          7  False       False    0.840428  0.159572       45
# 388          7  False       False    0.844237  0.155763       54
# 571          6  False       False    0.846062  0.153938       42
# 80           6  False       False    0.858281  0.141719       53
# 83           5  False       False    0.860322  0.139678       35
# 241          6  False       False    0.864202  0.135798       26
# 99           5  False       False    0.864277  0.135723       21
# 132          3  False       False    0.865569  0.134431       31
# 52           7  False       False    0.875437  0.124563       36
#
# [820 rows x 18 columns]

# %%
valid_predict[valid_predict['draft_year'] == 2019].sort_values(by='adj_conf',ascending=False)
# Out:
#      draft_num  draft_year                 name  \
# 153          0        2019          Kaapo_Kakko
# 112          0        2019      Patrik_Puistola
# 149          0        2019         Dylan_Cozens
# 146          0        2019        Alex_Turcotte
# 141          0        2019    Alexander_Newhook
# 89           0        2019  Robert_Mastrosimone
# 123          0        2019      Jakob_Pelletier
# 148          0        2019          Jack_Hughes
# 147          0        2019           Kirby_Dach
# 155          0        2019         Peyton_Krebs
# 137          0        2019             Cam_York
# 135          0        2019    Matthew_Robertson
# 96           0        2019          Albin_Grewe
# 49           0        2019      Arseni_Gritsyuk
# 144          0        2019       Philip_Broberg
# 31           0        2019         Sasha_Mutala
# 34           0        2019     Evgeni_Oksentyuk
# 143          0        2019          Bowen_Byram
# 60           0        2019        Case_McCarthy
# 50           0        2019  Valentin_Nussbaumer
# 139          0        2019        Thomas_Harley
# 56           0        2019    Vladislav_Firstov
# 142          0        2019        Trevor_Zegras
# 99           0        2019      Simon_Holmström
# 131          0        2019          Bobby_Brink
# 70           0        2019    Nando_Eggenberger
# 97           0        2019        Daniil_Misyul
# 132          0        2019          Ryan_Suzuki
# 125          0        2019        Ville_Heinola
# 121          0        2019   Harrison_Blaisdell
# ..         ...         ...                  ...
# 57           0        2019     John_Jack_Malone
# 28           0        2019         Aaron_Huglen
# 68           0        2019       Henry_Rybinski
# 94           0        2019         Mads_Søgaard
# 95           0        2019          Layton_Ahac
# 115          0        2019        Alex_Beaucage
# 84           0        2019        Yegor_Serdyuk
# 105          0        2019      Jackson_LaCombe
# 39           0        2019          Dustin_Wolf
# 32           0        2019         Oliver_Turan
# 33           0        2019           Kevin_Wall
# 65           0        2019          Cade_Webber
# 43           0        2019        Hugo_Alnefelt
# 46           0        2019            Liam_Ross
# 76           0        2019          Radek_Muzik
# 20           0        2019        Ronnie_Attard
# 21           0        2019      Juuso_Pärssinen
# 15           0        2019      Lucas_Johansson
# 150          0        2019           Mack_Guzda
# 17           0        2019       Samuel_Sjölund
# 102          0        2019      Pavel_Dorofeyev
# 98           0        2019         Colten_Ellis
# 85           0        2019       Henri_Nikkanen
# 75           0        2019             Jake_Lee
# 77           0        2019         Hunter_Jones
# 63           0        2019          Lukas_Parik
# 10           0        2019        Owen_Lindmark
# 73           0        2019      Taylor_Gauthier
# 59           0        2019         Cameron_Rowe
# 55           0        2019    Matthew_Struthers
#
#                                                 report draft_team  prediction  \
# 153  Big Finnish man child with above average size,...        TBD        True
# 112  An eye-opening performance at the Ivan Hlinka ...        TBD        True
# 149  Difference making power centre-wing with great...        TBD        True
# 146  Alfie's son is a 200 foot centre with decent s...        TBD        True
# 141  Savvy scorer with exceptional foot speed, elit...        TBD        True
# 89   “Maestro” is a high energy wing that plays in ...        TBD        True
# 123  High-pace undersized wing who who displays a h...        TBD        True
# 148  Orlando Florida born who many are calling the ...        TBD        True
# 147  Got an early taste in the "Dub" when injuries ...        TBD        True
# 155  Spirited competitor with skill and competitive...        TBD        True
# 137  Reliable all-around mobile defenseman who need...        TBD        True
# 135  Tall right side defender with a muscular frame...        TBD        True
# 96   Perpetual motion fireball of a wing with non s...        TBD        True
# 49   Elusive and tight edged little left winger wit...        TBD        True
# 144  Big, mobile Swedish defender who does everythi...        TBD        True
# 31   Physical player who dominate the U-17 who can ...        TBD        True
# 34   Tiny Belarusian winger (Cole Caufield size) ca...        TBD        True
# 143  All situation new age defender who can control...        TBD        True
# 60   The USANDTProgram has now reacts such high lev...        TBD        True
# 50   Top Swiss player makes the transition to the Q...        TBD        True
# 139  Tall OHL left defender who plays on Mississaug...        TBD        True
# 56   A slippery creative winger with a high skill s...        TBD        True
# 142  Creative centre who plays an aggressive style ...        TBD        True
# 99   So far he has had an injury-riddle past that p...        TBD        True
# 131  Hard working undersized winger with excellent ...        TBD        True
# 70   Big and strong Swiss wing who is a deceptively...        TBD        True
# 97   Tall lean attacking defenseman who is fluid on...        TBD        True
# 132  Smart quick scoring centre who gets loose and ...        TBD        True
# 125  An undersized Finnish defender already playing...        TBD        True
# 121  Well-condtionred warrior who looked impressive...        TBD        True
# ..                                                 ...        ...         ...
# 57   Big winger with skill and feel for the offensi...        TBD       False
# 28   Raw forward prospect who plays hard and attack...        TBD       False
# 68   Forced a trade out of Medicine Hat, but didn’t...        TBD       False
# 94   Giant Danish goaler who is quite agile and fle...        TBD       False
# 95   Long lean defender who wasn’t afforded as much...        TBD       False
# 115  Has become a nice sized winger with his growth...        TBD       False
# 84   Under the radar import who has gotten little b...        TBD       False
# 105  An intriguing high school who has made the tra...        TBD       False
# 39   Small goalie with agility, who competes hard. ...        TBD       False
# 32   Big man with a big frame massive reach and int...        TBD       False
# 33   Second year eligible centre-forward whonis ver...        TBD       False
# 65   Defender with a huge wingspan and frame. Displ...        TBD       False
# 43   Swedish net minder with nice size, glove and b...        TBD       False
# 46   Well-rounded OHL defender with good size whose...        TBD       False
# 76   Captained the Czech Republic team at the Five ...        TBD       False
# 20   3rd year eligible defender who moves the puck ...        TBD       False
# 21   A Centre-forward with nice size and girth and ...        TBD       False
# 15   A huge second year eligible goaltender who dis...        TBD       False
# 150  Prototypical big goaltender whose long legs, a...        TBD       False
# 17   Developing defender with good offensive tools ...        TBD       False
# 102  Intriguing long term prospect who still needs ...        TBD       False
# 98   Technically sound goaler who plays calm and co...        TBD       False
# 85   Big centre with good size and an effective pas...        TBD       False
# 75   Long term developmental defender with nice siz...        TBD       False
# 77   Has size and athleticism and is a solid techni...        TBD       False
# 63   Cool Czech goalie who stands tall and makes sa...        TBD       False
# 10   A strong on his skates, two way centre with a ...        TBD       False
# 73   Goalie prospect with good rebound control and ...        TBD       False
# 59   The “other” USA National Development goalie wh...        TBD       False
# 55   This is what I wrote last year in his first ye...        TBD       False
#
#      confidence  adj_conf
# 153    0.681088  0.681088
# 112    0.672591  0.672591
# 149    0.670912  0.670912
# 146    0.660872  0.660872
# 141    0.648463  0.648463
# 89     0.641626  0.641626
# 123    0.634157  0.634157
# 148    0.631388  0.631388
# 147    0.623298  0.623298
# 155    0.616662  0.616662
# 137    0.611782  0.611782
# 135    0.604724  0.604724
# 96     0.602302  0.602302
# 49     0.596348  0.596348
# 144    0.586471  0.586471
# 31     0.586083  0.586083
# 34     0.585628  0.585628
# 143    0.578203  0.578203
# 60     0.578138  0.578138
# 50     0.575437  0.575437
# 139    0.562212  0.562212
# 56     0.562178  0.562178
# 142    0.560218  0.560218
# 99     0.556771  0.556771
# 131    0.551222  0.551222
# 70     0.545743  0.545743
# 97     0.545182  0.545182
# 132    0.544630  0.544630
# 125    0.544327  0.544327
# 121    0.544325  0.544325
# ..          ...       ...
# 57     0.674882  0.325118
# 28     0.678815  0.321185
# 68     0.679181  0.320819
# 94     0.681447  0.318553
# 95     0.686262  0.313738
# 115    0.688025  0.311975
# 84     0.693065  0.306935
# 105    0.694421  0.305579
# 39     0.702185  0.297815
# 32     0.703109  0.296891
# 33     0.711330  0.288670
# 65     0.722517  0.277483
# 43     0.729668  0.270332
# 46     0.732487  0.267513
# 76     0.735387  0.264613
# 20     0.735435  0.264565
# 21     0.740035  0.259965
# 15     0.746783  0.253217
# 150    0.762387  0.237613
# 17     0.767241  0.232759
# 102    0.769683  0.230317
# 98     0.769804  0.230196
# 85     0.770312  0.229688
# 75     0.776924  0.223076
# 77     0.784454  0.215546
# 63     0.786453  0.213547
# 10     0.787440  0.212560
# 73     0.823716  0.176284
# 59     0.824270  0.175730
# 55     0.833946  0.166054
#
# [156 rows x 8 columns]

# %%
valid_predict['n_words'] = valid_predict['report'].str.split().apply(len)
fig = plt.figure(figsize=(18,10))
ax = fig.gca()
plt.scatter(x=valid_predict['adj_conf'],y=valid_predict['n_words'])
plt.xticks(np.arange(0,1.1,step=0.1))
plt.xlabel('Model Confidence')
plt.ylabel('Word Count')
plt.grid()
plt.show()
