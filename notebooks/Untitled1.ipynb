# %%
import pandas as pd
import numpy as np
import os
import re

# %%
reports = pd.read_csv('../data/reports/reports_v2.csv')
stats = pd.read_csv('../data/stats/stats_v2.csv')

# %%
# Replace whitespace
reports['name'] = reports['name'].str.replace(' ','_')
stats['name'] = stats['name'].str.replace(' ','_')

# Remove quotes because of forbidden characters in windows filenames
reports['name'] = reports['name'].str.replace('"','')
stats['name'] = stats['name'].str.replace('"','')

# %%
# Shift drasft numbers because of new jersey's forfeited pick
reports_shift = reports[(reports['draft_year'] == 2011) & (reports['draft_num'] >= 69)]
reports_shift['draft_num'] += 1
reports = reports[~reports['name'].isin(reports_shift['name'])]
reports = pd.concat([reports,reports_shift])
# Out:
# C:\Users\Matthew\Anaconda3\envs\hockey\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
reports2019 = reports[reports['draft_year'] == 2019]
reports_hist = reports[reports['draft_year'] != 2019]
merged = pd.merge(reports_hist.drop(columns='name'),stats,on=['draft_year','draft_num'],how='inner')
merged['NHL'] = (merged['GP'] > 0).astype(int)
#merged.head()

# %%
reports2019.head()
# Out:
#      draft_num  draft_year              name  \
# 235          0        2019      Cooper_Moore
# 238          0        2019    Eric_Ciccolini
# 240          0        2019       Mike_Koster
# 241          0        2019      Braden_Doyle
# 242          0        2019  Maxence_Guenette
#
#                                                 report
# 235     Committed to the Uiniversity of North Dakota..
# 238        Committed to the University of of Michigan.
# 240  His high school years started with him battlin...
# 241                    Committed to Boston University.
# 242  A wide framed defender with soft hands for rec...

# %%
merged.groupby(['draft_year','NHL']).size()
# Out:
# draft_year  NHL
# 2011        0       51
#             1       93
# 2012        0       87
#             1       88
# 2013        0       82
#             1       90
# 2014        0      104
#             1       69
# 2015        0      101
#             1       74
# 2016        0      105
#             1       45
# 2017        0      119
#             1       26
# 2018        0      154
#             1        8
# dtype: int64

# %%
# Define validation set
mask = (merged['draft_year'] >= 2016) & (merged['NHL'] == False)
valid = pd.concat([reports2019,merged[mask][['draft_num','draft_year','name','report']]])

# %%
valid.head()
# Out:
#      draft_num  draft_year              name  \
# 235          0        2019      Cooper_Moore
# 238          0        2019    Eric_Ciccolini
# 240          0        2019       Mike_Koster
# 241          0        2019      Braden_Doyle
# 242          0        2019  Maxence_Guenette
#
#                                                 report
# 235     Committed to the Uiniversity of North Dakota..
# 238        Committed to the University of of Michigan.
# 240  His high school years started with him battlin...
# 241                    Committed to Boston University.
# 242  A wide framed defender with soft hands for rec...

# %%
train = merged[~mask]
train['NHL'].value_counts()
# Out:
# 1    493
# 0    425
# Name: NHL, dtype: int64

# %% [markdown]
# # ==============Model==============

# %%
from sklearn.feature_extraction.text import CountVectorizer,TfidfTransformer
from sklearn.linear_model import SGDClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn import metrics

# %%
cv = CountVectorizer()
X_train_counts = cv.fit_transform(train.report)
X_train_counts.shape
# Out:
# (918, 4245)

# %%
cv.vocabulary_.get('juniors')
# Out:
# 2040

# %%
tfidf = TfidfTransformer()
X_train_tfidf = tfidf.fit_transform(X_train_counts)
X_train_tfidf.shape
# Out:
# (918, 4245)

# %%
clf = MultinomialNB().fit(X_train_tfidf,train.NHL)
X_valid_counts = cv.transform(valid.report)
X_valid_tfidf = tfidf.transform(X_valid_counts)
predicted = clf.predict(X_valid_tfidf)

# %%
valid['NHL'] = predicted
valid[valid['draft_year'] == 2019].NHL.value_counts()
# Out:
# 1    153
# 0     22
# Name: NHL, dtype: int64

# %%
np.mean(clf.predict(X_train_tfidf) == train.NHL)
# Out:
# 0.7331154684095861

# %%
# Naive Bayes
clf1 = Pipeline([
    ('vect',CountVectorizer()),
    ('tfidf',TfidfTransformer()),
    ('clf',MultinomialNB())
])

X_train,X_test,y_train,y_test = train_test_split(train.report,train.NHL,test_size=0.33,random_state=6)
clf1.fit(X_train,y_train)
predicted = clf1.predict(X_test)
np.mean(predicted == y_test)
# Out:
# 0.5742574257425742

# %%
np.mean(clf1.predict(train.report) == train.NHL)
# Out:
# 0.6982570806100218

# %%
# Linear SVM
clf2 = Pipeline([
    ('vect',CountVectorizer()),
    ('tfidf',TfidfTransformer()),
    ('clf',SGDClassifier(penalty='l2',alpha=1e-3,
                         max_iter=5,tol=None))
])

clf2.fit(train.report,train.NHL)
predicted = clf2.predict(X_test)
np.mean(predicted == y_test)
# Out:
# 0.9273927392739274

# %%
np.mean(clf2.predict(train.report) == train.NHL)
# Out:
# 0.9019607843137255

# %%
train[clf2.predict(train.report) != train.NHL]
# Out:
#       draft_num  draft_year  \
# 5            48        2013
# 12          209        2014
# 58          141        2016
# 123          76        2016
# 348         201        2015
# 364         168        2015
# 371         162        2015
# 376         150        2015
# 388         137        2015
# 390         135        2015
# 396         128        2015
# 408         115        2015
# 416         105        2015
# 427          95        2015
# 436          83        2015
# 445          66        2015
# 448          61        2015
# 464          49        2015
# 465          48        2015
# 472          40        2015
# 477          34        2015
# 478          38        2015
# 480          29        2015
# 482          26        2015
# 633          18        2017
# 652         199        2014
# 704         117        2014
# 707         114        2014
# 732          83        2014
# 757          59        2014
# ...         ...         ...
# 1004         72        2012
# 1013         62        2012
# 1016        183        2013
# 1018         65        2012
# 1019        177        2013
# 1020         69        2012
# 1042        134        2013
# 1045        136        2013
# 1048        130        2013
# 1052        120        2013
# 1053        129        2013
# 1057        127        2013
# 1059        115        2013
# 1086         38        2012
# 1091         33        2012
# 1122        111        2013
# 1123        108        2013
# 1155         73        2013
# 1159         68        2013
# 1163         62        2013
# 1174         60        2013
# 1180         38        2013
# 1192         31        2013
# 1247        151        2011
# 1251        134        2011
# 1254        129        2011
# 1263        118        2011
# 1274        101        2011
# 1275         93        2011
# 1280         83        2011
#
#                                                  report   A   G   GP  PIM  \
# 5     Versatile player with willingness to aggressiv...   0   0    0    0
# 12    Gifted scorer who has a knack for scoring. Ver...   0   0    0    0
# 58    Oversized lanky wing with surprising feet and ...   0   0    4    0
# 123           Committed to the University of Minnesota.   0   0    1    2
# 348   Under six foot carrier who has very good puck ...   0   0    0    0
# 364   Second year eligible who was a disruptive forc...   7   3   36    4
# 371   High energy wing with great wheels, strong han...   0   0    0    0
# 376   Blossoming rearguard with great all directiona...   0   0    0    0
# 388   Third year eligible centre who never takes a s...  30  12  109   34
# 390   Undersized fireplug of a wing who was the numb...   0   0    0    0
# 396   A member of his homeland’s team roster for the...   0   0    0    0
# 408   Smart two-way puck carrying defenseman whose a...   0   0    2    0
# 416   Truculent wing whose offensive side has taken ...   0   0    0    0
# 427   Possible first round sleeper who has come out ...   0   0    0    0
# 436   Interesting sleeper who is averaged sized, but...   0   0    0    0
# 445   Captain’s a weak Titan team and is good at bot...   0   0    8    0
# 448   Early on, there have been many comparisons of ...   0   0    0    0
# 464   A member of his homeland’s team roster for the...  13   9   58   24
# 465   Displays good hockey sense and game and all th...   3   2   25    8
# 472   Usually young defenders who display strong two...   0   0    0    0
# 477   Under six foot defender who is built thick and...  25   5  101   30
# 478   Lanky winger with plenty of potential. Was nam...   0   0    0    0
# 480   Huge Swedish defender who has a heavy point sh...   3   0   17    6
# 482   Thin six foot defender who plays tough but cle...   6   2   44   10
# 633   A year or so back, he was considered one of th...   0   0    2    0
# 652   Big strong two way forward with a two way game...   0   0    0    0
# 704   A late bloomer who entered the OHL as an 18 ye...   0   1    5    2
# 707   A big man who shows grit and competitive spiri...   0   0    0    0
# 732   3rd year eligible wing is a scorer with hard w...   0   0    0    0
# 757   Tall lean US goalie prospect who is currently ...   0   0    1    0
# ...                                                 ...  ..  ..  ...  ...
# 1004  Small, fearless, shifty centerman with good ho...   0   0    0    0
# 1013  Long term project who has good size, displays ...   0   0   90    2
# 1016  Solid defense-first player who plays all phase...   0   0    0    0
# 1018  Big stay-at-home defender who plays a reliable...  41  11  209   58
# 1019  Smaller buzz-bomb of an attacker who gets on t...   0   0    0    0
# 1020  Developing prospect who is a rookie in the OHL...   0   0    0    0
# 1042  Longer term forward prospect who will need to ...   1   0   15    8
# 1045  Thick centre-forward who plays an excellent tw...   0   0    0    0
# 1048  Developing scoring wing who displays ability t...   0   0    0    0
# 1052  An undersized centreman who plays fast and has...   0   0    0    0
# 1053  U. S. Team goaltender with good size and over ...   0   0   11    0
# 1057  Rangy defender who has shown glimpses of offen...   1   1   24    0
# 1059  Puck-moving defenseman who is positionally str...   0   0    0    0
# 1086  Agile wing with excellent skills, speed, and g...  27  14  150   58
# 1091  Shifty game-breaking winger with a superior hi...   0   0    0    0
# 1122  He was selected to the roster for the World Ju...   0   0    0    0
# 1123  Has only played defense for two seasons. Displ...   6   1  103   79
# 1155  Big centre who skates well and leads the rush....   0   0    0    0
# 1159  Possible sleeper who plays in the Swedish Elit...   0   0    0    0
# 1163  Thick centreman whose gifts of girth, wheels, ...   0   0    0    0
# 1174  Big skilled Swede defender already playing in ...   0   0    0    0
# 1180  Youngest player in the draft as his birthday i...   0   0    0    0
# 1192  Big skilled two-way defender who  committed to...   3   4   60   33
# 1247  Rising prep school prospect who competes at a ...   3   0   33    6
# 1251  This California-born skilled, smaller wing, pl...   0   0    0    0
# 1254                        Committed to Michigan Tech.   3   1   38   12
# 1263  2010 eligible German import who does not displ...   0   0    0    0
# 1274  Projects as a solid big forward when he adds s...   0   0   13   21
# 1275  Hard working two-way center with good touch. N...   0   0    0    0
# 1280  Rugged, balanced skating defenseman who's lear...   5   1   33    8
#
#       Pts    draft_team                            junior_team  \
# 5       0       Detroit                Owen Sound Attack [OHL]
# 12      0   Los Angeles              Kingston Frontenacs [OHL]
# 58      0    NY Rangers                   Soo Greyhounds [OHL]
# 123     0     Nashville            Muskegon Lumberjacks [USHL]
# 348     0     Minnesota                   Soo Greyhounds [OHL]
# 364    10      Winnipeg                  Tri-City Storm [USHL]
# 371     0       Florida                  Tri-City Storm [USHL]
# 376     0     Tampa Bay           Sioux City Musketeers [USHL]
# 388    42    Pittsburgh                       Plzen HC [Czech]
# 390     0     Minnesota           Novokuznetsk Metallurg [KHL]
# 396     0  Philadelphia             Chomutov Jrs. (Czech Rep.)
# 408     0     Nashville            Gatineau Olympiques [QMJHL]
# 416     0        Boston                      Regina Pats [WHL]
# 427     0       Toronto                     MODO Jrs. (Sweden)
# 436     0       Arizona                Brynas IF Gavle [SweHL]
# 445     0     Vancouver          Acadie-Bathurst Titan [QMJHL]
# 448     0       Toronto  U.S. National Development Team [USHL]
# 464    22        Dallas               Ilves Tampere [SM-liiga]
# 465     5        Ottawa        Charlottetown Islanders [QMJHL]
# 472     0      Colorado            Baie-Comeau Drakkar [QMJHL]
# 477    30       Toronto                      Erie Otters [OHL]
# 478     0      Columbus             Portland Winterhawks [WHL]
# 480     3      Columbus               Linkopings Jrs. (Sweden)
# 482     8      Montreal               Everett Silvertips [WHL]
# 633     0        Boston            JyP HT Jyvaskyla [SM-liiga]
# 652     0     Minnesota                    Brno Kometa [Czech]
# 704     1       Arizona                   Soo Greyhounds [OHL]
# 707     0      Colorado            Gatineau Olympiques [QMJHL]
# 732     0       Chicago            Muskegon Lumberjacks [USHL]
# 757     0    NY Rangers                   Soo Greyhounds [OHL]
# ...   ...           ...                                    ...
# 1004    0      Colorado            Prince George Cougars [WHL]
# 1013    0      Columbus                 Jokerit Jrs. [Finland]
# 1016    0      Colorado               Farjestads Jrs. (Sweden)
# 1018   52  NY Islanders                      Erie Otters [OHL]
# 1019    0       Anaheim                       Blues [SM-liiga]
# 1020    0      Carolina                  Oshawa Generals [OHL]
# 1042    1       Chicago                   Lincoln Stars [USHL]
# 1045    0  NY Islanders                Linkoping Jrs. (Sweden)
# 1048    0       Buffalo                     Modo Jrs. (Sweden)
# 1052    0        Boston             Valley Jr. Warriors [EJHL]
# 1053    0       Buffalo            Waterloo Black Hawks [USHL]
# 1057    2      Winnipeg                   Omaha Lancers [USHL]
# 1059    0     Vancouver                 Belleville Bulls [OHL]
# 1086   41      Carolina                  U. of Michigan [CCHA]
# 1091    0      Montreal                      Frolunda HC [SEL]
# 1122    0       Chicago               Djurgarden Jrs. (Sweden)
# 1123    7        Ottawa                     Guelph Storm [OHL]
# 1155    0    New Jersey              Kingston Frontenacs [OHL]
# 1159    0        Dallas                    Rogle (Sweden Jrs.)
# 1163    0       Phoenix    Prince Edward Island Rocket [QMJHL]
# 1174    0        Boston               Djurgarden Jrs. (Sweden)
# 1180    0       Buffalo                     Edina (Minn. H.S.)
# 1192    7       Florida            Waterloo Black Hawks [USHL]
# 1247    3        Boston                 Milton Academy [Mass.]
# 1251    0    NY Rangers                  Kelowna Rockets [WHL]
# 1254    4    New Jersey  U.S. National Development Team [USHL]
# 1263    0  Philadelphia             Seattle Thunderbirds [WHL]
# 1274    0     Vancouver            Holy Angels Academy (Minn.)
# 1275    0      Colorado                 Linkoping Jr. [Sweden]
# 1280    6       Anaheim              Green Bay Gamblers [USHL]
#
#                      name pos  round_num  NHL
# 5          Zach_Nastasiuk   R          2    0
# 12         Spencer_Watson   R          7    0
# 58          Tim_Gettinger   L          5    1
# 123           Rem_Pitlick   C          3    1
# 348      Gustav_Bouramman   D          7    0
# 364        Mason_Appleton   C          6    1
# 371          Chris_Wilkie   R          6    0
# 376        Ryan_Zuhlsdorf   D          5    0
# 388         Dominik_Simon   C          5    1
# 390       Kirill_Kaprizov   L          5    0
# 396            David_Kase   R          5    0
# 408     Alexandre_Carrier   D          4    1
# 416       Jesse_Gabrielle   L          4    0
# 427       Jesper_Lindgren   D          4    0
# 436            Jens_Looke   R          3    0
# 445   Guillaume_Brisebois   D          3    1
# 448         Jeremy_Bracco   R          2    0
# 464           Roope_Hintz   L          2    1
# 465         Filip_Chlapik   C          2    1
# 472       Nicolas_Meloche   D          2    0
# 477        Travis_Dermott   D          2    1
# 478          Paul_Bittner   L          2    0
# 480      Gabriel_Carlsson   D          1    1
# 482          Noah_Juulsen   D          1    1
# 633      Urho_Vaakanainen   D          1    1
# 652           Pavel_Jenys   R          7    0
# 704       Michael_Bunting   L          4    1
# 707          Alexis_Pepin   L          4    0
# 732    Matteson_Iacopelli   F          3    0
# 757     Brandon_Halverson   G          2    1
# ...                   ...  ..        ...  ...
# 1004          Troy_Bourke   L          3    0
# 1013     Joonas_Korpisalo   G          3    1
# 1016     Wilhelm_Westlund   D          7    0
# 1018          Adam_Pelech   D          3    1
# 1019        Miro_Aaltonen   C          6    0
# 1020    Daniel_Altshuller   G          3    0
# 1042         Luke_Johnson   C          5    1
# 1045  Viktor_Crus-Rydberg   C          5    0
# 1048       Gustav_Possler   R          5    0
# 1052      Ryan_Fitzgerald   L          4    0
# 1053         Cal_Petersen   G          5    1
# 1057       Tucker_Poolman   D          5    1
# 1059        Jordan_Subban   D          4    0
# 1086     Phil_Di_Giuseppe   L          2    1
# 1091   Sebastian_Collberg   R          2    0
# 1122         Robin_Norell   D          4    0
# 1123           Ben_Harpur   D          4    1
# 1155      Ryan_Kujawinski   C          3    0
# 1159       Niklas_Hansson   D          3    0
# 1163   Yan-Pavel_Laplante   C          3    0
# 1174       Linus_Arnesson   D          2    0
# 1180        Connor_Hurley   C          2    0
# 1192         Ian_McCoshen   D          2    1
# 1247           Rob_O'Gara   D          5    1
# 1251       Shane_McColgan   C          5    0
# 1254        Blake_Pietila   L          5    1
# 1263       Marcel_Noebels   C          4    0
# 1274           Joe_Labate   L          4    1
# 1275      Joachim_Nermark   C          4    0
# 1280        Andy_Welinski   D          3    1
#
# [82 rows x 14 columns]

# %%
print(metrics.classification_report(y_test,predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.61      0.53      0.57       143
#            1       0.63      0.70      0.66       160
#
#    micro avg       0.62      0.62      0.62       303
#    macro avg       0.62      0.62      0.62       303
# weighted avg       0.62      0.62      0.62       303

# %%
params = {
    'vect__ngram_range':[(1,1),(1,2)],
    'tfidf__use_idf':(True,False),
    'clf__alpha':(1e-2,1e-3),
    'clf__loss':('hinge','log'),
    'clf__penalty':('l1','l2','elasticnet'),
}
gs_clf = GridSearchCV(clf2,params,cv=5,iid=False,n_jobs=-1)
gs_clf.fit(train.report,train.NHL)
# Out:
# C:\Users\Matthew\Anaconda3\envs\hockey\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:183: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If max_iter is set but tol is left unset, the default value for tol in 0.19 and 0.20 will be None (which is equivalent to -infinity, so it has no effect) but will change in 0.21 to 1e-3. Specify tol to silence this warning.
#   FutureWarning)
# GridSearchCV(cv=5, error_score='raise-deprecating',
#        estimator=Pipeline(memory=None,
#      steps=[('vect', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip...ndom_state=1, shuffle=True, tol=None,
#        validation_fraction=0.1, verbose=0, warm_start=False))]),
#        fit_params=None, iid=False, n_jobs=-1,
#        param_grid={'vect__ngram_range': [(1, 1), (1, 2)], 'tfidf__use_idf': (True, False), 'clf__alpha': (0.01, 0.001), 'clf__loss': ('hinge', 'log'), 'clf__penalty': ('l1', 'l2', 'elasticnet')},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %%
gs_clf.best_score_
# Out:
# 0.6263839391779521

# %%
best_clf = gs_clf.best_estimator_
print(gs_clf.best_params_)
# Out:
# {'clf__alpha': 0.001, 'clf__loss': 'log', 'clf__penalty': 'elasticnet', 'tfidf__use_idf': False, 'vect__ngram_range': (1, 2)}

# %%
print(best_clf.steps)
# Out:
# [('vect', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 2), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)), ('tfidf', TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False,
#          use_idf=False)), ('clf', SGDClassifier(alpha=0.001, average=False, class_weight=None,
#        early_stopping=False, epsilon=0.1, eta0=0.0, fit_intercept=True,
#        l1_ratio=0.15, learning_rate='optimal', loss='log', max_iter=5,
#        n_iter=None, n_iter_no_change=5, n_jobs=None, penalty='elasticnet',
#        power_t=0.5, random_state=1, shuffle=True, tol=None,
#        validation_fraction=0.1, verbose=0, warm_start=False))]

# %%
train_predictions = best_clf.fit(train.report,train.NHL).predict(train.report)
valid_predictions = best_clf.fit(train.report,train.NHL).predict(valid.report)

# %%
np.mean(train_predictions == train.NHL)
# Out:
# 0.6993464052287581

# %%
# Erroneous predictions
train['predictions'] = train_predictions
train[train.NHL != train.predictions]
# Out:
# C:\Users\Matthew\Anaconda3\envs\hockey\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#       draft_num  draft_year  \
# 3            51        2013
# 4            59        2011
# 5            48        2013
# 6            47        2013
# 7            44        2013
# 9            49        2013
# 12          209        2014
# 58          141        2016
# 123          76        2016
# 198          39        2016
# 204          53        2016
# 205          29        2016
# 211          23        2016
# 341         205        2015
# 345         202        2015
# 348         201        2015
# 354         185        2015
# 364         168        2015
# 368         160        2015
# 371         162        2015
# 379         148        2015
# 382         143        2015
# 383         141        2015
# 388         137        2015
# 389         136        2015
# 390         135        2015
# 396         128        2015
# 399         132        2015
# 401         117        2015
# 402         125        2015
# ...         ...         ...
# 1180         38        2013
# 1185         36        2013
# 1192         31        2013
# 1213          7        2013
# 1220        187        2011
# 1222        203        2011
# 1232        176        2011
# 1233        175        2011
# 1243        159        2011
# 1245        154        2011
# 1248        143        2011
# 1249        145        2011
# 1250        135        2011
# 1251        134        2011
# 1254        129        2011
# 1255        133        2011
# 1261        116        2011
# 1262        114        2011
# 1263        118        2011
# 1264        111        2011
# 1266        109        2011
# 1269        106        2011
# 1272         98        2011
# 1273        115        2011
# 1275         93        2011
# 1277         92        2011
# 1280         83        2011
# 1287         79        2011
# 1290         72        2011
# 1293         74        2011
#
#                                                  report   A   G   GP  PIM  \
# 3     Strong large molded Swedish defenseman that is...   9   0   49    6
# 4     More of a stay at home defender who does have ...   0   0    0    0
# 5     Versatile player with willingness to aggressiv...   0   0    0    0
# 6     Aggressive offensive defender with a top gear,...   0   0    0    0
# 7     Athletic hybrid goaler with good size and abil...   2   0   29    4
# 9     Displays good speed, and offensive gifts. A de...   0   0    0    0
# 12    Gifted scorer who has a knack for scoring. Ver...   0   0    0    0
# 58    Oversized lanky wing with surprising feet and ...   0   0    4    0
# 123           Committed to the University of Minnesota.   0   0    1    2
# 198   Hampered by the graduation of his former linem...  59  69  164   21
# 204   Czech Republic defender who displayed terrific...  18   5   46   30
# 205    Centre with good size who plays strong on the...   0   0   15   15
# 211   Second year eligible Finnish centre is big sli...  10   9   54    4
# 341   Six foot six goaltender with long legs and ath...   0   0    0    0
# 345   Effective two-way defender with good boots,  c...   0   0    0    0
# 348   Under six foot carrier who has very good puck ...   0   0    0    0
# 354   Russian import in his second year in the OHL. ...   0   0    0    0
# 364   Second year eligible who was a disruptive forc...   7   3   36    4
# 368   Mammoth US born defender with a good hockey IQ...   0   0    0    0
# 371   High energy wing with great wheels, strong han...   0   0    0    0
# 379   Colorado-born winger who has a strong skating ...   9   4   34    2
# 382   Crisp tape to tape passer who can carry the ma...   0   0    0    0
# 383   A Finn offensiveman who needs plenty of develo...   0   0    0    0
# 388   Third year eligible centre who never takes a s...  30  12  109   34
# 389   Russian import whose big frame and athleticism...   0   0    0    0
# 390   Undersized fireplug of a wing who was the numb...   0   0    0    0
# 396   A member of his homeland’s team roster for the...   0   0    0    0
# 399   An undersized left wing who plays hard in the ...   0   0    0    0
# 401   Younger brother of Seth Jones is a only six fo...   5   1   17    6
# 402   Fireplug winger who arguably is the most dange...   0   0    0    0
# ...                                                 ...  ..  ..  ...  ...
# 1180  Youngest player in the draft as his birthday i...   0   0    0    0
# 1185  Top goalie prospect in North America at this j...   0   0    0    0
# 1192  Big skilled two-way defender who  committed to...   3   4   60   33
# 1213  Big, mobile defenseman who is a bit of a long-...  64  24  279  247
# 1220  Undrafted last year, he is a mobile defenseman...   0   0    0    0
# 1222  Smooth skating defenseman project who can be g...   0   0    0    0
# 1232  Czech import who is a high schooler in the Uni...   0   0    0    0
# 1233  So far has been passed on in two draft years, ...   0   0    0    0
# 1243  More of a long term project and is learning in...   0   0    0    0
# 1245  Physical high school D-man who can score as we...   0   0    0    0
# 1248  If you draft him here, what you see if what yo...   0   0    6    2
# 1249  Another Czech import with size, speed, and han...   0   0    0    0
# 1250  Big, punishing defender who loves to hit the a...   0   0    0    0
# 1251  This California-born skilled, smaller wing, pl...   0   0    0    0
# 1254                        Committed to Michigan Tech.   3   1   38   12
# 1255  Long shot due to lack of good hands & puck ski...  22  14  154   80
# 1261  Florida-born defender played with Detroit Comp...   0   0    0    0
# 1262  As the NHL starts seeing more and more German ...  73  55  379   44
# 1263  2010 eligible German import who does not displ...   0   0    0    0
# 1264  He was not invited to the scouting combine pos...   0   0    0    0
# 1266  Boom or Bust Russian giant who clearly exhibit...   0   0    0    0
# 1269  Undersized opportunistic scorer with great sti...   0   0    0    0
# 1272  Mighty mite with good offensive skills who com...  30   7  160   52
# 1273  Injured much of the season, but in his brief s...   0   0    0    0
# 1275  Hard working two-way center with good touch. N...   0   0    0    0
# 1277  Limited minutes/exposure on the talent filled ...   0   0    3    2
# 1280  Rugged, balanced skating defenseman who's lear...   5   1   33    8
# 1287  Big, fluid defensive prospect who has shown ma...  17   6  170   87
# 1290  Long term project who needs to work to get his...   0   0   11    2
# 1293  Relentless banging center who wins face-offs, ...   0   0    0    0
#
#       Pts    draft_team                            junior_team  \
# 3       9       Chicago                Linkoping Jrs. (Sweden)
# 4       0       Florida             Rogle BK Angelholm [Swe-1]
# 5       0       Detroit                Owen Sound Attack [OHL]
# 6       0     St. Louis                Minnetonka (Minn. H.S.)
# 7       2    Pittsburgh               Edmonton Oil Kings [WHL]
# 9       0      San Jose            Baie-Comeau Drakkar [QMJHL]
# 12      0   Los Angeles              Kingston Frontenacs [OHL]
# 58      0    NY Rangers                   Soo Greyhounds [OHL]
# 123     0     Nashville            Muskegon Lumberjacks [USHL]
# 198   128       Chicago                      Erie Otters [OHL]
# 204    23       Detroit                 Hradec Kralove [Czech]
# 205     0        Boston  U.S. National Development Team [USHL]
# 211    19       Florida                 HIFK Juniors (Finland)
# 341     0     Nashville                   Austin Bruins [NAHL]
# 345     0  NY Islanders               Linkopings Jrs. (Sweden)
# 348     0     Minnesota                   Soo Greyhounds [OHL]
# 354     0       Toronto                     Sarnia Sting [OHL]
# 364    10      Winnipeg                  Tri-City Storm [USHL]
# 368     0      San Jose               Wausau West (Wisc. H.S.)
# 371     0       Florida                  Tri-City Storm [USHL]
# 379    13       Anaheim  U.S. National Development Team [USHL]
# 382     0    Washington                      Regina Pats [WHL]
# 383     0      Columbus                   Blues Jrs. (Finland)
# 388    42    Pittsburgh                       Plzen HC [Czech]
# 389     0       Calgary                   Calgary Hitmen [WHL]
# 390     0     Minnesota           Novokuznetsk Metallurg [KHL]
# 396     0  Philadelphia             Chomutov Jrs. (Czech Rep.)
# 399     0       Florida          Culver Academy (Indiana H.S.)
# 401     6      Edmonton  U.S. National Development Team [USHL]
# 402     0       Toronto                Quebec Remparts [QMJHL]
# ...   ...           ...                                    ...
# 1180    0       Buffalo                     Edina (Minn. H.S.)
# 1185    0      Montreal             Halifax Mooseheads [QMJHL]
# 1192    7       Florida            Waterloo Black Hawks [USHL]
# 1213   88      Edmonton                   Soo Greyhounds [OHL]
# 1220    0      Winnipeg              Green Bay Gamblers [USHL]
# 1222    0       Toronto                     Edina H.S. (Minn.)
# 1232    0  Philadelphia               Hotchkiss School (Conn.)
# 1233    0       Detroit            Swift Current Broncos [WHL]
# 1243    0    New Jersey            Swift Current Broncos [WHL]
# 1245    0       Florida                Burnsville H.S. (Minn.)
# 1248    0       Anaheim                        Skovde [Sweden]
# 1249    0       Detroit           Choate Rosemary Hall (Conn.)
# 1250    0        Dallas           Victoriaville Tigres [QMJHL]
# 1251    0    NY Rangers                  Kelowna Rockets [WHL]
# 1254    4    New Jersey  U.S. National Development Team [USHL]
# 1255   36      San Jose                     Indiana Ice [USHL]
# 1261    0  Philadelphia                  Oshawa Generals [OHL]
# 1262  128      Edmonton                Kitchener Rangers [OHL]
# 1263    0  Philadelphia             Seattle Thunderbirds [WHL]
# 1264    0       Phoenix              Medicine Hat Tigers [WHL]
# 1266    0       Chicago               Cherepovets Jr. (Russia)
# 1269    0    NY Rangers               Edmonton Oil Kings [WHL]
# 1272   37      Columbus            Shattuck St. Mary's [Minn.]
# 1273    0       Detroit                 Vancouver Giants [WHL]
# 1275    0      Colorado                 Linkoping Jr. [Sweden]
# 1277    0      Edmonton              U. of North Dakota [WCHA]
# 1280    6       Anaheim              Green Bay Gamblers [USHL]
# 1287   23       Chicago                    Linkopings HC [SEL]
# 1290    0    NY Rangers                     Edina H.S. (Minn.)
# 1293    0      Edmonton               Edmonton Oil Kings [WHL]
#
#                    name pos  round_num  NHL  predictions
# 3        Carl_Dahlstrom   D          2    1            0
# 4      Rasmus_Bengtsson   D          2    0            1
# 5        Zach_Nastasiuk   R          2    0            1
# 6        Tommy_Vannelli   D          2    0            1
# 7         Tristan_Jarry   G          2    1            0
# 9      Gabryel_Boudreau   L          2    0            1
# 12       Spencer_Watson   R          7    0            1
# 58        Tim_Gettinger   L          5    1            0
# 123         Rem_Pitlick   C          3    1            0
# 198      Alex_DeBrincat   L          2    1            0
# 204        Filip_Hronek   D          2    1            0
# 205      Trent_Frederic   C          1    1            0
# 211    Henrik_Borgstrom   C          1    1            0
# 341          Evan_Smith   G          7    0            1
# 345      Petter_Hansson   D          7    0            1
# 348    Gustav_Bouramman   D          7    0            1
# 354   Nikita_Korostelev   R          7    0            1
# 364      Mason_Appleton   C          6    1            0
# 368       Adam_Parsells   D          6    0            1
# 371        Chris_Wilkie   R          6    0            1
# 379          Troy_Terry   R          5    1            0
# 382        Connor_Hobbs   D          5    0            1
# 383        Veeti_Vainio   D          5    0            1
# 388       Dominik_Simon   C          5    1            0
# 389    Pavel_Karnaukhov   L          5    0            1
# 390     Kirill_Kaprizov   L          5    0            1
# 396          David_Kase   R          5    0            1
# 399       Karch_Bachman   L          5    0            1
# 401         Caleb_Jones   D          4    1            0
# 402     Dmytro_Timashov   L          5    0            1
# ...                 ...  ..        ...  ...          ...
# 1180      Connor_Hurley   C          2    0            1
# 1185     Zachary_Fucale   G          2    0            1
# 1192       Ian_McCoshen   D          2    1            0
# 1213      Darnell_Nurse   D          1    1            0
# 1220      Aaron_Harstad   D          7    0            1
# 1222        Max_Everson   D          7    0            1
# 1232        Petr_Placek   R          6    0            1
# 1233   Richard_Nedomlel   D          6    0            1
# 1243     Reece_Scarlett   D          6    0            1
# 1245     Eddie_Wittchow   D          6    0            1
# 1248        Max_Friberg   L          5    1            0
# 1249     Philippe_Hudon   R          5    0            1
# 1250         Troy_Vance   D          5    0            1
# 1251     Shane_McColgan   C          5    0            1
# 1254      Blake_Pietila   L          5    1            0
# 1255        Sean_Kuraly   C          5    1            0
# 1261  Colin_Suellentrop   D          4    0            1
# 1262      Tobias_Rieder   R          4    1            0
# 1263     Marcel_Noebels   C          4    0            1
# 1264         Kale_Kessy   L          4    0            1
# 1266     Maxim_Shalunov   R          4    0            1
# 1269  Michael_St._Croix   C          4    0            1
# 1272        Mike_Reilly   D          4    1            0
# 1273       Marek_Tvrdon   L          4    0            1
# 1275    Joachim_Nermark   C          4    0            1
# 1277     Dillon_Simpson   D          4    1            0
# 1280      Andy_Welinski   D          3    1            0
# 1287      Klas_Dahlbeck   D          3    1            0
# 1290     Steven_Fogarty   C          3    1            0
# 1293      Travis_Ewanyk   C          3    0            1
#
# [276 rows x 15 columns]

# %%
valid['NHL'] = valid_predictions
valid[valid.draft_year == 2019]
# Out:
#      draft_num  draft_year                   name  \
# 235          0        2019           Cooper_Moore
# 238          0        2019         Eric_Ciccolini
# 240          0        2019            Mike_Koster
# 241          0        2019           Braden_Doyle
# 242          0        2019       Maxence_Guenette
# 243          0        2019         Jackson_Millar
# 244          0        2019          Jeremi_Gerber
# 245          0        2019          Drew_Helleson
# 246          0        2019           Danny_Weight
# 247          0        2019           Kyle_Topping
# 248          0        2019             Lucas_Feuk
# 249          0        2019           Will_Francis
# 250          0        2019        Yegor_Chizhikov
# 251          0        2019          Owen_Lindmark
# 252          0        2019          Kalle_Loponen
# 253          0        2019        Ludvig_Hedström
# 254          0        2019             Cole_Brady
# 255          0        2019          Kirby_Proctor
# 256          0        2019            Quinn_Olson
# 257          0        2019            Parker_Ford
# 258          0        2019        Lucas_Johansson
# 259          0        2019         Oliver_Okuliar
# 260          0        2019         Samuel_Sjölund
# 261          0        2019        Mitchell_Brewer
# 262          0        2019     Alexander_Campbell
# 263          0        2019             Alex_Young
# 264          0        2019           Ethan_Haider
# 265          0        2019          Ronnie_Attard
# 266          0        2019        Juuso_Pärssinen
# 267          0        2019        Grant_Silianoff
# ..         ...         ...                    ...
# 485          0        2019        Tobias_Björnfot
# 486          0        2019          Nathan_Légaré
# 487          0        2019         Spencer_Knight
# 488          0        2019       Phillip_Tomasino
# 489          0        2019       Connor_McMichael
# 490          0        2019            Bobby_Brink
# 491          0        2019            Ryan_Suzuki
# 492          0        2019          Samuel_Poulin
# 493          0        2019  Vladislav_Kolyachonok
# 494          0        2019      Matthew_Robertson
# 495          0        2019          Moritz_Seider
# 496          0        2019               Cam_York
# 497          0        2019      Victor_Söderström
# 498          0        2019          Thomas_Harley
# 499          0        2019         Arthur_Kaliyev
# 500          0        2019      Alexander_Newhook
# 501          0        2019          Trevor_Zegras
# 502          0        2019            Bowen_Byram
# 503          0        2019         Philip_Broberg
# 504          0        2019       Vasily_Podkolzin
# 505          0        2019          Alex_Turcotte
# 506          0        2019             Kirby_Dach
# 507          0        2019            Jack_Hughes
# 508          0        2019           Dylan_Cozens
# 509          0        2019             Mack_Guzda
# 510          0        2019          Matthew_Boldy
# 511          0        2019         Raphaël_Lavoie
# 512          0        2019            Kaapo_Kakko
# 513          0        2019          Cole_Caufield
# 515          0        2019           Peyton_Krebs
#
#                                                 report  NHL
# 235     Committed to the Uiniversity of North Dakota..    0
# 238        Committed to the University of of Michigan.    0
# 240  His high school years started with him battlin...    1
# 241                    Committed to Boston University.    0
# 242  A wide framed defender with soft hands for rec...    1
# 243                     Committed to Colorado College.    0
# 244  Strong skating Swiss winger with a powerful sm...    1
# 245  Tall USA National Development defenseman with ...    1
# 246  Doug's son has good size, vision, hands and a ...    0
# 247  Under six foot centre with a smooth skating st...    1
# 248  A Swedish centre who plays a smart game as a p...    0
# 249  Big bodied defender who has worked himself int...    1
# 250  Russian winger with a long stick who is a mast...    1
# 251  A strong on his skates, two way centre with a ...    0
# 252  Undersized defender who plays with the jam of ...    1
# 253  A smart defender with excellent hockey sense a...    1
# 254         Committed to the Arizona State University.    0
# 255  Committed to the University of Nebraska at Omaha.    0
# 256  Linemate of Dylan Holloway who plays a sound g...    1
# 257  Undersized centreman is constantly moving no m...    1
# 258  A huge second year eligible goaltender who dis...    1
# 259  Lanky Slovakian wing with skill and feistiness...    1
# 260  Developing defender with good offensive tools ...    0
# 261  A play it safe defender with a calm demeanor a...    1
# 262  Undersized forward who has elite feet. A true ...    0
# 263                   Committed to Colgate University.    0
# 264                  Committed to Clarkson University.    0
# 265  3rd year eligible defender who moves the puck ...    0
# 266  A Centre-forward with nice size and girth and ...    0
# 267  Winger who Is an excellent skater with terrifi...    1
# ..                                                 ...  ...
# 485  A push the pace attacking defenseman who plays...    1
# 486  Legare is 200 plus pound winger with strong co...    1
# 487  It is very rare that NHL teams select and stri...    1
# 488  High tempoed terrific skater who unearths his ...    1
# 489  Centre-wing with excellent speed, hands, shot ...    1
# 490  Hard working undersized winger with excellent ...    1
# 491  Smart quick scoring centre who gets loose and ...    1
# 492  Patrick's son already has one strong rookie se...    1
# 493  Yet another Flint team player who despite the ...    1
# 494  Tall right side defender with a muscular frame...    1
# 495  Huge German defender with a strong two way gam...    0
# 496  Reliable all-around mobile defenseman who need...    1
# 497  An under six foot Swedish defender with terrif...    1
# 498  Tall OHL left defender who plays on Mississaug...    1
# 499  Lit up the OHL Hamilton championship team, wit...    1
# 500  Savvy scorer with exceptional foot speed, elit...    1
# 501  Creative centre who plays an aggressive style ...    1
# 502  All situation new age defender who can control...    1
# 503  Big, mobile Swedish defender who does everythi...    1
# 504  Dynamic up and winger who can make a differenc...    1
# 505  Alfie's son is a 200 foot centre with decent s...    1
# 506  Got an early taste in the "Dub" when injuries ...    1
# 507  Orlando Florida born who many are calling the ...    1
# 508  Difference making power centre-wing with great...    1
# 509  Prototypical big goaltender whose long legs, a...    1
# 510  WInger with a solid two-way game, who finds th...    1
# 511  There are diverse opinions on how quickly this...    1
# 512  Big Finnish man child with above average size,...    1
# 513  Right now, a diminutive score with great wheel...    1
# 515  Spirited competitor with skill and competitive...    1
#
# [175 rows x 5 columns]

# %%
vect = best_clf.get_params()['vect']
tfidf = best_clf.get_params()['tfidf']
clf = best_clf.get_params()['clf']
class_labels = best_clf.classes_
feature_names = vect.get_feature_names()

# %%
# Negative features
[feature_names[i] for i in clf.coef_[0].argsort()[:100]]
# Out:
# ['good',
#  'game',
#  'university',
#  'term',
#  'has',
#  'developing',
#  'offensive',
#  'big',
#  'development',
#  'size and',
#  'his feet',
#  'some',
#  'feet',
#  'balance',
#  'all',
#  'need',
#  'the university',
#  'long term',
#  'defensive',
#  'goaltender',
#  'and is',
#  'physical',
#  'who has',
#  'raw',
#  'but',
#  'nice',
#  'must',
#  'and good',
#  'solid',
#  'wall',
#  'committed to',
#  'university of',
#  'zone',
#  'to develop',
#  'prospect',
#  'far',
#  'projects as',
#  'committed',
#  'like',
#  'as',
#  'developmental',
#  'two way',
#  'projects',
#  'improving',
#  'abilities',
#  'on his',
#  'hard',
#  'displays',
#  'passes',
#  'far from',
#  'has committed',
#  'if',
#  'prospect with',
#  'long',
#  'the cycle',
#  'positioning',
#  'develop',
#  'this',
#  'way',
#  'with the',
#  'physicality',
#  'cycle',
#  'wing',
#  'things',
#  'does',
#  'shutdown',
#  'they',
#  'that will',
#  'but already',
#  'has some',
#  'and offensive',
#  'open',
#  'size',
#  'school',
#  'as he',
#  'usa',
#  'also',
#  'second',
#  'in front',
#  'frame',
#  'time to',
#  'where',
#  'winger',
#  'continue',
#  'who is',
#  'prowess',
#  'challenge',
#  'cycle and',
#  'based on',
#  'corners',
#  'bit of',
#  'finds',
#  'all around',
#  'wisconsin',
#  'good vision',
#  'tools',
#  'possible',
#  'show',
#  'shot and',
#  'rebound']

# %%
# Positive features
[feature_names[i] for i in clf.coef_[0].argsort()[-100:][::-1]]
# Out:
# ['he',
#  'great',
#  'high',
#  'in',
#  'quick',
#  'with',
#  'the',
#  'on',
#  'stick',
#  'him',
#  'speed',
#  'being',
#  'scorer',
#  'you',
#  'line',
#  'he is',
#  'excellent',
#  'end',
#  'many',
#  'are',
#  'skater who',
#  'due',
#  'skater',
#  'due to',
#  'top',
#  'get',
#  'foot',
#  'go',
#  'but he',
#  'set',
#  'upside',
#  'team',
#  'how',
#  'net',
#  'smart',
#  'early',
#  'that',
#  'and',
#  'the best',
#  'player',
#  'world',
#  'nhl',
#  'with excellent',
#  'able',
#  'draft',
#  'speed and',
#  'the puck',
#  'players',
#  'attack',
#  'shift',
#  'release',
#  'defenders',
#  'able to',
#  'undersized',
#  'hockey',
#  'the net',
#  'his skating',
#  'set up',
#  'can',
#  'vision and',
#  'player who',
#  'play',
#  'shot',
#  'of the',
#  'to get',
#  'strong',
#  'junior',
#  'his team',
#  'improvement',
#  'jump',
#  'offensive upside',
#  'well',
#  'and has',
#  'accurate',
#  'vision',
#  'without',
#  'very',
#  'junior under',
#  'getting',
#  'passing',
#  'be the',
#  'moves',
#  'world junior',
#  'with his',
#  'moves well',
#  'whose',
#  'three',
#  'have',
#  'when',
#  'space',
#  'needs more',
#  'and will',
#  'level',
#  '20',
#  'crease',
#  'the top',
#  'pro',
#  'their',
#  'one',
#  'both']

# %%
clf.coef_[0][13108]
# Out:
# 1.9763950475962724

# %% [markdown]
# # ==============NHL Corpus==============

# %%
import nltk
from nltk.corpus import CategorizedPlaintextCorpusReader
import random

# %%
nhl = CategorizedPlaintextCorpusReader(root='../data/NHLcorpus/',fileids=r'.*\.txt',cat_pattern='(\w+)/*')

# %%
documents = [(list(nhl.words(fileid)),category)
             for category in nhl.categories()
             for fileid in nhl.fileids(category)]
random.shuffle(documents)

# %%
all_words = nltk.FreqDist(w.lower() for w in nhl.words())
all_words.most_common(1000)
# Out:
# [('.', 4755),
#  ('and', 3597),
#  ('the', 3332),
#  (',', 2812),
#  ('a', 2410),
#  ('to', 2085),
#  ('he', 1842),
#  ('his', 1762),
#  ('in', 1451),
#  ('is', 1236),
#  ('with', 1058),
#  ('-', 1025),
#  ('has', 939),
#  ('of', 907),
#  ('who', 888),
#  ('on', 804),
#  ('good', 780),
#  ('but', 573),
#  ('puck', 567),
#  ('as', 561),
#  ('strong', 455),
#  ('an', 414),
#  ('at', 410),
#  ('for', 402),
#  ('that', 401),
#  ('game', 400),
#  ('player', 391),
#  ('him', 369),
#  ('can', 364),
#  ('be', 347),
#  ('will', 334),
#  ('plays', 331),
#  ('well', 301),
#  ('up', 299),
#  ('offensive', 297),
#  ('play', 295),
#  ('all', 289),
#  ('big', 279),
#  ("'", 268),
#  ('excellent', 257),
#  ('shot', 248),
#  ('very', 248),
#  ('needs', 240),
#  ('size', 235),
#  ('more', 230),
#  ('was', 229),
#  ('get', 224),
#  ('t', 219),
#  ('speed', 219),
#  ('team', 215),
#  ('it', 215),
#  ('not', 215),
#  ('zone', 207),
#  ('when', 205),
#  ('ice', 201),
#  ('skills', 201),
#  ('quick', 198),
#  ('work', 194),
#  ('defensive', 190),
#  ('this', 188),
#  ('long', 186),
#  ('feet', 182),
#  ('one', 181),
#  ('hands', 180),
#  ('from', 179),
#  ('skating', 178),
#  ('defender', 176),
#  ('junior', 176),
#  ('ability', 175),
#  ('or', 175),
#  ('out', 173),
#  ('may', 171),
#  ('high', 171),
#  ('s', 167),
#  ('under', 164),
#  ('end', 164),
#  ('displays', 162),
#  ('great', 161),
#  ('wing', 157),
#  ('attack', 157),
#  ('have', 156),
#  ('stick', 152),
#  ('hard', 147),
#  ('world', 147),
#  ('prospect', 146),
#  ('’', 141),
#  ('way', 139),
#  ('top', 135),
#  ('two', 133),
#  ('solid', 131),
#  ('point', 131),
#  ('first', 130),
#  ('time', 130),
#  ('term', 129),
#  ('vision', 128),
#  ('upside', 128),
#  ('some', 126),
#  ('if', 126),
#  ('strength', 121),
#  ('there', 120),
#  ('power', 120),
#  ('make', 119),
#  ('wall', 119),
#  ('man', 118),
#  ('nhl', 117),
#  ('year', 116),
#  ('scoring', 115),
#  ('like', 114),
#  ('into', 114),
#  ('centre', 114),
#  ('down', 114),
#  ('roster', 113),
#  ('around', 112),
#  ('hockey', 112),
#  ('still', 112),
#  ('forward', 112),
#  ('skill', 106),
#  ('makes', 104),
#  ('skater', 104),
#  ('defenseman', 103),
#  ('already', 101),
#  ('by', 97),
#  ('off', 96),
#  ('set', 96),
#  ('where', 96),
#  ('gets', 95),
#  ('you', 94),
#  ('committed', 94),
#  ('guy', 93),
#  ('physical', 92),
#  ('so', 92),
#  ('stride', 92),
#  ('bigger', 91),
#  ('front', 90),
#  ('balance', 89),
#  ('18', 89),
#  ('draft', 89),
#  ('areas', 88),
#  ('are', 88),
#  ('back', 87),
#  ('doesn', 86),
#  ('project', 85),
#  ('foot', 85),
#  ('need', 84),
#  ('soft', 84),
#  ('shows', 84),
#  ('passes', 84),
#  ('own', 84),
#  ('much', 83),
#  ('smart', 83),
#  ('improve', 82),
#  ('uses', 81),
#  ('tournament', 81),
#  ('pass', 81),
#  ('also', 81),
#  ('passer', 81),
#  ('stronger', 80),
#  ('level', 80),
#  ('really', 80),
#  ('both', 78),
#  ('scorer', 78),
#  ('go', 78),
#  ('net', 78),
#  ('quickness', 77),
#  ('winger', 76),
#  ('does', 74),
#  ('playing', 74),
#  ('bit', 74),
#  ('university', 74),
#  ('selected', 74),
#  ('season', 74),
#  ('line', 74),
#  ('better', 73),
#  ('nice', 73),
#  ('abilities', 72),
#  ('pro', 72),
#  ('control', 71),
#  ('open', 71),
#  ('pp', 70),
#  ('being', 70),
#  ('release', 70),
#  ('than', 70),
#  ('defenders', 69),
#  ('lateral', 69),
#  ('due', 69),
#  ('many', 68),
#  ('teams', 68),
#  ('might', 68),
#  ('over', 67),
#  ('mobility', 66),
#  ('just', 66),
#  ('even', 66),
#  ('agility', 65),
#  ('developing', 65),
#  ('jump', 65),
#  ('players', 65),
#  ('going', 64),
#  ('pucks', 64),
#  ('three', 64),
#  ('seems', 63),
#  ('far', 63),
#  ('six', 63),
#  ('passing', 63),
#  ('april', 62),
#  ('reads', 62),
#  ('along', 62),
#  ('skates', 61),
#  ('projects', 61),
#  ('because', 61),
#  ('heavy', 61),
#  ('against', 61),
#  ('body', 61),
#  ('transition', 60),
#  ('north', 60),
#  ('chances', 60),
#  ('whose', 60),
#  ('undersized', 60),
#  ('best', 59),
#  ('himself', 59),
#  ('develop', 59),
#  ('things', 58),
#  ('aggressive', 58),
#  ('most', 58),
#  ('had', 57),
#  ('developmental', 56),
#  ('able', 56),
#  ('no', 56),
#  ('decent', 55),
#  ('handling', 55),
#  ('center', 55),
#  ('low', 55),
#  ('moves', 55),
#  ('side', 54),
#  ('always', 54),
#  ('early', 54),
#  ('take', 53),
#  ('zones', 52),
#  ('/', 52),
#  ('attackers', 51),
#  ('use', 51),
#  ('battles', 51),
#  ('style', 51),
#  ('battle', 50),
#  ('position', 50),
#  ('see', 50),
#  ('defense', 50),
#  ('while', 49),
#  ('continue', 48),
#  ('shown', 48),
#  ('enough', 48),
#  ('never', 47),
#  ('reach', 47),
#  ('development', 47),
#  ('they', 47),
#  ('making', 47),
#  ('frame', 47),
#  ('could', 47),
#  ('takes', 46),
#  ('them', 46),
#  ('second', 46),
#  ('instincts', 46),
#  ('after', 46),
#  ('"', 46),
#  ('eligible', 45),
#  ('improving', 45),
#  ('iq', 45),
#  ('what', 45),
#  ('average', 45),
#  ('opposition', 45),
#  ('tough', 45),
#  ('plenty', 45),
#  ('too', 44),
#  ('progress', 44),
#  ('room', 44),
#  ('moving', 44),
#  ('elite', 44),
#  ('little', 44),
#  ('come', 43),
#  ('terrific', 43),
#  ('20', 43),
#  ('games', 43),
#  ('goals', 43),
#  ('away', 42),
#  ('physicality', 42),
#  ('quickly', 42),
#  ('willing', 42),
#  ('league', 41),
#  ('skilled', 41),
#  ('stay', 41),
#  ('u', 41),
#  ('acceleration', 41),
#  ('look', 41),
#  ('working', 40),
#  ('edge', 40),
#  ('getting', 40),
#  ('teammates', 40),
#  ('looks', 40),
#  ('smaller', 40),
#  ('right', 40),
#  ('isn', 40),
#  ('traffic', 40),
#  ('smarts', 40),
#  ('touch', 40),
#  ('been', 40),
#  ('attacker', 39),
#  ('phases', 39),
#  ('huge', 39),
#  ('area', 39),
#  ('although', 39),
#  ('possesses', 39),
#  ('space', 38),
#  ('close', 38),
#  ('last', 37),
#  ('goal', 37),
#  ('shift', 37),
#  ('handles', 37),
#  ('despite', 37),
#  ('any', 37),
#  ('i', 37),
#  ('difficult', 36),
#  ('potential', 36),
#  ('do', 36),
#  ('fearless', 36),
#  ('only', 36),
#  ('round', 36),
#  ('defensively', 35),
#  ('shots', 35),
#  ('effective', 35),
#  ('carrier', 35),
#  ('situations', 35),
#  ('their', 35),
#  ('decisions', 35),
#  ('four', 34),
#  ('calm', 34),
#  ('balanced', 34),
#  ('christmas', 34),
#  ('would', 34),
#  ('accurate', 34),
#  ('played', 33),
#  ('stop', 33),
#  ('commitment', 33),
#  ('lots', 33),
#  ('points', 33),
#  ('must', 32),
#  ('move', 32),
#  ('juncture', 32),
#  ('fast', 32),
#  ('member', 32),
#  ('2014', 32),
#  ('sees', 32),
#  ('class', 32),
#  ('through', 32),
#  ('improvement', 31),
#  ('how', 31),
#  ('presence', 31),
#  ('win', 31),
#  ('powerful', 31),
#  ('once', 31),
#  ('pressure', 31),
#  ('weight', 31),
#  ('tremendous', 31),
#  ('physically', 31),
#  ('south', 31),
#  ('hits', 30),
#  ('outlet', 30),
#  ('sense', 30),
#  ('goes', 30),
#  ('forecheck', 30),
#  ('tall', 30),
#  ('russian', 30),
#  ('homeland', 30),
#  ('swedish', 30),
#  ('muscle', 30),
#  ('checks', 30),
#  ('step', 30),
#  ('tools', 30),
#  ('tourney', 30),
#  ('carrying', 29),
#  ('born', 29),
#  ('grit', 29),
#  ('fact', 29),
#  ('handle', 29),
#  ('add', 29),
#  ('another', 29),
#  ('forechecker', 29),
#  ('score', 28),
#  ('home', 28),
#  ('become', 28),
#  ('decision', 28),
#  ('&', 28),
#  ('200', 28),
#  ('prospects', 28),
#  ('compete', 28),
#  ('ends', 28),
#  ('possession', 28),
#  ('biscuit', 28),
#  ('wrist', 28),
#  ('improved', 28),
#  ('show', 28),
#  ('named', 27),
#  ('based', 27),
#  ('willingness', 27),
#  ('find', 27),
#  ('gears', 27),
#  ('agile', 27),
#  ('opponents', 27),
#  ('pick', 27),
#  ('help', 27),
#  ('feel', 27),
#  ('which', 27),
#  ('don', 27),
#  ('every', 27),
#  ('grow', 27),
#  ('give', 27),
#  ('ready', 27),
#  ('active', 26),
#  ('positioning', 26),
#  ('son', 26),
#  ('lack', 26),
#  ('hasn', 26),
#  ('prowess', 26),
#  ('fill', 26),
#  ('about', 26),
#  ('offense', 26),
#  ('goalie', 26),
#  ('crease', 26),
#  ('linemates', 26),
#  ('mobile', 25),
#  ('other', 25),
#  ('carry', 25),
#  ('left', 25),
#  ('works', 25),
#  ('selection', 25),
#  ('pace', 25),
#  ('college', 25),
#  ('shooter', 25),
#  ('exceptional', 24),
#  ('name', 24),
#  ('american', 24),
#  ('ohl', 24),
#  ('movement', 24),
#  ('gear', 24),
#  ('using', 24),
#  ('import', 24),
#  ('keeps', 24),
#  ('minnesota', 24),
#  ('scored', 24),
#  ('penalty', 24),
#  ('third', 24),
#  ('part', 24),
#  ('(', 24),
#  ('rush', 24),
#  ('lot', 24),
#  ('wide', 24),
#  ('former', 23),
#  ('responsible', 23),
#  ('head', 23),
#  ('growing', 23),
#  ('laterally', 23),
#  ('let', 23),
#  ('face', 23),
#  ('small', 23),
#  ('higher', 23),
#  ('present', 23),
#  ('then', 23),
#  ('playmaking', 23),
#  ('put', 23),
#  ('minutes', 23),
#  ('build', 23),
#  ('rising', 23),
#  ('continues', 23),
#  ('whether', 23),
#  ('showing', 23),
#  ('showed', 23),
#  ('drive', 23),
#  ('above', 23),
#  ('large', 22),
#  ('usa', 22),
#  ('ivan', 22),
#  ('pk', 22),
#  ('advantage', 22),
#  ('creates', 22),
#  ('competition', 22),
#  ('short', 22),
#  ('glove', 22),
#  ('wins', 22),
#  ('possible', 22),
#  ('competitor', 22),
#  ('challenge', 22),
#  ('thick', 22),
#  ('generator', 22),
#  ('carries', 22),
#  ('smooth', 22),
#  ('years', 22),
#  ('question', 22),
#  ('pretty', 22),
#  ('break', 21),
#  ('before', 21),
#  ('corners', 21),
#  ('talent', 21),
#  ('impact', 21),
#  ('terms', 21),
#  ('gaps', 21),
#  ('now', 21),
#  ('shoot', 21),
#  ('tight', 21),
#  ('until', 21),
#  ('future', 21),
#  ('girth', 21),
#  ('gain', 21),
#  ('leg', 21),
#  ('dirty', 21),
#  ('understands', 21),
#  ('awareness', 21),
#  ('superb', 21),
#  ('yet', 21),
#  ('extremely', 21),
#  ('displayed', 21),
#  ('simply', 21),
#  ('leads', 21),
#  ('hlinka', 20),
#  ('full', 20),
#  ('longer', 20),
#  (';', 20),
#  ('cycle', 20),
#  ('direction', 20),
#  ('intriguing', 20),
#  ('fluid', 20),
#  ('force', 20),
#  ('comes', 20),
#  ('wants', 20),
#  ('threat', 20),
#  ('handler', 20),
#  ('taking', 20),
#  ('since', 20),
#  ('raw', 20),
#  ('place', 20),
#  ('dominant', 20),
#  ('natural', 20),
#  ('think', 20),
#  ('less', 20),
#  ('though', 20),
#  ('injury', 20),
#  ('package', 20),
#  ('father', 20),
#  ('energy', 19),
#  ('finds', 19),
#  ('positionally', 19),
#  ('lets', 19),
#  ('finnish', 19),
#  ('made', 19),
#  ('positions', 19),
#  ('significant', 19),
#  ('role', 19),
#  ('toughness', 19),
#  ('polished', 19),
#  ('hit', 19),
#  ('without', 19),
#  ('creative', 19),
#  ('looking', 19),
#  ('lead', 19),
#  ('late', 19),
#  ('playmaker', 19),
#  ('czech', 19),
#  ('nasty', 19),
#  ('straight', 19),
#  ('quicker', 18),
#  ('road', 18),
#  ('contact', 18),
#  ('called', 18),
#  ('thin', 18),
#  ('clearly', 18),
#  ('new', 18),
#  ('learning', 18),
#  ('goaltender', 18),
#  ('overall', 18),
#  ('relentless', 18),
#  ('finished', 18),
#  ('?', 18),
#  ('matter', 18),
#  ('five', 17),
#  ('true', 17),
#  ('start', 17),
#  ('create', 17),
#  ('certainly', 17),
#  ('qmjhl', 17),
#  ('starting', 17),
#  ('starts', 17),
#  ('those', 17),
#  ('check', 17),
#  ('patient', 17),
#  ('loose', 17),
#  ('maybe', 17),
#  ('jam', 17),
#  ('board', 17),
#  ('michigan', 17),
#  ('success', 17),
#  ('seen', 17),
#  ('stand', 17),
#  ('drives', 17),
#  ('past', 17),
#  ('super', 17),
#  ('club', 17),
#  ('emerging', 17),
#  ('burst', 17),
#  ('nhler', 17),
#  ('lightning', 17),
#  ('drop', 17),
#  ('6', 17),
#  ('snarl', 17),
#  ('offensively', 17),
#  ('parts', 17),
#  ('sized', 17),
#  ('shoots', 17),
#  ('type', 17),
#  ('easily', 17),
#  ('simple', 16),
#  ('confident', 16),
#  ('few', 16),
#  ('gives', 16),
#  ('cause', 16),
#  ('ethic', 16),
#  ('wait', 16),
#  ('lanes', 16),
#  ('framed', 16),
#  ('beat', 16),
#  ('each', 16),
#  ('creativity', 16),
#  ('drafted', 16),
#  ('light', 16),
#  ('chance', 16),
#  ('outside', 16),
#  ('centreman', 16),
#  ('wheels', 16),
#  ('entire', 16),
#  ('knows', 16),
#  ('rookie', 16),
#  ('times', 16),
#  ('legs', 16),
#  ('consistency', 16),
#  ('tape', 16),
#  ('men', 16),
#  ('intensity', 16),
#  ('poise', 16),
#  ('dee', 15),
#  ('aggression', 15),
#  ('safe', 15),
#  ('sound', 15),
#  ('real', 15),
#  ('separation', 15),
#  ('developed', 15),
#  ('levels', 15),
#  ('hold', 15),
#  ('checker', 15),
#  ('patience', 15),
#  ('school', 15),
#  ('totals', 15),
#  ('17', 15),
#  ('lanky', 15),
#  ('coverage', 15),
#  ('2011', 15),
#  ('impressive', 15),
#  ('old', 15),
#  ('skate', 15),
#  ('boards', 15),
#  ('involved', 15),
#  ('status', 15),
#  ('young', 15),
#  ('demeanor', 15),
#  ('further', 15),
#  ('opportunistic', 15),
#  ('know', 15),
#  ('qb', 15),
#  ('easy', 15),
#  ('kid', 15),
#  ('nonetheless', 14),
#  ('gap', 14),
#  ('reliable', 14),
#  ('attacking', 14),
#  ('poised', 14),
#  ('athleticism', 14),
#  ('perimeter', 14),
#  ('limited', 14),
#  ('shutdown', 14),
#  ('almost', 14),
#  ('steps', 14),
#  ('canada', 14),
#  ('keep', 14),
#  ('lower', 14),
#  ('post', 14),
#  ('hand', 14),
#  ('eye', 14),
#  ('loves', 14),
#  ('engage', 14),
#  ('anticipation', 14),
#  ('closes', 14),
#  ('allows', 14),
#  ('stays', 14),
#  ('footwork', 14),
#  ('major', 14),
#  ('playoffs', 14),
#  ('besides', 14),
#  ('coming', 14),
#  ('forwards', 14),
#  ('rebounds', 14),
#  ('finisher', 14),
#  ('killer', 14),
#  ('ups', 14),
#  ('lacks', 14),
#  ('knock', 13),
#  ('next', 13),
#  ('sniper', 13),
#  ('turns', 13),
#  ('trouble', 13),
#  ('wisconsin', 13),
#  ('fine', 13),
#  ('effort', 13),
#  ('rebound', 13),
#  ('eventually', 13),
#  ('growth', 13),
#  ('consideration', 13),
#  ('punishing', 13),
#  ('worker', 13),
#  ('later', 13),
#  ('2013', 13),
#  ('shifty', 13),
#  ('seasons', 13),
#  ('athletic', 13),
#  ('boston', 13),
#  ('leader', 13),
#  ('push', 13),
#  ('goaler', 13),
#  ('problems', 13),
#  (')', 13),
#  ('turnovers', 13),
#  ('product', 13),
#  ('whl', 13),
#  ('q', 13),
#  ('d', 13),
#  ('bodied', 13),
#  ('blue', 13),
#  ('edging', 13),
#  ('tempo', 13),
#  ('necessary', 13),
#  ('dub', 12),
#  ('highly', 12),
#  ('lines', 12),
#  ('receive', 12),
#  ('strides', 12),
#  ('sweden', 12),
#  ('we', 12),
#  ('throw', 12),
#  ('edges', 12),
#  ('seem', 12),
#  ('opposing', 12),
#  ('wrister', 12),
#  ('larger', 12),
#  ('technique', 12),
#  ('elusive', 12),
#  ('camp', 12),
#  ('continued', 12),
#  ('run', 12),
#  ('sets', 12),
#  ('radar', 12),
#  ('stickhandler', 12),
#  ('state', 12),
#  ('develops', 12),
#  ('asked', 12),
#  ('consistently', 12),
#  ('won', 12),
#  ('spaces', 12),
#  ('dominate', 12),
#  ('either', 12),
#  ('complete', 12),
#  ('considered', 12),
#  ('nations', 12),
#  ('opportunities', 12),
#  ('juniors', 12),
#  ('experience', 11),
#  ('sheet', 11),
#  ('bloodlines', 11),
#  ('upon', 11),
#  ('call', 11),
#  ('spots', 11),
#  ('bottom', 11),
#  ('catch', 11),
#  ('3rd', 11),
#  ('effectively', 11),
#  ('dangle', 11),
#  ('advance', 11),
#  ('footer', 11),
#  ('likes', 11),
#  ('fairly', 11),
#  ('learn', 11),
#  ('didn', 11),
#  ('determined', 11),
#  ('having', 11),
#  ('fastest', 11),
#  ('winning', 11),
#  ('consistent', 11),
#  ('reflexes', 11),
#  ('finishes', 11),
#  ('stands', 11),
#  ('pursuit', 11),
#  ('read', 11),
#  ('attributes', 11),
#  ('deceptive', 11),
#  ('including', 11),
#  ('cool', 11),
#  ('coach', 11),
#  (':', 11),
#  ('toolbox', 11),
#  ('elusiveness', 11),
#  ('base', 11),
#  ('gifted', 11),
#  ('free', 11),
#  ('watch', 11),
#  ('spot', 11),
#  ('stretch', 11),
#  ('pivot', 11),
#  ('added', 11),
#  ('did', 11),
#  ('provide', 11),
#  ('were', 11),
#  ('overly', 11),
#  ('outstanding', 11),
#  ('2012', 11),
#  ('dynamic', 11),
#  ('gritty', 11),
#  ('surprise', 11),
#  ('younger', 11),
#  ('western', 10),
#  ('mail', 10),
#  ('5', 10),
#  ('fall', 10),
#  ('veteran', 10),
#  ('turn', 10),
#  ('backline', 10),
#  ('handed', 10),
#  ('functional', 10),
#  ('enemy', 10),
#  ('sleeper', 10),
#  ('timer', 10),
#  ('hitter', 10),
#  ('rounder', 10),
#  ('speedy', 10),
#  ('behind', 10),
#  ('prototypical', 10),
#  ('height', 10),
#  ('shut', 10),
#  ('attacks', 10),
#  ('60', 10),
#  ('minute', 10),
#  ('confidence', 10),
#  ('scouts', 10),
#  ('native', 10),
#  ('intense', 10),
#  ('older', 10),
#  ('say', 10),
#  ('cannot', 10),
#  ('cut', 10),
#  ('em', 10),
#  ('rounds', 10),
#  ('dangerous', 10),
#  ('america', 10),
#  ('middle', 10),
#  ('swiss', 10),
#  ('deadly', 10),
#  ('remains', 10),
#  ('giant', 10),
#  ('reacts', 10),
#  ('understanding', 10),
#  ('display', 10),
#  ('number', 10),
#  ('distributes', 10),
#  ('contain', 10),
#  ('instinctive', 10),
#  ('snap', 10),
#  ('load', 10),
#  ('finish', 10),
#  ('sticks', 9),
#  ('unafraid', 9),
#  ('try', 9),
#  ('pivots', 9),
#  ('teammate', 9),
#  ('surprising', 9),
#  ('thought', 9),
#  ('competitive', 9),
#  ('lists', 9),
#  ('production', 9),
#  ('east', 9),
#  ('west', 9),
#  ('ladder', 9),
#  ('slick', 9),
#  ('strider', 9),
#  ('advanced', 9),
#  ('chl', 9),
#  ('should', 9),
#  ('notice', 9),
#  ('bring', 9),
#  ('slot', 9),
#  ('select', 9),
#  ('causes', 9),
#  ('generate', 9),
#  ('midget', 9),
#  ('qualities', 9),
#  ('sure', 9),
#  ('mark', 9),
#  ('leading', 9),
#  ('upward', 9),
#  ('options', 9),
#  ('inside', 9),
#  ('usually', 9),
#  ('sometimes', 9),
#  ('ahead', 9),
#  ('water', 9),
#  ('rough', 9),
#  ('corner', 9),
#  ('shooters', 9),
#  ('thicker', 9),
#  ('half', 9),
#  ('biggest', 9),
#  ('went', 9),
#  ('mature', 9),
#  ('example', 9),
#  ('actually', 9),
#  ('fly', 9),
#  ('ever', 9),
#  ('circle', 9),
#  ('maker', 9),
#  ('helps', 9),
#  ('regularity', 9),
#  ('pounds', 9),
#  ('panic', 9),
#  ('character', 9),
#  ('excels', 8),
#  ('option', 8),
#  ('slow', 8),
#  ('us', 8),
#  ('angles', 8),
#  ('hope', 8),
#  ('fits', 8),
#  ('expect', 8),
#  ('puts', 8),
#  ('regular', 8),
#  ('ago', 8),
#  ('wasn', 8),
#  ('probably', 8),
#  ('ushl', 8),
#  ('stature', 8),
#  ('rearguard', 8),
#  ('allow', 8),
#  ('shooting', 8),
#  ('12', 8),
#  ('training', 8),
#  ('key', 8),
#  ('playoff', 8),
#  ('paint', 8),
#  ('happen', 8),
#  ('hone', 8),
#  ('motor', 8),
#  ('mean', 8),
#  ('bad', 8),
#  ('pads', 8),
#  ('basically', 8),
#  ('reading', 8),
#  ('match', 8),
#  ('16', 8),
#  ('brother', 8),
#  ('job', 8),
#  ('took', 8),
#  ('blocks', 8),
#  ('jumps', 8),
#  ('50', 8),
#  ('lacking', 8),
#  ('within', 8),
#  ('fills', 8),
#  ('again', 8),
#  ('led', 8),
#  ('couple', 8),
#  ('combined', 8),
#  ('elevated', 8),
#  ('november', 8),
#  ('pairing', 8),
#  ('rounded', 8),
#  ('drafts', 8),
#  ('needed', 8),
#  ('such', 8),
#  ('deceptively', 8),
#  ('ten', 8),
#  ('saw', 8),
#  ('comfortable', 8),
#  ('edgy', 8),
#  ('finn', 8),
#  ('defensemen', 8),
#  ('capable', 8),
#  ('russia', 8),
#  ('cannon', 8),
#  ('keeping', 7),
#  ('flight', 7)]

# %%
word_features = [w[0] for w in all_words.most_common(1000)]

def document_features(document):
    document_words = set(document)
    features = {}
    for word in word_features:
        features['contains({})'.format(word)] = word in document_words
    return features

# %%
document_features(nhl.words(nhl.fileids('false')[86]))
# Out:
# {'contains(.)': True,
#  'contains(and)': True,
#  'contains(the)': True,
#  'contains(,)': True,
#  'contains(a)': True,
#  'contains(to)': True,
#  'contains(he)': True,
#  'contains(his)': True,
#  'contains(in)': True,
#  'contains(is)': True,
#  'contains(with)': False,
#  'contains(-)': True,
#  'contains(has)': True,
#  'contains(of)': True,
#  'contains(who)': True,
#  'contains(on)': False,
#  'contains(good)': False,
#  'contains(but)': True,
#  'contains(puck)': False,
#  'contains(as)': False,
#  'contains(strong)': False,
#  'contains(an)': True,
#  'contains(at)': True,
#  'contains(for)': True,
#  'contains(that)': False,
#  'contains(game)': False,
#  'contains(player)': True,
#  'contains(him)': False,
#  'contains(can)': True,
#  'contains(be)': False,
#  'contains(will)': False,
#  'contains(plays)': True,
#  'contains(well)': False,
#  'contains(up)': False,
#  'contains(offensive)': False,
#  'contains(play)': False,
#  'contains(all)': False,
#  'contains(big)': False,
#  "contains(')": False,
#  'contains(excellent)': False,
#  'contains(shot)': False,
#  'contains(very)': False,
#  'contains(needs)': True,
#  'contains(size)': False,
#  'contains(more)': False,
#  'contains(was)': False,
#  'contains(get)': False,
#  'contains(t)': False,
#  'contains(speed)': False,
#  'contains(team)': False,
#  'contains(it)': True,
#  'contains(not)': False,
#  'contains(zone)': True,
#  'contains(when)': False,
#  'contains(ice)': False,
#  'contains(skills)': False,
#  'contains(quick)': False,
#  'contains(work)': True,
#  'contains(defensive)': False,
#  'contains(this)': True,
#  'contains(long)': False,
#  'contains(feet)': False,
#  'contains(one)': False,
#  'contains(hands)': False,
#  'contains(from)': False,
#  'contains(skating)': False,
#  'contains(defender)': False,
#  'contains(junior)': False,
#  'contains(ability)': False,
#  'contains(or)': True,
#  'contains(out)': True,
#  'contains(may)': False,
#  'contains(high)': False,
#  'contains(s)': False,
#  'contains(under)': False,
#  'contains(end)': False,
#  'contains(displays)': False,
#  'contains(great)': False,
#  'contains(wing)': False,
#  'contains(attack)': True,
#  'contains(have)': False,
#  'contains(stick)': False,
#  'contains(hard)': False,
#  'contains(world)': False,
#  'contains(prospect)': False,
#  'contains(’)': False,
#  'contains(way)': True,
#  'contains(top)': False,
#  'contains(two)': False,
#  'contains(solid)': False,
#  'contains(point)': False,
#  'contains(first)': True,
#  'contains(time)': False,
#  'contains(term)': False,
#  'contains(vision)': False,
#  'contains(upside)': False,
#  'contains(some)': False,
#  'contains(if)': True,
#  'contains(strength)': False,
#  'contains(there)': True,
#  'contains(power)': False,
#  'contains(make)': False,
#  'contains(wall)': False,
#  'contains(man)': False,
#  'contains(nhl)': False,
#  'contains(year)': True,
#  'contains(scoring)': False,
#  'contains(like)': True,
#  'contains(into)': False,
#  'contains(centre)': False,
#  'contains(down)': True,
#  'contains(roster)': False,
#  'contains(around)': False,
#  'contains(hockey)': False,
#  'contains(still)': False,
#  'contains(forward)': False,
#  'contains(skill)': False,
#  'contains(makes)': False,
#  'contains(skater)': False,
#  'contains(defenseman)': False,
#  'contains(already)': False,
#  'contains(by)': False,
#  'contains(off)': False,
#  'contains(set)': False,
#  'contains(where)': False,
#  'contains(gets)': False,
#  'contains(you)': False,
#  'contains(committed)': False,
#  'contains(guy)': False,
#  'contains(physical)': False,
#  'contains(so)': False,
#  'contains(stride)': True,
#  'contains(bigger)': False,
#  'contains(front)': False,
#  'contains(balance)': False,
#  'contains(18)': False,
#  'contains(draft)': False,
#  'contains(areas)': False,
#  'contains(are)': False,
#  'contains(back)': False,
#  'contains(doesn)': False,
#  'contains(project)': False,
#  'contains(foot)': False,
#  'contains(need)': False,
#  'contains(soft)': False,
#  'contains(shows)': False,
#  'contains(passes)': False,
#  'contains(own)': False,
#  'contains(much)': False,
#  'contains(smart)': False,
#  'contains(improve)': False,
#  'contains(uses)': False,
#  'contains(tournament)': False,
#  'contains(pass)': True,
#  'contains(also)': True,
#  'contains(passer)': True,
#  'contains(stronger)': False,
#  'contains(level)': False,
#  'contains(really)': False,
#  'contains(both)': False,
#  'contains(scorer)': False,
#  'contains(go)': False,
#  'contains(net)': False,
#  'contains(quickness)': False,
#  'contains(winger)': False,
#  'contains(does)': False,
#  'contains(playing)': True,
#  'contains(bit)': False,
#  'contains(university)': False,
#  'contains(selected)': False,
#  'contains(season)': False,
#  'contains(line)': False,
#  'contains(better)': False,
#  'contains(nice)': False,
#  'contains(abilities)': False,
#  'contains(pro)': False,
#  'contains(control)': False,
#  'contains(open)': False,
#  'contains(pp)': False,
#  'contains(being)': False,
#  'contains(release)': False,
#  'contains(than)': False,
#  'contains(defenders)': False,
#  'contains(lateral)': False,
#  'contains(due)': False,
#  'contains(many)': False,
#  'contains(teams)': False,
#  'contains(might)': False,
#  'contains(over)': False,
#  'contains(mobility)': False,
#  'contains(just)': False,
#  'contains(even)': False,
#  'contains(agility)': False,
#  'contains(developing)': False,
#  'contains(jump)': False,
#  'contains(players)': False,
#  'contains(going)': False,
#  'contains(pucks)': False,
#  'contains(three)': False,
#  'contains(seems)': False,
#  'contains(far)': False,
#  'contains(six)': False,
#  'contains(passing)': False,
#  'contains(april)': False,
#  'contains(reads)': False,
#  'contains(along)': False,
#  'contains(skates)': False,
#  'contains(projects)': False,
#  'contains(because)': False,
#  'contains(heavy)': False,
#  'contains(against)': False,
#  'contains(body)': False,
#  'contains(transition)': True,
#  'contains(north)': False,
#  'contains(chances)': False,
#  'contains(whose)': False,
#  'contains(undersized)': False,
#  'contains(best)': False,
#  'contains(himself)': False,
#  'contains(develop)': False,
#  'contains(things)': False,
#  'contains(aggressive)': False,
#  'contains(most)': False,
#  'contains(had)': False,
#  'contains(developmental)': False,
#  'contains(able)': False,
#  'contains(no)': True,
#  'contains(decent)': False,
#  'contains(handling)': False,
#  'contains(center)': False,
#  'contains(low)': False,
#  'contains(moves)': False,
#  'contains(side)': False,
#  'contains(always)': False,
#  'contains(early)': True,
#  'contains(take)': False,
#  'contains(zones)': False,
#  'contains(/)': False,
#  'contains(attackers)': False,
#  'contains(use)': False,
#  'contains(battles)': False,
#  'contains(style)': False,
#  'contains(battle)': False,
#  'contains(position)': False,
#  'contains(see)': False,
#  'contains(defense)': False,
#  'contains(while)': False,
#  'contains(continue)': False,
#  'contains(shown)': False,
#  'contains(enough)': False,
#  'contains(never)': False,
#  'contains(reach)': False,
#  'contains(development)': False,
#  'contains(they)': False,
#  'contains(making)': False,
#  'contains(frame)': True,
#  'contains(could)': False,
#  'contains(takes)': False,
#  'contains(them)': False,
#  'contains(second)': False,
#  'contains(instincts)': False,
#  'contains(after)': True,
#  'contains(")': False,
#  'contains(eligible)': False,
#  'contains(improving)': False,
#  'contains(iq)': False,
#  'contains(what)': False,
#  'contains(average)': False,
#  'contains(opposition)': False,
#  'contains(tough)': False,
#  'contains(plenty)': False,
#  'contains(too)': False,
#  'contains(progress)': False,
#  'contains(room)': False,
#  'contains(moving)': False,
#  'contains(elite)': False,
#  'contains(little)': False,
#  'contains(come)': False,
#  'contains(terrific)': False,
#  'contains(20)': False,
#  'contains(games)': False,
#  'contains(goals)': False,
#  'contains(away)': False,
#  'contains(physicality)': False,
#  'contains(quickly)': False,
#  'contains(willing)': False,
#  'contains(league)': False,
#  'contains(skilled)': False,
#  'contains(stay)': False,
#  'contains(u)': False,
#  'contains(acceleration)': False,
#  'contains(look)': False,
#  'contains(working)': False,
#  'contains(edge)': False,
#  'contains(getting)': False,
#  'contains(teammates)': False,
#  'contains(looks)': False,
#  'contains(smaller)': False,
#  'contains(right)': False,
#  'contains(isn)': False,
#  'contains(traffic)': False,
#  'contains(smarts)': False,
#  'contains(touch)': False,
#  'contains(been)': False,
#  'contains(attacker)': False,
#  'contains(phases)': False,
#  'contains(huge)': False,
#  'contains(area)': False,
#  'contains(although)': False,
#  'contains(possesses)': False,
#  'contains(space)': False,
#  'contains(close)': False,
#  'contains(last)': True,
#  'contains(goal)': False,
#  'contains(shift)': False,
#  'contains(handles)': False,
#  'contains(despite)': False,
#  'contains(any)': False,
#  'contains(i)': False,
#  'contains(difficult)': False,
#  'contains(potential)': False,
#  'contains(do)': False,
#  'contains(fearless)': False,
#  'contains(only)': False,
#  'contains(round)': False,
#  'contains(defensively)': False,
#  'contains(shots)': False,
#  'contains(effective)': False,
#  'contains(carrier)': False,
#  'contains(situations)': False,
#  'contains(their)': False,
#  'contains(decisions)': False,
#  'contains(four)': False,
#  'contains(calm)': False,
#  'contains(balanced)': False,
#  'contains(christmas)': False,
#  'contains(would)': False,
#  'contains(accurate)': False,
#  'contains(played)': False,
#  'contains(stop)': False,
#  'contains(commitment)': False,
#  'contains(lots)': True,
#  'contains(points)': False,
#  'contains(must)': False,
#  'contains(move)': False,
#  'contains(juncture)': True,
#  'contains(fast)': False,
#  'contains(member)': False,
#  'contains(2014)': False,
#  'contains(sees)': False,
#  'contains(class)': False,
#  'contains(through)': False,
#  'contains(improvement)': False,
#  'contains(how)': False,
#  'contains(presence)': False,
#  'contains(win)': False,
#  'contains(powerful)': False,
#  'contains(once)': False,
#  'contains(pressure)': False,
#  'contains(weight)': False,
#  'contains(tremendous)': False,
#  'contains(physically)': False,
#  'contains(south)': False,
#  'contains(hits)': True,
#  'contains(outlet)': False,
#  'contains(sense)': False,
#  'contains(goes)': False,
#  'contains(forecheck)': False,
#  'contains(tall)': False,
#  'contains(russian)': False,
#  'contains(homeland)': False,
#  'contains(swedish)': False,
#  'contains(muscle)': False,
#  'contains(checks)': False,
#  'contains(step)': False,
#  'contains(tools)': False,
#  'contains(tourney)': False,
#  'contains(carrying)': False,
#  'contains(born)': False,
#  'contains(grit)': True,
#  'contains(fact)': False,
#  'contains(handle)': False,
#  'contains(add)': False,
#  'contains(another)': False,
#  'contains(forechecker)': False,
#  'contains(score)': False,
#  'contains(home)': False,
#  'contains(become)': False,
#  'contains(decision)': False,
#  'contains(&)': False,
#  'contains(200)': False,
#  'contains(prospects)': False,
#  'contains(compete)': False,
#  'contains(ends)': False,
#  'contains(possession)': False,
#  'contains(biscuit)': False,
#  'contains(wrist)': False,
#  'contains(improved)': False,
#  'contains(show)': True,
#  'contains(named)': False,
#  'contains(based)': False,
#  'contains(willingness)': False,
#  'contains(find)': False,
#  'contains(gears)': False,
#  'contains(agile)': False,
#  'contains(opponents)': False,
#  'contains(pick)': False,
#  'contains(help)': False,
#  'contains(feel)': True,
#  'contains(which)': False,
#  'contains(don)': False,
#  'contains(every)': False,
#  'contains(grow)': False,
#  'contains(give)': False,
#  'contains(ready)': False,
#  'contains(active)': False,
#  'contains(positioning)': False,
#  'contains(son)': False,
#  'contains(lack)': False,
#  'contains(hasn)': False,
#  'contains(prowess)': False,
#  'contains(fill)': False,
#  'contains(about)': True,
#  'contains(offense)': False,
#  'contains(goalie)': False,
#  'contains(crease)': False,
#  'contains(linemates)': False,
#  'contains(mobile)': False,
#  'contains(other)': False,
#  'contains(carry)': True,
#  'contains(left)': False,
#  'contains(works)': False,
#  'contains(selection)': False,
#  'contains(pace)': False,
#  'contains(college)': False,
#  'contains(shooter)': False,
#  'contains(exceptional)': True,
#  'contains(name)': False,
#  'contains(american)': False,
#  'contains(ohl)': False,
#  'contains(movement)': False,
#  'contains(gear)': False,
#  'contains(using)': False,
#  'contains(import)': False,
#  'contains(keeps)': False,
#  'contains(minnesota)': False,
#  'contains(scored)': False,
#  'contains(penalty)': False,
#  'contains(third)': False,
#  'contains(part)': False,
#  'contains(()': False,
#  'contains(rush)': False,
#  'contains(lot)': True,
#  'contains(wide)': False,
#  'contains(former)': False,
#  'contains(responsible)': False,
#  'contains(head)': False,
#  'contains(growing)': False,
#  'contains(laterally)': False,
#  'contains(let)': False,
#  'contains(face)': False,
#  'contains(small)': False,
#  'contains(higher)': False,
#  'contains(present)': False,
#  'contains(then)': False,
#  'contains(playmaking)': False,
#  'contains(put)': False,
#  'contains(minutes)': False,
#  'contains(build)': False,
#  'contains(rising)': False,
#  'contains(continues)': False,
#  'contains(whether)': False,
#  'contains(showing)': False,
#  'contains(showed)': False,
#  'contains(drive)': False,
#  'contains(above)': False,
#  'contains(large)': False,
#  'contains(usa)': False,
#  'contains(ivan)': False,
#  'contains(pk)': False,
#  'contains(advantage)': False,
#  'contains(creates)': False,
#  'contains(competition)': False,
#  'contains(short)': False,
#  'contains(glove)': False,
#  'contains(wins)': False,
#  'contains(possible)': False,
#  'contains(competitor)': False,
#  'contains(challenge)': False,
#  'contains(thick)': False,
#  'contains(generator)': False,
#  'contains(carries)': False,
#  'contains(smooth)': False,
#  'contains(years)': False,
#  'contains(question)': False,
#  'contains(pretty)': False,
#  'contains(break)': False,
#  'contains(before)': False,
#  'contains(corners)': False,
#  'contains(talent)': False,
#  'contains(impact)': False,
#  'contains(terms)': False,
#  'contains(gaps)': True,
#  'contains(now)': False,
#  'contains(shoot)': True,
#  'contains(tight)': False,
#  'contains(until)': False,
#  'contains(future)': False,
#  'contains(girth)': False,
#  'contains(gain)': False,
#  'contains(leg)': False,
#  'contains(dirty)': False,
#  'contains(understands)': False,
#  'contains(awareness)': False,
#  'contains(superb)': False,
#  'contains(yet)': False,
#  'contains(extremely)': False,
#  'contains(displayed)': False,
#  'contains(simply)': False,
#  'contains(leads)': False,
#  'contains(hlinka)': False,
#  'contains(full)': False,
#  'contains(longer)': False,
#  'contains(;)': False,
#  'contains(cycle)': False,
#  'contains(direction)': False,
#  'contains(intriguing)': False,
#  'contains(fluid)': False,
#  'contains(force)': False,
#  'contains(comes)': False,
#  'contains(wants)': False,
#  'contains(threat)': False,
#  'contains(handler)': False,
#  'contains(taking)': False,
#  'contains(since)': False,
#  'contains(raw)': False,
#  'contains(place)': False,
#  'contains(dominant)': False,
#  'contains(natural)': False,
#  'contains(think)': False,
#  'contains(less)': False,
#  'contains(though)': False,
#  'contains(injury)': False,
#  'contains(package)': False,
#  'contains(father)': False,
#  'contains(energy)': False,
#  'contains(finds)': False,
#  'contains(positionally)': False,
#  'contains(lets)': False,
#  'contains(finnish)': False,
#  'contains(made)': False,
#  'contains(positions)': False,
#  'contains(significant)': False,
#  'contains(role)': False,
#  'contains(toughness)': False,
#  'contains(polished)': False,
#  'contains(hit)': False,
#  'contains(without)': False,
#  'contains(creative)': False,
#  'contains(looking)': False,
#  'contains(lead)': False,
#  'contains(late)': False,
#  'contains(playmaker)': False,
#  'contains(czech)': False,
#  'contains(nasty)': False,
#  'contains(straight)': False,
#  'contains(quicker)': False,
#  'contains(road)': False,
#  'contains(contact)': False,
#  'contains(called)': False,
#  'contains(thin)': False,
#  'contains(clearly)': True,
#  'contains(new)': False,
#  'contains(learning)': False,
#  'contains(goaltender)': False,
#  'contains(overall)': False,
#  'contains(relentless)': False,
#  'contains(finished)': False,
#  'contains(?)': False,
#  'contains(matter)': False,
#  'contains(five)': False,
#  'contains(true)': False,
#  'contains(start)': False,
#  'contains(create)': False,
#  'contains(certainly)': False,
#  'contains(qmjhl)': False,
#  'contains(starting)': False,
#  'contains(starts)': False,
#  'contains(those)': False,
#  'contains(check)': False,
#  'contains(patient)': False,
#  'contains(loose)': False,
#  'contains(maybe)': False,
#  'contains(jam)': False,
#  'contains(board)': False,
#  'contains(michigan)': False,
#  'contains(success)': False,
#  'contains(seen)': False,
#  'contains(stand)': False,
#  'contains(drives)': False,
#  'contains(past)': False,
#  'contains(super)': False,
#  'contains(club)': False,
#  'contains(emerging)': False,
#  'contains(burst)': False,
#  'contains(nhler)': False,
#  'contains(lightning)': False,
#  'contains(drop)': False,
#  'contains(6)': False,
#  'contains(snarl)': False,
#  'contains(offensively)': False,
#  'contains(parts)': False,
#  'contains(sized)': False,
#  'contains(shoots)': False,
#  'contains(type)': False,
#  'contains(easily)': False,
#  'contains(simple)': False,
#  'contains(confident)': False,
#  'contains(few)': False,
#  'contains(gives)': False,
#  'contains(cause)': False,
#  'contains(ethic)': False,
#  'contains(wait)': False,
#  'contains(lanes)': False,
#  'contains(framed)': False,
#  'contains(beat)': False,
#  'contains(each)': False,
#  'contains(creativity)': False,
#  'contains(drafted)': False,
#  'contains(light)': False,
#  'contains(chance)': False,
#  'contains(outside)': False,
#  'contains(centreman)': False,
#  'contains(wheels)': False,
#  'contains(entire)': False,
#  'contains(knows)': False,
#  'contains(rookie)': False,
#  'contains(times)': False,
#  'contains(legs)': False,
#  'contains(consistency)': False,
#  'contains(tape)': True,
#  'contains(men)': False,
#  'contains(intensity)': False,
#  'contains(poise)': False,
#  'contains(dee)': False,
#  'contains(aggression)': False,
#  'contains(safe)': False,
#  'contains(sound)': False,
#  'contains(real)': False,
#  'contains(separation)': False,
#  'contains(developed)': False,
#  'contains(levels)': False,
#  'contains(hold)': False,
#  'contains(checker)': False,
#  'contains(patience)': False,
#  'contains(school)': False,
#  'contains(totals)': False,
#  'contains(17)': False,
#  'contains(lanky)': False,
#  'contains(coverage)': False,
#  'contains(2011)': False,
#  'contains(impressive)': False,
#  'contains(old)': False,
#  'contains(skate)': False,
#  'contains(boards)': False,
#  'contains(involved)': False,
#  'contains(status)': False,
#  'contains(young)': False,
#  'contains(demeanor)': False,
#  'contains(further)': False,
#  'contains(opportunistic)': False,
#  'contains(know)': False,
#  'contains(qb)': False,
#  'contains(easy)': False,
#  'contains(kid)': False,
#  'contains(nonetheless)': False,
#  'contains(gap)': False,
#  'contains(reliable)': False,
#  'contains(attacking)': False,
#  'contains(poised)': False,
#  'contains(athleticism)': False,
#  'contains(perimeter)': False,
#  'contains(limited)': False,
#  'contains(shutdown)': False,
#  'contains(almost)': False,
#  'contains(steps)': False,
#  'contains(canada)': False,
#  'contains(keep)': False,
#  'contains(lower)': False,
#  'contains(post)': False,
#  'contains(hand)': False,
#  'contains(eye)': False,
#  'contains(loves)': False,
#  'contains(engage)': False,
#  'contains(anticipation)': False,
#  'contains(closes)': True,
#  'contains(allows)': False,
#  'contains(stays)': False,
#  'contains(footwork)': False,
#  'contains(major)': False,
#  'contains(playoffs)': False,
#  'contains(besides)': False,
#  'contains(coming)': False,
#  'contains(forwards)': False,
#  'contains(rebounds)': False,
#  'contains(finisher)': False,
#  'contains(killer)': False,
#  'contains(ups)': False,
#  'contains(lacks)': False,
#  'contains(knock)': False,
#  'contains(next)': False,
#  'contains(sniper)': False,
#  'contains(turns)': False,
#  'contains(trouble)': False,
#  'contains(wisconsin)': False,
#  'contains(fine)': False,
#  'contains(effort)': False,
#  'contains(rebound)': False,
#  'contains(eventually)': False,
#  'contains(growth)': False,
#  'contains(consideration)': False,
#  'contains(punishing)': False,
#  'contains(worker)': False,
#  'contains(later)': False,
#  'contains(2013)': False,
#  'contains(shifty)': False,
#  'contains(seasons)': False,
#  'contains(athletic)': False,
#  'contains(boston)': False,
#  'contains(leader)': False,
#  'contains(push)': False,
#  'contains(goaler)': False,
#  'contains(problems)': False,
#  'contains())': False,
#  'contains(turnovers)': False,
#  'contains(product)': False,
#  'contains(whl)': False,
#  'contains(q)': False,
#  'contains(d)': False,
#  'contains(bodied)': False,
#  'contains(blue)': False,
#  'contains(edging)': False,
#  'contains(tempo)': False,
#  'contains(necessary)': False,
#  'contains(dub)': False,
#  'contains(highly)': False,
#  'contains(lines)': False,
#  'contains(receive)': False,
#  'contains(strides)': False,
#  'contains(sweden)': False,
#  'contains(we)': False,
#  'contains(throw)': False,
#  'contains(edges)': False,
#  'contains(seem)': False,
#  'contains(opposing)': False,
#  'contains(wrister)': False,
#  'contains(larger)': False,
#  'contains(technique)': False,
#  'contains(elusive)': False,
#  'contains(camp)': False,
#  'contains(continued)': False,
#  'contains(run)': False,
#  'contains(sets)': False,
#  'contains(radar)': False,
#  'contains(stickhandler)': False,
#  'contains(state)': False,
#  'contains(develops)': False,
#  'contains(asked)': False,
#  'contains(consistently)': False,
#  'contains(won)': False,
#  'contains(spaces)': False,
#  'contains(dominate)': False,
#  'contains(either)': False,
#  'contains(complete)': False,
#  'contains(considered)': False,
#  'contains(nations)': False,
#  'contains(opportunities)': False,
#  'contains(juniors)': False,
#  'contains(experience)': False,
#  'contains(sheet)': False,
#  'contains(bloodlines)': False,
#  'contains(upon)': False,
#  'contains(call)': False,
#  'contains(spots)': False,
#  'contains(bottom)': False,
#  'contains(catch)': False,
#  'contains(3rd)': False,
#  'contains(effectively)': False,
#  'contains(dangle)': False,
#  'contains(advance)': False,
#  'contains(footer)': False,
#  'contains(likes)': False,
#  'contains(fairly)': False,
#  'contains(learn)': False,
#  'contains(didn)': False,
#  'contains(determined)': False,
#  'contains(having)': False,
#  'contains(fastest)': False,
#  'contains(winning)': False,
#  'contains(consistent)': False,
#  'contains(reflexes)': False,
#  'contains(finishes)': False,
#  'contains(stands)': False,
#  'contains(pursuit)': False,
#  'contains(read)': False,
#  'contains(attributes)': False,
#  'contains(deceptive)': False,
#  'contains(including)': False,
#  'contains(cool)': False,
#  'contains(coach)': False,
#  'contains(:)': False,
#  'contains(toolbox)': False,
#  'contains(elusiveness)': False,
#  'contains(base)': False,
#  'contains(gifted)': False,
#  'contains(free)': False,
#  'contains(watch)': False,
#  'contains(spot)': False,
#  'contains(stretch)': False,
#  'contains(pivot)': False,
#  'contains(added)': False,
#  'contains(did)': False,
#  'contains(provide)': False,
#  'contains(were)': False,
#  'contains(overly)': False,
#  'contains(outstanding)': False,
#  'contains(2012)': False,
#  'contains(dynamic)': False,
#  'contains(gritty)': False,
#  'contains(surprise)': False,
#  'contains(younger)': False,
#  'contains(western)': False,
#  'contains(mail)': True,
#  'contains(5)': False,
#  'contains(fall)': False,
#  'contains(veteran)': False,
#  'contains(turn)': False,
#  'contains(backline)': False,
#  'contains(handed)': False,
#  'contains(functional)': False,
#  'contains(enemy)': False,
#  'contains(sleeper)': False,
#  'contains(timer)': False,
#  'contains(hitter)': False,
#  'contains(rounder)': False,
#  'contains(speedy)': False,
#  'contains(behind)': False,
#  'contains(prototypical)': False,
#  'contains(height)': False,
#  'contains(shut)': False,
#  'contains(attacks)': False,
#  'contains(60)': False,
#  'contains(minute)': False,
#  'contains(confidence)': False,
#  'contains(scouts)': False,
#  'contains(native)': False,
#  'contains(intense)': False,
#  'contains(older)': False,
#  'contains(say)': False,
#  'contains(cannot)': False,
#  'contains(cut)': False,
#  'contains(em)': False,
#  'contains(rounds)': False,
#  'contains(dangerous)': False,
#  'contains(america)': False,
#  'contains(middle)': False,
#  'contains(swiss)': False,
#  'contains(deadly)': False,
#  'contains(remains)': False,
#  'contains(giant)': False,
#  'contains(reacts)': False,
#  'contains(understanding)': False,
#  'contains(display)': False,
#  'contains(number)': False,
#  'contains(distributes)': False,
#  'contains(contain)': False,
#  'contains(instinctive)': False,
#  'contains(snap)': False,
#  'contains(load)': False,
#  'contains(finish)': False,
#  'contains(sticks)': False,
#  'contains(unafraid)': False,
#  'contains(try)': False,
#  'contains(pivots)': False,
#  'contains(teammate)': False,
#  'contains(surprising)': False,
#  'contains(thought)': False,
#  'contains(competitive)': False,
#  'contains(lists)': False,
#  'contains(production)': False,
#  'contains(east)': False,
#  'contains(west)': False,
#  'contains(ladder)': False,
#  'contains(slick)': False,
#  'contains(strider)': False,
#  'contains(advanced)': False,
#  'contains(chl)': False,
#  'contains(should)': False,
#  'contains(notice)': False,
#  'contains(bring)': False,
#  'contains(slot)': False,
#  'contains(select)': False,
#  'contains(causes)': False,
#  'contains(generate)': False,
#  'contains(midget)': True,
#  'contains(qualities)': False,
#  'contains(sure)': False,
#  'contains(mark)': False,
#  'contains(leading)': False,
#  'contains(upward)': False,
#  'contains(options)': False,
#  'contains(inside)': False,
#  'contains(usually)': False,
#  'contains(sometimes)': False,
#  'contains(ahead)': False,
#  'contains(water)': False,
#  'contains(rough)': False,
#  'contains(corner)': False,
#  'contains(shooters)': False,
#  'contains(thicker)': False,
#  'contains(half)': False,
#  'contains(biggest)': False,
#  'contains(went)': False,
#  'contains(mature)': False,
#  'contains(example)': False,
#  'contains(actually)': False,
#  'contains(fly)': False,
#  'contains(ever)': False,
#  'contains(circle)': False,
#  'contains(maker)': False,
#  'contains(helps)': False,
#  'contains(regularity)': False,
#  'contains(pounds)': False,
#  'contains(panic)': False,
#  'contains(character)': False,
#  'contains(excels)': False,
#  'contains(option)': False,
#  'contains(slow)': False,
#  'contains(us)': False,
#  'contains(angles)': False,
#  'contains(hope)': False,
#  'contains(fits)': False,
#  'contains(expect)': False,
#  'contains(puts)': False,
#  'contains(regular)': False,
#  'contains(ago)': False,
#  'contains(wasn)': False,
#  'contains(probably)': False,
#  'contains(ushl)': False,
#  'contains(stature)': False,
#  'contains(rearguard)': False,
#  'contains(allow)': False,
#  'contains(shooting)': False,
#  'contains(12)': False,
#  'contains(training)': False,
#  'contains(key)': False,
#  'contains(playoff)': False,
#  'contains(paint)': False,
#  'contains(happen)': False,
#  'contains(hone)': False,
#  'contains(motor)': False,
#  'contains(mean)': False,
#  'contains(bad)': False,
#  'contains(pads)': False,
#  'contains(basically)': False,
#  'contains(reading)': False,
#  'contains(match)': False,
#  'contains(16)': False,
#  'contains(brother)': False,
#  'contains(job)': False,
#  'contains(took)': False,
#  'contains(blocks)': False,
#  'contains(jumps)': False,
#  'contains(50)': False,
#  'contains(lacking)': False,
#  'contains(within)': False,
#  'contains(fills)': False,
#  'contains(again)': False,
#  'contains(led)': False,
#  'contains(couple)': False,
#  'contains(combined)': False,
#  'contains(elevated)': False,
#  'contains(november)': False,
#  'contains(pairing)': False,
#  'contains(rounded)': False,
#  'contains(drafts)': False,
#  'contains(needed)': False,
#  'contains(such)': False,
#  'contains(deceptively)': False,
#  'contains(ten)': False,
#  'contains(saw)': False,
#  'contains(comfortable)': False,
#  'contains(edgy)': False,
#  'contains(finn)': False,
#  'contains(defensemen)': False,
#  'contains(capable)': False,
#  'contains(russia)': False,
#  'contains(cannon)': False,
#  'contains(keeping)': False,
#  'contains(flight)': False}

# %%
random.shuffle(documents)
featuresets = [(document_features(d),c) for (d,c) in documents]
train_set,test_set = featuresets[818:],featuresets[:100]
classifier = nltk.NaiveBayesClassifier.train(train_set)
nltk.classify.accuracy(classifier,test_set)
# Out:
# 0.54

# %%
classifier.show_most_informative_features(1000)
# Out:
# Most Informative Features
#           contains(will) = True             true : false  =      5.8 : 1.0
#          contains(front) = True             true : false  =      5.0 : 1.0
#         contains(season) = True             true : false  =      5.0 : 1.0
#       contains(attacker) = True             true : false  =      5.0 : 1.0
#          contains(solid) = True             true : false  =      5.0 : 1.0
#           contains(open) = True             true : false  =      4.3 : 1.0
#          contains(tools) = True            false : true   =      4.3 : 1.0
#        contains(himself) = True            false : true   =      4.3 : 1.0
#           contains(have) = True             true : false  =      4.1 : 1.0
#         contains(scorer) = True             true : false  =      3.8 : 1.0
#          contains(seems) = True             true : false  =      3.7 : 1.0
#          contains(doesn) = True             true : false  =      3.7 : 1.0
#       contains(progress) = True            false : true   =      3.7 : 1.0
#            contains(net) = True             true : false  =      3.7 : 1.0
#         contains(things) = True            false : true   =      3.7 : 1.0
#           contains(take) = True            false : true   =      3.7 : 1.0
#           contains(even) = True             true : false  =      3.7 : 1.0
#        contains(agility) = True             true : false  =      3.4 : 1.0
#         contains(handle) = True             true : false  =      3.0 : 1.0
#         contains(league) = True             true : false  =      3.0 : 1.0
#       contains(position) = True            false : true   =      3.0 : 1.0
#           contains(like) = True             true : false  =      3.0 : 1.0
#      contains(attackers) = True            false : true   =      3.0 : 1.0
#         contains(smarts) = True             true : false  =      3.0 : 1.0
#            contains(yet) = True            false : true   =      3.0 : 1.0
#        contains(willing) = True             true : false  =      3.0 : 1.0
#        contains(already) = True            false : true   =      3.0 : 1.0
#              contains(s) = True             true : false  =      3.0 : 1.0
#           contains(must) = True            false : true   =      3.0 : 1.0
#       contains(although) = True            false : true   =      3.0 : 1.0
#          contains(draft) = True             true : false  =      3.0 : 1.0
#      contains(forecheck) = True             true : false  =      3.0 : 1.0
#     contains(aggressive) = True             true : false  =      3.0 : 1.0
#          contains(would) = True             true : false  =      3.0 : 1.0
#    contains(development) = True            false : true   =      3.0 : 1.0
#            contains(use) = True            false : true   =      3.0 : 1.0
#          contains(works) = True             true : false  =      3.0 : 1.0
#          contains(hands) = True             true : false  =      2.8 : 1.0
#           contains(very) = True             true : false  =      2.7 : 1.0
#            contains(was) = True             true : false  =      2.6 : 1.0
#       contains(strength) = True             true : false  =      2.4 : 1.0
#     contains(defenseman) = True             true : false  =      2.4 : 1.0
#       contains(terrific) = True             true : false  =      2.3 : 1.0
#          contains(cycle) = True            false : true   =      2.3 : 1.0
#          contains(drive) = True             true : false  =      2.3 : 1.0
#        contains(offense) = True             true : false  =      2.3 : 1.0
#          contains(looks) = True             true : false  =      2.3 : 1.0
#          contains(wrist) = True            false : true   =      2.3 : 1.0
#              contains(/) = True             true : false  =      2.3 : 1.0
#           contains(then) = True             true : false  =      2.3 : 1.0
#          contains(check) = True            false : true   =      2.3 : 1.0
#     contains(considered) = True             true : false  =      2.3 : 1.0
#           contains(move) = True             true : false  =      2.3 : 1.0
#           contains(pace) = True             true : false  =      2.3 : 1.0
#           contains(calm) = True             true : false  =      2.3 : 1.0
#             contains(by) = True            false : true   =      2.3 : 1.0
#          contains(moves) = True            false : true   =      2.3 : 1.0
#             contains(17) = True             true : false  =      2.3 : 1.0
#         contains(outlet) = True             true : false  =      2.3 : 1.0
#          contains(touch) = True            false : true   =      2.3 : 1.0
#      contains(developed) = True             true : false  =      2.3 : 1.0
#      contains(displayed) = True             true : false  =      2.3 : 1.0
#          contains(areas) = True             true : false  =      2.3 : 1.0
#           contains(role) = True             true : false  =      2.3 : 1.0
#       contains(projects) = True            false : true   =      2.3 : 1.0
#           contains(away) = True            false : true   =      2.3 : 1.0
#         contains(injury) = True             true : false  =      2.3 : 1.0
#       contains(presence) = True             true : false  =      2.3 : 1.0
#           contains(area) = True             true : false  =      2.3 : 1.0
#        contains(quickly) = True             true : false  =      2.3 : 1.0
#           contains(lack) = True             true : false  =      2.3 : 1.0
#         contains(wheels) = True             true : false  =      2.3 : 1.0
#          contains(light) = True             true : false  =      2.3 : 1.0
#            contains(six) = True             true : false  =      2.3 : 1.0
#         contains(passes) = True            false : true   =      2.3 : 1.0
#          contains(great) = True             true : false  =      2.3 : 1.0
#           contains(more) = True             true : false  =      2.2 : 1.0
#          contains(going) = True            false : true   =      2.2 : 1.0
#       contains(mobility) = True            false : true   =      2.2 : 1.0
#             contains(go) = True             true : false  =      2.2 : 1.0
#           contains(edge) = True             true : false  =      2.2 : 1.0
#     contains(transition) = True            false : true   =      2.2 : 1.0
#            contains(are) = True             true : false  =      2.2 : 1.0
#       contains(accurate) = True             true : false  =      2.2 : 1.0
#           contains(just) = True             true : false  =      2.2 : 1.0
#         contains(decent) = True            false : true   =      2.2 : 1.0
#         contains(really) = True             true : false  =      2.2 : 1.0
#        contains(because) = True             true : false  =      2.1 : 1.0
#           contains(hard) = True             true : false  =      2.1 : 1.0
#           contains(this) = True             true : false  =      2.1 : 1.0
#          contains(plays) = True             true : false  =      2.1 : 1.0
#          contains(quick) = True             true : false  =      2.1 : 1.0
#           contains(shot) = True             true : false  =      2.0 : 1.0
#            contains(him) = True             true : false  =      1.9 : 1.0
#           contains(that) = True             true : false  =      1.9 : 1.0
#              contains(t) = True             true : false  =      1.9 : 1.0
#              contains(') = True             true : false  =      1.9 : 1.0
#            contains(end) = True             true : false  =      1.9 : 1.0
#           contains(term) = True            false : true   =      1.9 : 1.0
#            contains(not) = True             true : false  =      1.9 : 1.0
#        contains(forward) = True             true : false  =      1.9 : 1.0
#            contains(one) = True             true : false  =      1.9 : 1.0
#           contains(into) = True             true : false  =      1.9 : 1.0
#             contains(it) = True            false : true   =      1.9 : 1.0
#            contains(bit) = True             true : false  =      1.9 : 1.0
#             contains(or) = True            false : true   =      1.9 : 1.0
#           contains(soft) = True             true : false  =      1.9 : 1.0
#          contains(heavy) = True             true : false  =      1.9 : 1.0
#         contains(winger) = True            false : true   =      1.8 : 1.0
#   contains(acceleration) = True            false : true   =      1.8 : 1.0
#      contains(improving) = True            false : true   =      1.8 : 1.0
#    contains(forechecker) = True             true : false  =      1.8 : 1.0
#            contains(you) = True             true : false  =      1.8 : 1.0
#      contains(abilities) = True            false : true   =      1.8 : 1.0
#          contains(could) = True             true : false  =      1.8 : 1.0
#       contains(eligible) = True             true : false  =      1.8 : 1.0
#         contains(little) = True             true : false  =      1.8 : 1.0
#           contains(come) = True             true : false  =      1.8 : 1.0
#            contains(far) = True            false : true   =      1.8 : 1.0
#       contains(continue) = True            false : true   =      1.8 : 1.0
#        contains(skilled) = True             true : false  =      1.8 : 1.0
#          contains(under) = True             true : false  =      1.8 : 1.0
#         contains(roster) = True             true : false  =      1.8 : 1.0
#          contains(pucks) = True             true : false  =      1.8 : 1.0
#        contains(passing) = True             true : false  =      1.8 : 1.0
#          contains(point) = True             true : false  =      1.8 : 1.0
#            contains(get) = True             true : false  =      1.8 : 1.0
#              contains(a) = False           false : true   =      1.7 : 1.0
#         contains(vision) = True             true : false  =      1.7 : 1.0
#           contains(with) = False           false : true   =      1.7 : 1.0
#             contains(be) = True             true : false  =      1.7 : 1.0
#            contains(eye) = True             true : false  =      1.7 : 1.0
#     contains(possession) = True             true : false  =      1.7 : 1.0
#     contains(situations) = True             true : false  =      1.7 : 1.0
#           contains(what) = True             true : false  =      1.7 : 1.0
#           contains(over) = True             true : false  =      1.7 : 1.0
#       contains(handling) = True             true : false  =      1.7 : 1.0
#          contains(style) = True             true : false  =      1.7 : 1.0
#    contains(physicality) = True             true : false  =      1.7 : 1.0
#           contains(type) = True             true : false  =      1.7 : 1.0
#          contains(close) = True            false : true   =      1.7 : 1.0
#     contains(goaltender) = True            false : true   =      1.7 : 1.0
#           contains(many) = True             true : false  =      1.7 : 1.0
#           contains(year) = True             true : false  =      1.7 : 1.0
#       contains(starting) = True            false : true   =      1.7 : 1.0
#        contains(carries) = True             true : false  =      1.7 : 1.0
#        contains(carrier) = True             true : false  =      1.7 : 1.0
#          contains(wants) = True            false : true   =      1.7 : 1.0
#        contains(growing) = True            false : true   =      1.7 : 1.0
#            contains(200) = True             true : false  =      1.7 : 1.0
#         contains(second) = True            false : true   =      1.7 : 1.0
#           contains(half) = True             true : false  =      1.7 : 1.0
#       contains(movement) = True            false : true   =      1.7 : 1.0
#           contains(high) = True             true : false  =      1.7 : 1.0
#          contains(level) = True            false : true   =      1.7 : 1.0
#         contains(rising) = True             true : false  =      1.7 : 1.0
#           contains(room) = True             true : false  =      1.7 : 1.0
#           contains(gets) = True             true : false  =      1.7 : 1.0
#           contains(fast) = True             true : false  =      1.7 : 1.0
#        contains(quicker) = True             true : false  =      1.7 : 1.0
#          contains(other) = True             true : false  =      1.7 : 1.0
#      contains(advantage) = True             true : false  =      1.7 : 1.0
#      contains(selection) = True            false : true   =      1.7 : 1.0
#          contains(three) = True             true : false  =      1.7 : 1.0
#       contains(prospect) = True             true : false  =      1.7 : 1.0
#         contains(higher) = True             true : false  =      1.7 : 1.0
#          contains(ready) = True            false : true   =      1.7 : 1.0
#           contains(once) = True            false : true   =      1.7 : 1.0
#           contains(give) = True             true : false  =      1.7 : 1.0
#          contains(short) = True            false : true   =      1.7 : 1.0
#          contains(learn) = True            false : true   =      1.7 : 1.0
#             contains(an) = True             true : false  =      1.7 : 1.0
#      contains(generator) = True             true : false  =      1.7 : 1.0
#        contains(handles) = True             true : false  =      1.7 : 1.0
#        contains(without) = True             true : false  =      1.7 : 1.0
#          contains(about) = True             true : false  =      1.7 : 1.0
#          contains(asked) = True            false : true   =      1.7 : 1.0
#           contains(lead) = True            false : true   =      1.7 : 1.0
#           contains(grit) = True            false : true   =      1.7 : 1.0
#          contains(small) = True             true : false  =      1.7 : 1.0
#            contains(son) = True            false : true   =      1.7 : 1.0
#           contains(hits) = True             true : false  =      1.7 : 1.0
#         contains(pretty) = True             true : false  =      1.7 : 1.0
#        contains(battles) = True            false : true   =      1.7 : 1.0
#        contains(against) = True            false : true   =      1.7 : 1.0
#       contains(possible) = True             true : false  =      1.7 : 1.0
#          contains(think) = True            false : true   =      1.7 : 1.0
#           contains(goal) = True             true : false  =      1.7 : 1.0
#         contains(import) = True            false : true   =      1.7 : 1.0
#       contains(question) = True             true : false  =      1.7 : 1.0
#           contains(step) = True            false : true   =      1.7 : 1.0
#       contains(footwork) = True             true : false  =      1.7 : 1.0
#        contains(strides) = True            false : true   =      1.7 : 1.0
#             contains(20) = True             true : false  =      1.7 : 1.0
#           contains(side) = True             true : false  =      1.7 : 1.0
#           contains(left) = True             true : false  =      1.7 : 1.0
#           contains(cool) = True            false : true   =      1.7 : 1.0
#         contains(phases) = True            false : true   =      1.7 : 1.0
#            contains(hit) = True            false : true   =      1.7 : 1.0
#   contains(positionally) = True            false : true   =      1.7 : 1.0
#         contains(framed) = True            false : true   =      1.7 : 1.0
#            contains(way) = True             true : false  =      1.7 : 1.0
#              contains(-) = False           false : true   =      1.7 : 1.0
#           contains(team) = True             true : false  =      1.6 : 1.0
#             contains(if) = True            false : true   =      1.6 : 1.0
#         contains(passer) = True             true : false  =      1.6 : 1.0
#           contains(also) = True            false : true   =      1.6 : 1.0
#            contains(man) = True             true : false  =      1.6 : 1.0
#        contains(control) = True            false : true   =      1.6 : 1.0
#           contains(zone) = True             true : false  =      1.5 : 1.0
#          contains(there) = True             true : false  =      1.5 : 1.0
#        contains(balance) = True             true : false  =      1.5 : 1.0
#           contains(play) = True             true : false  =      1.5 : 1.0
#           contains(well) = True             true : false  =      1.5 : 1.0
#            contains(two) = True             true : false  =      1.5 : 1.0
#              contains(-) = True             true : false  =      1.5 : 1.0
#             contains(on) = True             true : false  =      1.5 : 1.0
#            contains(set) = True             true : false  =      1.4 : 1.0
#            contains(own) = True            false : true   =      1.4 : 1.0
#        contains(project) = True             true : false  =      1.4 : 1.0
#           contains(pass) = True            false : true   =      1.4 : 1.0
#         contains(around) = True             true : false  =      1.4 : 1.0
#           contains(nice) = True             true : false  =      1.4 : 1.0
#       contains(physical) = True             true : false  =      1.4 : 1.0
#           contains(wall) = True             true : false  =      1.4 : 1.0
#              contains(’) = True             true : false  =      1.4 : 1.0
#            contains(all) = True             true : false  =      1.4 : 1.0
#             contains(to) = False            true : false  =      1.4 : 1.0
#         contains(talent) = True             true : false  =      1.4 : 1.0
#        contains(working) = True            false : true   =      1.4 : 1.0
#          contains(power) = True             true : false  =      1.4 : 1.0
#         contains(bigger) = True            false : true   =      1.4 : 1.0
#        contains(corners) = True            false : true   =      1.4 : 1.0
#           contains(sees) = True             true : false  =      1.4 : 1.0
#        contains(players) = True             true : false  =      1.4 : 1.0
#             contains(no) = True            false : true   =      1.4 : 1.0
#             contains(so) = True            false : true   =      1.4 : 1.0
#      contains(potential) = True            false : true   =      1.4 : 1.0
#           contains(jump) = True            false : true   =      1.4 : 1.0
#       contains(learning) = True            false : true   =      1.4 : 1.0
#          contains(smart) = True             true : false  =      1.4 : 1.0
#             contains(on) = False           false : true   =      1.4 : 1.0
#          contains(frame) = True            false : true   =      1.4 : 1.0
#           contains(pick) = True             true : false  =      1.4 : 1.0
#         contains(enough) = True             true : false  =      1.4 : 1.0
#           contains(foot) = True             true : false  =      1.4 : 1.0
#      contains(instincts) = True             true : false  =      1.4 : 1.0
#           contains(ends) = True             true : false  =      1.4 : 1.0
#           contains(them) = True            false : true   =      1.4 : 1.0
#         contains(always) = True             true : false  =      1.4 : 1.0
#           contains(four) = True            false : true   =      1.4 : 1.0
#        contains(defense) = True             true : false  =      1.4 : 1.0
#          contains(being) = True             true : false  =      1.4 : 1.0
#          contains(reads) = True             true : false  =      1.4 : 1.0
#      contains(confident) = True            false : true   =      1.4 : 1.0
#        contains(improve) = True             true : false  =      1.4 : 1.0
#         contains(active) = True            false : true   =      1.4 : 1.0
#          contains(where) = True             true : false  =      1.4 : 1.0
#        contains(chances) = True            false : true   =      1.4 : 1.0
#          contains(makes) = True            false : true   =      1.4 : 1.0
#       contains(pressure) = True            false : true   =      1.4 : 1.0
#            contains(due) = True             true : false  =      1.4 : 1.0
#         contains(skates) = True             true : false  =      1.4 : 1.0
#      contains(offensive) = True            false : true   =      1.4 : 1.0
#          contains(skill) = True             true : false  =      1.4 : 1.0
#           contains(make) = True             true : false  =      1.4 : 1.0
#           contains(work) = True            false : true   =      1.4 : 1.0
#            contains(can) = True             true : false  =      1.3 : 1.0
#           contains(will) = False           false : true   =      1.3 : 1.0
#           contains(shot) = False           false : true   =      1.3 : 1.0
#             contains(an) = False           false : true   =      1.3 : 1.0
#            contains(ice) = True             true : false  =      1.3 : 1.0
#           contains(long) = True            false : true   =      1.3 : 1.0
#           contains(time) = True             true : false  =      1.3 : 1.0
#           contains(from) = True             true : false  =      1.3 : 1.0
#           contains(when) = True            false : true   =      1.3 : 1.0
#              contains(,) = False            true : false  =      1.3 : 1.0
#           contains(with) = True             true : false  =      1.3 : 1.0
#         contains(strong) = True            false : true   =      1.3 : 1.0
#           contains(have) = False           false : true   =      1.3 : 1.0
#        contains(develop) = True            false : true   =      1.3 : 1.0
#           contains(much) = True             true : false  =      1.3 : 1.0
#      contains(quickness) = True            false : true   =      1.3 : 1.0
#           contains(uses) = True             true : false  =      1.3 : 1.0
#            contains(low) = True            false : true   =      1.3 : 1.0
#        contains(playing) = True            false : true   =      1.3 : 1.0
#           contains(line) = True             true : false  =      1.3 : 1.0
#          contains(zones) = True            false : true   =      1.3 : 1.0
#        contains(scoring) = True             true : false  =      1.3 : 1.0
#           contains(born) = True             true : false  =      1.3 : 1.0
#         contains(moving) = True            false : true   =      1.3 : 1.0
#          contains(still) = True             true : false  =      1.3 : 1.0
#          contains(teams) = True            false : true   =      1.3 : 1.0
#            contains(him) = False           false : true   =      1.3 : 1.0
#           contains(that) = False           false : true   =      1.3 : 1.0
#          contains(first) = True             true : false  =      1.3 : 1.0
#      contains(defensive) = True            false : true   =      1.3 : 1.0
#             contains(be) = False           false : true   =      1.3 : 1.0
#           contains(good) = False           false : true   =      1.2 : 1.0
#        contains(ability) = True             true : false  =      1.2 : 1.0
#           contains(well) = False           false : true   =      1.2 : 1.0
#          contains(quick) = False           false : true   =      1.2 : 1.0
#            contains(for) = True             true : false  =      1.2 : 1.0
#            contains(out) = True            false : true   =      1.2 : 1.0
#      contains(defenders) = True             true : false  =      1.2 : 1.0
#            contains(top) = True             true : false  =      1.2 : 1.0
#       contains(stronger) = True            false : true   =      1.2 : 1.0
#         contains(centre) = True             true : false  =      1.2 : 1.0
#            contains(guy) = True             true : false  =      1.2 : 1.0
#         contains(hockey) = True             true : false  =      1.2 : 1.0
#         contains(upside) = True            false : true   =      1.2 : 1.0
#           contains(more) = False           false : true   =      1.2 : 1.0
#        contains(skating) = True             true : false  =      1.2 : 1.0
#          contains(hands) = False           false : true   =      1.2 : 1.0
#           contains(good) = True             true : false  =      1.2 : 1.0
#         contains(player) = True             true : false  =      1.2 : 1.0
#       contains(defender) = True            false : true   =      1.2 : 1.0
#        contains(release) = False           false : true   =      1.2 : 1.0
#          contains(plays) = False           false : true   =      1.2 : 1.0
#           contains(some) = True            false : true   =      1.2 : 1.0
#         contains(attack) = True             true : false  =      1.2 : 1.0
#           contains(back) = True             true : false  =      1.2 : 1.0
#           contains(down) = True            false : true   =      1.2 : 1.0
#         contains(strong) = False            true : false  =      1.2 : 1.0
#         contains(scorer) = False           false : true   =      1.2 : 1.0
#           contains(puck) = True             true : false  =      1.2 : 1.0
#              contains(') = False           false : true   =      1.2 : 1.0
#              contains(t) = False           false : true   =      1.2 : 1.0
#           contains(wing) = True            false : true   =      1.2 : 1.0
#            contains(off) = True             true : false  =      1.2 : 1.0
#           contains(this) = False           false : true   =      1.2 : 1.0
#         contains(passes) = False            true : false  =      1.1 : 1.0
#          contains(great) = False           false : true   =      1.1 : 1.0
#             contains(is) = False           false : true   =      1.1 : 1.0
#           contains(very) = False           false : true   =      1.1 : 1.0
#        contains(agility) = False           false : true   =      1.1 : 1.0
#            contains(has) = True            false : true   =      1.1 : 1.0
#             contains(he) = False           false : true   =      1.1 : 1.0
#         contains(season) = False           false : true   =      1.1 : 1.0
#       contains(attacker) = False           false : true   =      1.1 : 1.0
#          contains(solid) = False           false : true   =      1.1 : 1.0
#          contains(front) = False           false : true   =      1.1 : 1.0
#     contains(developing) = False            true : false  =      1.1 : 1.0
#            contains(way) = False           false : true   =      1.1 : 1.0
#             contains(in) = False            true : false  =      1.1 : 1.0
#             contains(of) = True            false : true   =      1.1 : 1.0
#          contains(point) = False           false : true   =      1.1 : 1.0
#            contains(get) = False           false : true   =      1.1 : 1.0
#            contains(end) = False           false : true   =      1.1 : 1.0
#             contains(of) = False            true : false  =      1.1 : 1.0
#           contains(hard) = False           false : true   =      1.1 : 1.0
#      contains(excellent) = True             true : false  =      1.1 : 1.0
#            contains(may) = True             true : false  =      1.1 : 1.0
#          contains(needs) = True            false : true   =      1.1 : 1.0
#         contains(skills) = True            false : true   =      1.1 : 1.0
#       contains(strength) = False           false : true   =      1.1 : 1.0
#     contains(defenseman) = False           false : true   =      1.1 : 1.0
#              contains(s) = False           false : true   =      1.1 : 1.0
#          contains(draft) = False           false : true   =      1.1 : 1.0
#           contains(game) = True            false : true   =      1.1 : 1.0
#            contains(has) = False            true : false  =      1.1 : 1.0
#             contains(he) = True             true : false  =      1.1 : 1.0
#            contains(can) = False           false : true   =      1.1 : 1.0
#        contains(himself) = False            true : false  =      1.1 : 1.0
#           contains(open) = False           false : true   =      1.1 : 1.0
#          contains(tools) = False            true : false  =      1.1 : 1.0
#             contains(18) = False           false : true   =      1.1 : 1.0
#      contains(decisions) = False           false : true   =      1.1 : 1.0
#      contains(offensive) = False            true : false  =      1.1 : 1.0
#             contains(is) = True             true : false  =      1.1 : 1.0
#            contains(all) = False           false : true   =      1.1 : 1.0
#             contains(to) = True            false : true   =      1.1 : 1.0
#            contains(two) = False           false : true   =      1.1 : 1.0
#           contains(puck) = False           false : true   =      1.1 : 1.0
#           contains(play) = False           false : true   =      1.1 : 1.0
#           contains(team) = False           false : true   =      1.1 : 1.0
#              contains(a) = True             true : false  =      1.1 : 1.0
#         contains(vision) = False           false : true   =      1.1 : 1.0
#          contains(speed) = True             true : false  =      1.1 : 1.0
#            contains(not) = False           false : true   =      1.1 : 1.0
#            contains(one) = False           false : true   =      1.1 : 1.0
#           contains(term) = False            true : false  =      1.1 : 1.0
#           contains(into) = False           false : true   =      1.1 : 1.0
#        contains(forward) = False           false : true   =      1.1 : 1.0
#         contains(player) = False           false : true   =      1.1 : 1.0
#        contains(because) = False           false : true   =      1.1 : 1.0
#            contains(was) = False           false : true   =      1.1 : 1.0
#          contains(doesn) = False           false : true   =      1.1 : 1.0
#          contains(seems) = False           false : true   =      1.1 : 1.0
#            contains(net) = False           false : true   =      1.1 : 1.0
#         contains(things) = False            true : false  =      1.1 : 1.0
#       contains(progress) = False            true : false  =      1.1 : 1.0
#           contains(take) = False            true : false  =      1.1 : 1.0
#           contains(even) = False           false : true   =      1.1 : 1.0
#             contains(at) = True             true : false  =      1.1 : 1.0
#            contains(for) = False           false : true   =      1.1 : 1.0
#            contains(put) = False            true : false  =      1.1 : 1.0
#          contains(gives) = False           false : true   =      1.1 : 1.0
#        contains(through) = False           false : true   =      1.1 : 1.0
#        contains(options) = False           false : true   =      1.1 : 1.0
#          contains(until) = False           false : true   =      1.1 : 1.0
#           contains(most) = False           false : true   =      1.1 : 1.0
#       contains(surprise) = False           false : true   =      1.1 : 1.0
#       contains(decision) = False           false : true   =      1.1 : 1.0
#         contains(making) = False           false : true   =      1.1 : 1.0
#          contains(whose) = False           false : true   =      1.1 : 1.0
#            contains(but) = False            true : false  =      1.1 : 1.0
#            contains(but) = True            false : true   =      1.1 : 1.0
#           contains(size) = True            false : true   =      1.1 : 1.0
#            contains(ice) = False           false : true   =      1.1 : 1.0
#           contains(make) = False           false : true   =      1.1 : 1.0
#           contains(work) = False            true : false  =      1.1 : 1.0
#             contains(up) = True            false : true   =      1.1 : 1.0
#        contains(balance) = False           false : true   =      1.1 : 1.0
#          contains(there) = False           false : true   =      1.1 : 1.0
#           contains(zone) = False           false : true   =      1.1 : 1.0
#           contains(high) = False           false : true   =      1.1 : 1.0
#       contains(prospect) = False           false : true   =      1.1 : 1.0
#           contains(year) = False           false : true   =      1.1 : 1.0
#             contains(it) = False            true : false  =      1.1 : 1.0
#            contains(bit) = False           false : true   =      1.1 : 1.0
#             contains(or) = False            true : false  =      1.1 : 1.0
#           contains(soft) = False           false : true   =      1.1 : 1.0
#          contains(heavy) = False           false : true   =      1.1 : 1.0
#             contains(go) = False           false : true   =      1.1 : 1.0
#         contains(really) = False           false : true   =      1.1 : 1.0
#     contains(transition) = False            true : false  =      1.1 : 1.0
#       contains(mobility) = False            true : false  =      1.1 : 1.0
#            contains(are) = False           false : true   =      1.1 : 1.0
#           contains(edge) = False           false : true   =      1.1 : 1.0
#       contains(accurate) = False           false : true   =      1.1 : 1.0
#         contains(decent) = False            true : false  =      1.1 : 1.0
#           contains(just) = False           false : true   =      1.1 : 1.0
#          contains(going) = False            true : false  =      1.1 : 1.0
#         contains(smarts) = False           false : true   =      1.1 : 1.0
#    contains(development) = False            true : false  =      1.1 : 1.0
#            contains(yet) = False            true : false  =      1.1 : 1.0
#            contains(use) = False            true : false  =      1.1 : 1.0
#           contains(must) = False            true : false  =      1.1 : 1.0
#        contains(willing) = False           false : true   =      1.1 : 1.0
#        contains(already) = False            true : false  =      1.1 : 1.0
#       contains(although) = False            true : false  =      1.1 : 1.0
#          contains(works) = False           false : true   =      1.1 : 1.0
#         contains(handle) = False           false : true   =      1.1 : 1.0
#      contains(forecheck) = False           false : true   =      1.1 : 1.0
#         contains(league) = False           false : true   =      1.1 : 1.0
#     contains(aggressive) = False           false : true   =      1.1 : 1.0
#       contains(position) = False            true : false  =      1.1 : 1.0
#           contains(like) = False           false : true   =      1.1 : 1.0
#      contains(attackers) = False            true : false  =      1.1 : 1.0
#          contains(would) = False           false : true   =      1.1 : 1.0
#           contains(game) = False            true : false  =      1.1 : 1.0
#          contains(space) = False           false : true   =      1.1 : 1.0
#  contains(opportunities) = False           false : true   =      1.1 : 1.0
#           contains(gaps) = False            true : false  =      1.1 : 1.0
#    contains(consistency) = False            true : false  =      1.1 : 1.0
#         contains(checks) = False           false : true   =      1.1 : 1.0
#        contains(leading) = False           false : true   =      1.1 : 1.0
#           contains(real) = False           false : true   =      1.1 : 1.0
#      contains(linemates) = False           false : true   =      1.1 : 1.0
#      contains(effective) = False           false : true   =      1.1 : 1.0
#        contains(contact) = False           false : true   =      1.1 : 1.0
#       contains(selected) = False           false : true   =      1.1 : 1.0
#       contains(playoffs) = False           false : true   =      1.1 : 1.0
#            contains(see) = False           false : true   =      1.1 : 1.0
#       contains(demeanor) = False           false : true   =      1.1 : 1.0
#       contains(develops) = False           false : true   =      1.1 : 1.0
#          contains(every) = False           false : true   =      1.1 : 1.0
#            contains(let) = False            true : false  =      1.1 : 1.0
#            contains(pro) = False           false : true   =      1.1 : 1.0
#        contains(toolbox) = False            true : false  =      1.1 : 1.0
#              contains(() = False           false : true   =      1.1 : 1.0
#          contains(score) = False           false : true   =      1.1 : 1.0
#          contains(girth) = False           false : true   =      1.1 : 1.0
#       contains(coverage) = False           false : true   =      1.1 : 1.0
#         contains(crease) = False           false : true   =      1.1 : 1.0
#             contains(in) = True            false : true   =      1.1 : 1.0
#             contains(as) = True            false : true   =      1.1 : 1.0
#            contains(who) = False            true : false  =      1.1 : 1.0
#       contains(defender) = False            true : false  =      1.1 : 1.0
#        contains(skating) = False           false : true   =      1.1 : 1.0
#        contains(ability) = False           false : true   =      1.0 : 1.0
#          contains(first) = False           false : true   =      1.0 : 1.0
#      contains(defensive) = False            true : false  =      1.0 : 1.0
#           contains(long) = False            true : false  =      1.0 : 1.0
#           contains(time) = False           false : true   =      1.0 : 1.0
#           contains(when) = False            true : false  =      1.0 : 1.0
#              contains(,) = True            false : true   =      1.0 : 1.0
#           contains(from) = False           false : true   =      1.0 : 1.0
#          contains(skill) = False           false : true   =      1.0 : 1.0
#           contains(wall) = False           false : true   =      1.0 : 1.0
#            contains(set) = False           false : true   =      1.0 : 1.0
#        contains(project) = False           false : true   =      1.0 : 1.0
#         contains(around) = False           false : true   =      1.0 : 1.0
#              contains(’) = False           false : true   =      1.0 : 1.0
#           contains(pass) = False            true : false  =      1.0 : 1.0
#           contains(nice) = False           false : true   =      1.0 : 1.0
#            contains(own) = False            true : false  =      1.0 : 1.0
#       contains(physical) = False           false : true   =      1.0 : 1.0
#            contains(man) = False           false : true   =      1.0 : 1.0
#        contains(control) = False            true : false  =      1.0 : 1.0
#             contains(if) = False            true : false  =      1.0 : 1.0
#         contains(passer) = False           false : true   =      1.0 : 1.0
#           contains(also) = False            true : false  =      1.0 : 1.0
#         contains(winger) = False            true : false  =      1.0 : 1.0
#      contains(abilities) = False            true : false  =      1.0 : 1.0
#           contains(come) = False           false : true   =      1.0 : 1.0
#   contains(acceleration) = False            true : false  =      1.0 : 1.0
#      contains(improving) = False            true : false  =      1.0 : 1.0
#       contains(continue) = False            true : false  =      1.0 : 1.0
#    contains(forechecker) = False           false : true   =      1.0 : 1.0
#        contains(skilled) = False           false : true   =      1.0 : 1.0
#            contains(you) = False           false : true   =      1.0 : 1.0
#          contains(could) = False           false : true   =      1.0 : 1.0
#       contains(eligible) = False           false : true   =      1.0 : 1.0
#          contains(under) = False           false : true   =      1.0 : 1.0
#         contains(little) = False           false : true   =      1.0 : 1.0
#            contains(far) = False            true : false  =      1.0 : 1.0
#          contains(pucks) = False           false : true   =      1.0 : 1.0
#        contains(passing) = False           false : true   =      1.0 : 1.0
#         contains(roster) = False           false : true   =      1.0 : 1.0
#          contains(looks) = False           false : true   =      1.0 : 1.0
#          contains(wrist) = False            true : false  =      1.0 : 1.0
#           contains(then) = False           false : true   =      1.0 : 1.0
#          contains(check) = False            true : false  =      1.0 : 1.0
#     contains(considered) = False           false : true   =      1.0 : 1.0
#           contains(move) = False           false : true   =      1.0 : 1.0
#       contains(terrific) = False           false : true   =      1.0 : 1.0
#             contains(by) = False            true : false  =      1.0 : 1.0
#          contains(moves) = False            true : false  =      1.0 : 1.0
#          contains(cycle) = False            true : false  =      1.0 : 1.0
#          contains(drive) = False           false : true   =      1.0 : 1.0
#      contains(developed) = False           false : true   =      1.0 : 1.0
#          contains(areas) = False           false : true   =      1.0 : 1.0
#              contains(/) = False           false : true   =      1.0 : 1.0
#           contains(pace) = False           false : true   =      1.0 : 1.0
#           contains(calm) = False           false : true   =      1.0 : 1.0
#             contains(17) = False           false : true   =      1.0 : 1.0
#       contains(presence) = False           false : true   =      1.0 : 1.0
#         contains(outlet) = False           false : true   =      1.0 : 1.0
#          contains(touch) = False            true : false  =      1.0 : 1.0
#           contains(area) = False           false : true   =      1.0 : 1.0
#        contains(quickly) = False           false : true   =      1.0 : 1.0
#      contains(displayed) = False           false : true   =      1.0 : 1.0
#           contains(lack) = False           false : true   =      1.0 : 1.0
#           contains(role) = False           false : true   =      1.0 : 1.0
#       contains(projects) = False            true : false  =      1.0 : 1.0
#           contains(away) = False            true : false  =      1.0 : 1.0
#          contains(light) = False           false : true   =      1.0 : 1.0
#            contains(six) = False           false : true   =      1.0 : 1.0
#         contains(injury) = False           false : true   =      1.0 : 1.0
#        contains(offense) = False           false : true   =      1.0 : 1.0
#         contains(wheels) = False           false : true   =      1.0 : 1.0
#          contains(board) = False           false : true   =      1.0 : 1.0
#           contains(only) = False           false : true   =      1.0 : 1.0
#         contains(edging) = False           false : true   =      1.0 : 1.0
#        contains(veteran) = False            true : false  =      1.0 : 1.0
#              contains()) = False           false : true   =      1.0 : 1.0
#      contains(laterally) = False           false : true   =      1.0 : 1.0
#          contains(maybe) = False           false : true   =      1.0 : 1.0
#    contains(willingness) = False           false : true   =      1.0 : 1.0
#       contains(generate) = False           false : true   =      1.0 : 1.0
#          contains(panic) = False           false : true   =      1.0 : 1.0
#             contains(do) = False           false : true   =      1.0 : 1.0
#            contains(win) = False           false : true   =      1.0 : 1.0
#        contains(stretch) = False            true : false  =      1.0 : 1.0
#              contains(;) = False           false : true   =      1.0 : 1.0
#          contains(takes) = False            true : false  =      1.0 : 1.0
#          contains(catch) = False            true : false  =      1.0 : 1.0
#        contains(average) = False           false : true   =      1.0 : 1.0
#          contains(sense) = False            true : false  =      1.0 : 1.0
#          contains(break) = False            true : false  =      1.0 : 1.0
#            contains(run) = False           false : true   =      1.0 : 1.0
#           contains(keep) = False           false : true   =      1.0 : 1.0
#          contains(named) = False            true : false  =      1.0 : 1.0
#         contains(showed) = False           false : true   =      1.0 : 1.0
#        contains(wrister) = False            true : false  =      1.0 : 1.0
#           contains(went) = False           false : true   =      1.0 : 1.0
#      contains(rearguard) = False            true : false  =      1.0 : 1.0
#          contains(reach) = False           false : true   =      1.0 : 1.0
#      contains(teammates) = False           false : true   =      1.0 : 1.0
#         contains(before) = False           false : true   =      1.0 : 1.0
#       contains(fearless) = False            true : false  =      1.0 : 1.0
#       contains(powerful) = False            true : false  =      1.0 : 1.0
#        contains(overall) = False           false : true   =      1.0 : 1.0
#        contains(remains) = False            true : false  =      1.0 : 1.0
#      contains(difficult) = False           false : true   =      1.0 : 1.0
#           contains(lots) = False           false : true   =      1.0 : 1.0
#          contains(goals) = False           false : true   =      1.0 : 1.0
#        contains(further) = False           false : true   =      1.0 : 1.0
#         contains(totals) = False           false : true   =      1.0 : 1.0
#        contains(rounded) = False           false : true   =      1.0 : 1.0
#           contains(2013) = False           false : true   =      1.0 : 1.0
#           contains(hand) = False           false : true   =      1.0 : 1.0
#            contains(led) = False           false : true   =      1.0 : 1.0
#           contains(easy) = False            true : false  =      1.0 : 1.0
#            contains(new) = False           false : true   =      1.0 : 1.0
#           contains(free) = False           false : true   =      1.0 : 1.0
#       contains(teammate) = False           false : true   =      1.0 : 1.0
#         contains(needed) = False           false : true   =      1.0 : 1.0
#         contains(energy) = False            true : false  =      1.0 : 1.0
#           contains(rush) = False           false : true   =      1.0 : 1.0
#          contains(gears) = False           false : true   =      1.0 : 1.0
#           contains(push) = False            true : false  =      1.0 : 1.0
#    contains(improvement) = False           false : true   =      1.0 : 1.0
#       contains(carrying) = False           false : true   =      1.0 : 1.0
#        contains(looking) = False            true : false  =      1.0 : 1.0
#          contains(throw) = False            true : false  =      1.0 : 1.0
#           contains(took) = False           false : true   =      1.0 : 1.0
#         contains(allows) = False           false : true   =      1.0 : 1.0
#           contains(home) = False           false : true   =      1.0 : 1.0
#         contains(chance) = False            true : false  =      1.0 : 1.0
#      contains(prospects) = False           false : true   =      1.0 : 1.0
#          contains(sound) = False           false : true   =      1.0 : 1.0
#     contains(competitor) = False           false : true   =      1.0 : 1.0
#         contains(worker) = False           false : true   =      1.0 : 1.0
#         contains(coming) = False           false : true   =      1.0 : 1.0
#       contains(dominant) = False           false : true   =      1.0 : 1.0
#      contains(lightning) = False           false : true   =      1.0 : 1.0
#         contains(impact) = False           false : true   =      1.0 : 1.0
#        contains(seasons) = False            true : false  =      1.0 : 1.0
#         contains(middle) = False           false : true   =      1.0 : 1.0
#    contains(elusiveness) = False            true : false  =      1.0 : 1.0
#         contains(dangle) = False           false : true   =      1.0 : 1.0
#            contains(don) = False            true : false  =      1.0 : 1.0
#            contains(how) = False           false : true   =      1.0 : 1.0
#           contains(read) = False           false : true   =      1.0 : 1.0
#           contains(road) = False           false : true   =      1.0 : 1.0
#     contains(attributes) = False            true : false  =      1.0 : 1.0
#           contains(best) = False            true : false  =      1.0 : 1.0
#            contains(old) = False           false : true   =      1.0 : 1.0
#         contains(played) = False            true : false  =      1.0 : 1.0
#          contains(thick) = False           false : true   =      1.0 : 1.0
#           contains(shut) = False            true : false  =      1.0 : 1.0
#    contains(significant) = False           false : true   =      1.0 : 1.0
#     contains(undersized) = False           false : true   =      1.0 : 1.0
#             contains(as) = False            true : false  =      1.0 : 1.0
#            contains(who) = True            false : true   =      1.0 : 1.0
#             contains(up) = False            true : false  =      1.0 : 1.0
# ...
#        contains(besides) = False           false : true   =      1.0 : 1.0
#           contains(puts) = False            true : false  =      1.0 : 1.0
#          contains(tight) = False            true : false  =      1.0 : 1.0
#         contains(option) = False            true : false  =      1.0 : 1.0
#        contains(thought) = False           false : true   =      1.0 : 1.0
#           contains(made) = False            true : false  =      1.0 : 1.0
#        contains(smaller) = False           false : true   =      1.0 : 1.0
#          contains(tempo) = False           false : true   =      1.0 : 1.0
#          contains(paint) = False            true : false  =      1.0 : 1.0
#           contains(name) = False            true : false  =      1.0 : 1.0
#        contains(drafted) = False           false : true   =      1.0 : 1.0
#         contains(muscle) = False            true : false  =      1.0 : 1.0
#         contains(center) = False           false : true   =      1.0 : 1.0
#         contains(overly) = False           false : true   =      1.0 : 1.0
#              contains(5) = False            true : false  =      1.0 : 1.0
#       contains(creative) = False            true : false  =      1.0 : 1.0
#          contains(pivot) = False            true : false  =      1.0 : 1.0
#         contains(entire) = False            true : false  =      1.0 : 1.0
#       contains(dominate) = False           false : true   =      1.0 : 1.0
#     contains(bloodlines) = False            true : false  =      1.0 : 1.0
#         contains(mobile) = False           false : true   =      1.0 : 1.0
#       contains(shutdown) = False            true : false  =      1.0 : 1.0
#          contains(glove) = False            true : false  =      1.0 : 1.0
#           contains(help) = False           false : true   =      1.0 : 1.0
#         contains(growth) = False            true : false  =      1.0 : 1.0
#          contains(right) = False            true : false  =      1.0 : 1.0
#          contains(knock) = False            true : false  =      1.0 : 1.0
#       contains(advanced) = False            true : false  =      1.0 : 1.0
#           contains(hope) = False           false : true   =      1.0 : 1.0
#            contains(lot) = False           false : true   =      1.0 : 1.0
#       contains(complete) = False           false : true   =      1.0 : 1.0
#         contains(expect) = False           false : true   =      1.0 : 1.0
#         contains(smooth) = False            true : false  =      1.0 : 1.0
#    contains(positioning) = False            true : false  =      1.0 : 1.0
#           contains(pads) = False           false : true   =      1.0 : 1.0
#          contains(dirty) = False            true : false  =      1.0 : 1.0
#          contains(shift) = False           false : true   =      1.0 : 1.0
#           contains(2012) = False           false : true   =      1.0 : 1.0
#    contains(nonetheless) = False            true : false  =      1.0 : 1.0
#           contains(didn) = False           false : true   =      1.0 : 1.0
#       contains(finished) = False            true : false  =      1.0 : 1.0
#        contains(thicker) = False           false : true   =      1.0 : 1.0
#        contains(clearly) = False           false : true   =      1.0 : 1.0
#           contains(head) = False            true : false  =      1.0 : 1.0
#       contains(opposing) = False           false : true   =      1.0 : 1.0
#        contains(despite) = False           false : true   =      1.0 : 1.0
#       contains(shooting) = False            true : false  =      1.0 : 1.0
#              contains(?) = False           false : true   =      1.0 : 1.0
#         contains(matter) = False           false : true   =      1.0 : 1.0
#        contains(provide) = False            true : false  =      1.0 : 1.0
#        contains(attacks) = False            true : false  =      1.0 : 1.0
#          contains(knows) = False           false : true   =      1.0 : 1.0
#           contains(wins) = False            true : false  =      1.0 : 1.0
#      contains(including) = False           false : true   =      1.0 : 1.0
#        contains(usually) = False           false : true   =      1.0 : 1.0
#          contains(motor) = False           false : true   =      1.0 : 1.0
#    contains(responsible) = False           false : true   =      1.0 : 1.0
#          contains(lists) = False            true : false  =      1.0 : 1.0
#         contains(battle) = False           false : true   =      1.0 : 1.0
#       contains(homeland) = False            true : false  =      1.0 : 1.0
#       contains(polished) = False            true : false  =      1.0 : 1.0
#         contains(future) = False           false : true   =      1.0 : 1.0
#          contains(lanky) = False            true : false  =      1.0 : 1.0
#           contains(spot) = False           false : true   =      1.0 : 1.0
#         contains(former) = False            true : false  =      1.0 : 1.0
#         contains(ladder) = False            true : false  =      1.0 : 1.0
#   contains(consistently) = False           false : true   =      1.0 : 1.0
#           contains(sets) = False           false : true   =      1.0 : 1.0
#              contains(d) = False           false : true   =      1.0 : 1.0
#        contains(shooter) = False           false : true   =      1.0 : 1.0
#             contains(16) = False           false : true   =      1.0 : 1.0
#           contains(last) = False           false : true   =      1.0 : 1.0
#        contains(strider) = False           false : true   =      1.0 : 1.0
#         contains(leader) = False           false : true   =      1.0 : 1.0
#     contains(commitment) = False           false : true   =      1.0 : 1.0
#     contains(impressive) = False           false : true   =      1.0 : 1.0
#          contains(comes) = False            true : false  =      1.0 : 1.0
#         contains(scouts) = False           false : true   =      1.0 : 1.0
#     contains(determined) = False           false : true   =      1.0 : 1.0
#        contains(dynamic) = False           false : true   =      1.0 : 1.0
#         contains(pivots) = False           false : true   =      1.0 : 1.0
#        contains(biscuit) = False           false : true   =      1.0 : 1.0
#    contains(distributes) = False            true : false  =      1.0 : 1.0
#     contains(intriguing) = False            true : false  =      1.0 : 1.0
#           contains(fall) = False           false : true   =      1.0 : 1.0
#          contains(nasty) = False            true : false  =      1.0 : 1.0
#      contains(necessary) = False           false : true   =      1.0 : 1.0
#            contains(ago) = False            true : false  =      1.0 : 1.0
#          contains(tough) = False           false : true   =      1.0 : 1.0
#         contains(weight) = False           false : true   =      1.0 : 1.0
#    contains(competitive) = False            true : false  =      1.0 : 1.0
#  contains(opportunistic) = False            true : false  =      1.0 : 1.0
#           contains(slot) = False            true : false  =      1.0 : 1.0
#           contains(fill) = False            true : false  =      1.0 : 1.0
#          contains(rough) = False           false : true   =      1.0 : 1.0
#        contains(brother) = False           false : true   =      1.0 : 1.0
#           contains(look) = False            true : false  =      1.0 : 1.0
#    contains(effectively) = False           false : true   =      1.0 : 1.0
#           contains(goes) = False            true : false  =      1.0 : 1.0
#        contains(getting) = False           false : true   =      1.0 : 1.0
#             contains(60) = False            true : false  =      1.0 : 1.0
#         contains(hitter) = False           false : true   =      1.0 : 1.0
#          contains(times) = False            true : false  =      1.0 : 1.0
#         contains(mature) = False            true : false  =      1.0 : 1.0
#            contains(kid) = False           false : true   =      1.0 : 1.0
#           contains(slow) = False            true : false  =      1.0 : 1.0
#          contains(loves) = False            true : false  =      1.0 : 1.0
#          contains(bring) = False           false : true   =      1.0 : 1.0
#         contains(effort) = False            true : false  =      1.0 : 1.0
#          contains(stays) = False           false : true   =      1.0 : 1.0
#          contains(enemy) = False           false : true   =      1.0 : 1.0
#           contains(such) = False           false : true   =      1.0 : 1.0
#         contains(starts) = False            true : false  =      1.0 : 1.0
#     contains(production) = False           false : true   =      1.0 : 1.0
#          contains(build) = False           false : true   =      1.0 : 1.0
#        contains(sleeper) = False            true : false  =      1.0 : 1.0
#          contains(after) = False            true : false  =      1.0 : 1.0
#         contains(sniper) = False            true : false  =      1.0 : 1.0
#          contains(start) = False           false : true   =      1.0 : 1.0
#         contains(bottom) = False           false : true   =      1.0 : 1.0
#          contains(ahead) = False           false : true   =      1.0 : 1.0
#          contains(maker) = False           false : true   =      1.0 : 1.0
#      contains(awareness) = False           false : true   =      1.0 : 1.0
#           contains(safe) = False           false : true   =      1.0 : 1.0
#           contains(club) = False            true : false  =      1.0 : 1.0
#       contains(elevated) = False           false : true   =      1.0 : 1.0
#       contains(unafraid) = False            true : false  =      1.0 : 1.0
#            contains(leg) = False            true : false  =      1.0 : 1.0
#           contains(camp) = False           false : true   =      1.0 : 1.0
#        contains(example) = False            true : false  =      1.0 : 1.0
#   contains(anticipation) = False           false : true   =      1.0 : 1.0
#         contains(behind) = False           false : true   =      1.0 : 1.0
#     contains(separation) = False            true : false  =      1.0 : 1.0
#         contains(larger) = False            true : false  =      1.0 : 1.0
#         contains(happen) = False            true : false  =      1.0 : 1.0
#         contains(cannot) = False           false : true   =      1.0 : 1.0
#           contains(gain) = False           false : true   =      1.0 : 1.0
#    contains(offensively) = False            true : false  =      1.0 : 1.0
#        contains(product) = False            true : false  =      1.0 : 1.0
#         contains(flight) = False           false : true   =      1.0 : 1.0
#           contains(true) = False           false : true   =      1.0 : 1.0
#     contains(relentless) = False           false : true   =      1.0 : 1.0
#         contains(reacts) = False           false : true   =      1.0 : 1.0
#         contains(midget) = False           false : true   =      1.0 : 1.0
#            contains(raw) = False            true : false  =      1.0 : 1.0
#         contains(finish) = False           false : true   =      1.0 : 1.0
#         contains(status) = False           false : true   =      1.0 : 1.0
#        contains(playoff) = False           false : true   =      1.0 : 1.0
#    contains(exceptional) = False           false : true   =      1.0 : 1.0
#         contains(member) = False            true : false  =      1.0 : 1.0
#           contains(upon) = False           false : true   =      1.0 : 1.0
#           contains(full) = False            true : false  =      1.0 : 1.0
#          contains(edges) = False           false : true   =      1.0 : 1.0
#     contains(regularity) = False            true : false  =      1.0 : 1.0
#        contains(stature) = False            true : false  =      1.0 : 1.0
#              contains(6) = False            true : false  =      1.0 : 1.0
#     contains(aggression) = False            true : false  =      1.0 : 1.0
#              contains(") = False           false : true   =      1.0 : 1.0
#          contains(large) = False            true : false  =      1.0 : 1.0
#         contains(footer) = False           false : true   =      1.0 : 1.0
#       contains(combined) = False           false : true   =      1.0 : 1.0
#  contains(consideration) = False            true : false  =      1.0 : 1.0
#          contains(ethic) = False            true : false  =      1.0 : 1.0
#         contains(causes) = False            true : false  =      1.0 : 1.0
#          contains(again) = False           false : true   =      1.0 : 1.0
#          contains(using) = False            true : false  =      1.0 : 1.0
#           contains(huge) = False            true : false  =      1.0 : 1.0
#       contains(juncture) = False            true : false  =      1.0 : 1.0
#        contains(reading) = False            true : false  =      1.0 : 1.0
#         contains(easily) = False           false : true   =      1.0 : 1.0
#         contains(engage) = False           false : true   =      1.0 : 1.0
#         contains(poised) = False            true : false  =      1.0 : 1.0
#         contains(called) = False            true : false  =      1.0 : 1.0
#           contains(post) = False           false : true   =      1.0 : 1.0
#        contains(minutes) = False            true : false  =      1.0 : 1.0
#           contains(hone) = False            true : false  =      1.0 : 1.0
#       contains(backline) = False           false : true   =      1.0 : 1.0
#      contains(opponents) = False           false : true   =      1.0 : 1.0
#        contains(outside) = False            true : false  =      1.0 : 1.0
#           contains(drop) = False            true : false  =      1.0 : 1.0
#          contains(elite) = False            true : false  =      1.0 : 1.0
#    contains(defensively) = False            true : false  =      1.0 : 1.0
#           contains(load) = False           false : true   =      1.0 : 1.0
#          contains(watch) = False            true : false  =      1.0 : 1.0
#        contains(rounder) = False            true : false  =      1.0 : 1.0
#         contains(speedy) = False           false : true   =      1.0 : 1.0
#       contains(rebounds) = False           false : true   =      1.0 : 1.0
#          contains(lower) = False           false : true   =      1.0 : 1.0
#      contains(playmaker) = False           false : true   =      1.0 : 1.0
#          contains(major) = False           false : true   =      1.0 : 1.0
#      contains(attacking) = False           false : true   =      1.0 : 1.0
#            contains(fly) = False           false : true   =      1.0 : 1.0
#           contains(lets) = False           false : true   =      1.0 : 1.0
#         contains(handed) = False           false : true   =      1.0 : 1.0
#           contains(stay) = False            true : false  =      1.0 : 1.0
#    contains(instinctive) = False           false : true   =      1.0 : 1.0
#         contains(height) = False           false : true   =      1.0 : 1.0
#     contains(experience) = False            true : false  =      1.0 : 1.0
#      contains(intensity) = False            true : false  =      1.0 : 1.0
#           contains(legs) = False            true : false  =      1.0 : 1.0
#           contains(tall) = False           false : true   =      1.0 : 1.0
#           contains(part) = False           false : true   =      1.0 : 1.0
#          contains(agile) = False            true : false  =      1.0 : 1.0
#        contains(prowess) = False           false : true   =      1.0 : 1.0
#          contains(allow) = False            true : false  =      1.0 : 1.0
#           contains(turn) = False           false : true   =      1.0 : 1.0
#          contains(later) = False           false : true   =      1.0 : 1.0
#         contains(almost) = False            true : false  =      1.0 : 1.0
#          contains(sheet) = False            true : false  =      1.0 : 1.0
#        contains(keeping) = False           false : true   =      1.0 : 1.0
#         contains(simple) = False           false : true   =      1.0 : 1.0
#             contains(we) = False           false : true   =      1.0 : 1.0
#           contains(blue) = False            true : false  =      1.0 : 1.0

# %% [markdown]
# # ==========Filtering Words NHL==========

# %%
from nltk.corpus import stopwords
import pickle
import re

# %%
# Filter stop words
# Convert to lower case for case insensitive matching
# Remove punctuation
stop_words = set(stopwords.words('english'))

documents_filtered = [([re.sub(r'\W+','',w.lower()) for  w in nhl.words(fileid) if w.lower() not in stop_words],category)
                      for category in nhl.categories()
                      for fileid in nhl.fileids(category)]

# %%
words_filtered = nltk.FreqDist(re.sub(r'\W+','',w.lower()) for w in nhl.words() if w.lower() not in stop_words)
words_filtered.most_common(1000)
# Out:
# [('', 9279),
#  ('good', 780),
#  ('puck', 567),
#  ('strong', 455),
#  ('game', 400),
#  ('player', 391),
#  ('plays', 331),
#  ('well', 301),
#  ('offensive', 297),
#  ('play', 295),
#  ('big', 279),
#  ('excellent', 257),
#  ('shot', 248),
#  ('needs', 240),
#  ('size', 235),
#  ('get', 224),
#  ('speed', 219),
#  ('team', 215),
#  ('zone', 207),
#  ('ice', 201),
#  ('skills', 201),
#  ('quick', 198),
#  ('work', 194),
#  ('defensive', 190),
#  ('long', 186),
#  ('feet', 182),
#  ('one', 181),
#  ('hands', 180),
#  ('skating', 178),
#  ('defender', 176),
#  ('junior', 176),
#  ('ability', 175),
#  ('may', 171),
#  ('high', 171),
#  ('end', 164),
#  ('displays', 162),
#  ('great', 161),
#  ('wing', 157),
#  ('attack', 157),
#  ('stick', 152),
#  ('hard', 147),
#  ('world', 147),
#  ('prospect', 146),
#  ('way', 139),
#  ('top', 135),
#  ('two', 133),
#  ('solid', 131),
#  ('point', 131),
#  ('first', 130),
#  ('time', 130),
#  ('term', 129),
#  ('vision', 128),
#  ('upside', 128),
#  ('strength', 121),
#  ('power', 120),
#  ('make', 119),
#  ('wall', 119),
#  ('man', 118),
#  ('nhl', 117),
#  ('year', 116),
#  ('scoring', 115),
#  ('like', 114),
#  ('centre', 114),
#  ('roster', 113),
#  ('around', 112),
#  ('hockey', 112),
#  ('still', 112),
#  ('forward', 112),
#  ('skill', 106),
#  ('makes', 104),
#  ('skater', 104),
#  ('defenseman', 103),
#  ('already', 101),
#  ('set', 96),
#  ('gets', 95),
#  ('committed', 94),
#  ('guy', 93),
#  ('physical', 92),
#  ('stride', 92),
#  ('bigger', 91),
#  ('front', 90),
#  ('balance', 89),
#  ('18', 89),
#  ('draft', 89),
#  ('areas', 88),
#  ('back', 87),
#  ('project', 85),
#  ('foot', 85),
#  ('need', 84),
#  ('soft', 84),
#  ('shows', 84),
#  ('passes', 84),
#  ('much', 83),
#  ('smart', 83),
#  ('improve', 82),
#  ('uses', 81),
#  ('tournament', 81),
#  ('pass', 81),
#  ('also', 81),
#  ('passer', 81),
#  ('stronger', 80),
#  ('level', 80),
#  ('really', 80),
#  ('scorer', 78),
#  ('go', 78),
#  ('net', 78),
#  ('quickness', 77),
#  ('winger', 76),
#  ('playing', 74),
#  ('bit', 74),
#  ('university', 74),
#  ('selected', 74),
#  ('season', 74),
#  ('line', 74),
#  ('better', 73),
#  ('nice', 73),
#  ('abilities', 72),
#  ('pro', 72),
#  ('control', 71),
#  ('open', 71),
#  ('pp', 70),
#  ('release', 70),
#  ('defenders', 69),
#  ('lateral', 69),
#  ('due', 69),
#  ('many', 68),
#  ('teams', 68),
#  ('might', 68),
#  ('mobility', 66),
#  ('even', 66),
#  ('agility', 65),
#  ('developing', 65),
#  ('jump', 65),
#  ('players', 65),
#  ('going', 64),
#  ('pucks', 64),
#  ('three', 64),
#  ('seems', 63),
#  ('far', 63),
#  ('six', 63),
#  ('passing', 63),
#  ('april', 62),
#  ('reads', 62),
#  ('along', 62),
#  ('skates', 61),
#  ('projects', 61),
#  ('heavy', 61),
#  ('body', 61),
#  ('transition', 60),
#  ('north', 60),
#  ('chances', 60),
#  ('whose', 60),
#  ('undersized', 60),
#  ('best', 59),
#  ('develop', 59),
#  ('things', 58),
#  ('aggressive', 58),
#  ('developmental', 56),
#  ('able', 56),
#  ('decent', 55),
#  ('handling', 55),
#  ('center', 55),
#  ('low', 55),
#  ('moves', 55),
#  ('side', 54),
#  ('always', 54),
#  ('early', 54),
#  ('take', 53),
#  ('zones', 52),
#  ('attackers', 51),
#  ('use', 51),
#  ('battles', 51),
#  ('style', 51),
#  ('battle', 50),
#  ('position', 50),
#  ('see', 50),
#  ('defense', 50),
#  ('continue', 48),
#  ('shown', 48),
#  ('enough', 48),
#  ('never', 47),
#  ('reach', 47),
#  ('development', 47),
#  ('making', 47),
#  ('frame', 47),
#  ('could', 47),
#  ('takes', 46),
#  ('second', 46),
#  ('instincts', 46),
#  ('eligible', 45),
#  ('improving', 45),
#  ('iq', 45),
#  ('average', 45),
#  ('opposition', 45),
#  ('tough', 45),
#  ('plenty', 45),
#  ('progress', 44),
#  ('room', 44),
#  ('moving', 44),
#  ('elite', 44),
#  ('little', 44),
#  ('come', 43),
#  ('terrific', 43),
#  ('20', 43),
#  ('games', 43),
#  ('goals', 43),
#  ('away', 42),
#  ('physicality', 42),
#  ('quickly', 42),
#  ('willing', 42),
#  ('league', 41),
#  ('skilled', 41),
#  ('stay', 41),
#  ('u', 41),
#  ('acceleration', 41),
#  ('look', 41),
#  ('working', 40),
#  ('edge', 40),
#  ('getting', 40),
#  ('teammates', 40),
#  ('looks', 40),
#  ('smaller', 40),
#  ('right', 40),
#  ('traffic', 40),
#  ('smarts', 40),
#  ('touch', 40),
#  ('attacker', 39),
#  ('phases', 39),
#  ('huge', 39),
#  ('area', 39),
#  ('although', 39),
#  ('possesses', 39),
#  ('space', 38),
#  ('close', 38),
#  ('last', 37),
#  ('goal', 37),
#  ('shift', 37),
#  ('handles', 37),
#  ('despite', 37),
#  ('difficult', 36),
#  ('potential', 36),
#  ('fearless', 36),
#  ('round', 36),
#  ('defensively', 35),
#  ('shots', 35),
#  ('effective', 35),
#  ('carrier', 35),
#  ('situations', 35),
#  ('decisions', 35),
#  ('four', 34),
#  ('calm', 34),
#  ('balanced', 34),
#  ('christmas', 34),
#  ('would', 34),
#  ('accurate', 34),
#  ('played', 33),
#  ('stop', 33),
#  ('commitment', 33),
#  ('lots', 33),
#  ('points', 33),
#  ('must', 32),
#  ('move', 32),
#  ('juncture', 32),
#  ('fast', 32),
#  ('member', 32),
#  ('2014', 32),
#  ('sees', 32),
#  ('class', 32),
#  ('improvement', 31),
#  ('presence', 31),
#  ('win', 31),
#  ('powerful', 31),
#  ('pressure', 31),
#  ('weight', 31),
#  ('tremendous', 31),
#  ('physically', 31),
#  ('south', 31),
#  ('hits', 30),
#  ('outlet', 30),
#  ('sense', 30),
#  ('goes', 30),
#  ('forecheck', 30),
#  ('tall', 30),
#  ('russian', 30),
#  ('homeland', 30),
#  ('swedish', 30),
#  ('muscle', 30),
#  ('checks', 30),
#  ('step', 30),
#  ('tools', 30),
#  ('tourney', 30),
#  ('carrying', 29),
#  ('born', 29),
#  ('grit', 29),
#  ('fact', 29),
#  ('handle', 29),
#  ('add', 29),
#  ('another', 29),
#  ('forechecker', 29),
#  ('score', 28),
#  ('home', 28),
#  ('become', 28),
#  ('decision', 28),
#  ('200', 28),
#  ('prospects', 28),
#  ('compete', 28),
#  ('ends', 28),
#  ('possession', 28),
#  ('biscuit', 28),
#  ('wrist', 28),
#  ('improved', 28),
#  ('show', 28),
#  ('named', 27),
#  ('based', 27),
#  ('willingness', 27),
#  ('find', 27),
#  ('gears', 27),
#  ('agile', 27),
#  ('opponents', 27),
#  ('pick', 27),
#  ('help', 27),
#  ('feel', 27),
#  ('every', 27),
#  ('grow', 27),
#  ('give', 27),
#  ('ready', 27),
#  ('active', 26),
#  ('positioning', 26),
#  ('son', 26),
#  ('lack', 26),
#  ('prowess', 26),
#  ('fill', 26),
#  ('offense', 26),
#  ('goalie', 26),
#  ('crease', 26),
#  ('linemates', 26),
#  ('mobile', 25),
#  ('carry', 25),
#  ('left', 25),
#  ('works', 25),
#  ('selection', 25),
#  ('pace', 25),
#  ('college', 25),
#  ('shooter', 25),
#  ('exceptional', 24),
#  ('name', 24),
#  ('american', 24),
#  ('ohl', 24),
#  ('movement', 24),
#  ('gear', 24),
#  ('using', 24),
#  ('import', 24),
#  ('keeps', 24),
#  ('minnesota', 24),
#  ('scored', 24),
#  ('penalty', 24),
#  ('third', 24),
#  ('part', 24),
#  ('rush', 24),
#  ('lot', 24),
#  ('wide', 24),
#  ('former', 23),
#  ('responsible', 23),
#  ('head', 23),
#  ('growing', 23),
#  ('laterally', 23),
#  ('let', 23),
#  ('face', 23),
#  ('small', 23),
#  ('higher', 23),
#  ('present', 23),
#  ('playmaking', 23),
#  ('put', 23),
#  ('minutes', 23),
#  ('build', 23),
#  ('rising', 23),
#  ('continues', 23),
#  ('whether', 23),
#  ('showing', 23),
#  ('showed', 23),
#  ('drive', 23),
#  ('large', 22),
#  ('usa', 22),
#  ('ivan', 22),
#  ('pk', 22),
#  ('advantage', 22),
#  ('creates', 22),
#  ('competition', 22),
#  ('short', 22),
#  ('glove', 22),
#  ('wins', 22),
#  ('possible', 22),
#  ('competitor', 22),
#  ('challenge', 22),
#  ('thick', 22),
#  ('generator', 22),
#  ('carries', 22),
#  ('smooth', 22),
#  ('years', 22),
#  ('question', 22),
#  ('pretty', 22),
#  ('break', 21),
#  ('corners', 21),
#  ('talent', 21),
#  ('impact', 21),
#  ('terms', 21),
#  ('gaps', 21),
#  ('shoot', 21),
#  ('tight', 21),
#  ('future', 21),
#  ('girth', 21),
#  ('gain', 21),
#  ('leg', 21),
#  ('dirty', 21),
#  ('understands', 21),
#  ('awareness', 21),
#  ('superb', 21),
#  ('yet', 21),
#  ('extremely', 21),
#  ('displayed', 21),
#  ('simply', 21),
#  ('leads', 21),
#  ('hlinka', 20),
#  ('full', 20),
#  ('longer', 20),
#  ('cycle', 20),
#  ('direction', 20),
#  ('intriguing', 20),
#  ('fluid', 20),
#  ('force', 20),
#  ('comes', 20),
#  ('wants', 20),
#  ('threat', 20),
#  ('handler', 20),
#  ('taking', 20),
#  ('since', 20),
#  ('raw', 20),
#  ('place', 20),
#  ('dominant', 20),
#  ('natural', 20),
#  ('think', 20),
#  ('less', 20),
#  ('though', 20),
#  ('injury', 20),
#  ('package', 20),
#  ('father', 20),
#  ('energy', 19),
#  ('finds', 19),
#  ('positionally', 19),
#  ('lets', 19),
#  ('finnish', 19),
#  ('made', 19),
#  ('positions', 19),
#  ('significant', 19),
#  ('role', 19),
#  ('toughness', 19),
#  ('polished', 19),
#  ('hit', 19),
#  ('without', 19),
#  ('creative', 19),
#  ('looking', 19),
#  ('lead', 19),
#  ('late', 19),
#  ('playmaker', 19),
#  ('czech', 19),
#  ('nasty', 19),
#  ('straight', 19),
#  ('quicker', 18),
#  ('road', 18),
#  ('contact', 18),
#  ('called', 18),
#  ('thin', 18),
#  ('clearly', 18),
#  ('new', 18),
#  ('learning', 18),
#  ('goaltender', 18),
#  ('overall', 18),
#  ('relentless', 18),
#  ('finished', 18),
#  ('matter', 18),
#  ('five', 17),
#  ('true', 17),
#  ('start', 17),
#  ('create', 17),
#  ('certainly', 17),
#  ('qmjhl', 17),
#  ('starting', 17),
#  ('starts', 17),
#  ('check', 17),
#  ('patient', 17),
#  ('loose', 17),
#  ('maybe', 17),
#  ('jam', 17),
#  ('board', 17),
#  ('michigan', 17),
#  ('success', 17),
#  ('seen', 17),
#  ('stand', 17),
#  ('drives', 17),
#  ('past', 17),
#  ('super', 17),
#  ('club', 17),
#  ('emerging', 17),
#  ('burst', 17),
#  ('nhler', 17),
#  ('lightning', 17),
#  ('drop', 17),
#  ('6', 17),
#  ('snarl', 17),
#  ('offensively', 17),
#  ('parts', 17),
#  ('sized', 17),
#  ('shoots', 17),
#  ('type', 17),
#  ('easily', 17),
#  ('simple', 16),
#  ('confident', 16),
#  ('gives', 16),
#  ('cause', 16),
#  ('ethic', 16),
#  ('wait', 16),
#  ('lanes', 16),
#  ('framed', 16),
#  ('beat', 16),
#  ('creativity', 16),
#  ('drafted', 16),
#  ('light', 16),
#  ('chance', 16),
#  ('outside', 16),
#  ('centreman', 16),
#  ('wheels', 16),
#  ('entire', 16),
#  ('knows', 16),
#  ('rookie', 16),
#  ('times', 16),
#  ('legs', 16),
#  ('consistency', 16),
#  ('tape', 16),
#  ('men', 16),
#  ('intensity', 16),
#  ('poise', 16),
#  ('dee', 15),
#  ('aggression', 15),
#  ('safe', 15),
#  ('sound', 15),
#  ('real', 15),
#  ('separation', 15),
#  ('developed', 15),
#  ('levels', 15),
#  ('hold', 15),
#  ('checker', 15),
#  ('patience', 15),
#  ('school', 15),
#  ('totals', 15),
#  ('17', 15),
#  ('lanky', 15),
#  ('coverage', 15),
#  ('2011', 15),
#  ('impressive', 15),
#  ('old', 15),
#  ('skate', 15),
#  ('boards', 15),
#  ('involved', 15),
#  ('status', 15),
#  ('young', 15),
#  ('demeanor', 15),
#  ('opportunistic', 15),
#  ('know', 15),
#  ('qb', 15),
#  ('easy', 15),
#  ('kid', 15),
#  ('nonetheless', 14),
#  ('gap', 14),
#  ('reliable', 14),
#  ('attacking', 14),
#  ('poised', 14),
#  ('athleticism', 14),
#  ('perimeter', 14),
#  ('limited', 14),
#  ('shutdown', 14),
#  ('almost', 14),
#  ('steps', 14),
#  ('canada', 14),
#  ('keep', 14),
#  ('lower', 14),
#  ('post', 14),
#  ('hand', 14),
#  ('eye', 14),
#  ('loves', 14),
#  ('engage', 14),
#  ('anticipation', 14),
#  ('closes', 14),
#  ('allows', 14),
#  ('stays', 14),
#  ('footwork', 14),
#  ('major', 14),
#  ('playoffs', 14),
#  ('besides', 14),
#  ('coming', 14),
#  ('forwards', 14),
#  ('rebounds', 14),
#  ('finisher', 14),
#  ('killer', 14),
#  ('ups', 14),
#  ('lacks', 14),
#  ('knock', 13),
#  ('next', 13),
#  ('sniper', 13),
#  ('turns', 13),
#  ('trouble', 13),
#  ('wisconsin', 13),
#  ('fine', 13),
#  ('effort', 13),
#  ('rebound', 13),
#  ('eventually', 13),
#  ('growth', 13),
#  ('consideration', 13),
#  ('punishing', 13),
#  ('worker', 13),
#  ('later', 13),
#  ('2013', 13),
#  ('shifty', 13),
#  ('seasons', 13),
#  ('athletic', 13),
#  ('boston', 13),
#  ('leader', 13),
#  ('push', 13),
#  ('goaler', 13),
#  ('problems', 13),
#  ('turnovers', 13),
#  ('product', 13),
#  ('whl', 13),
#  ('q', 13),
#  ('bodied', 13),
#  ('blue', 13),
#  ('edging', 13),
#  ('tempo', 13),
#  ('necessary', 13),
#  ('dub', 12),
#  ('highly', 12),
#  ('lines', 12),
#  ('receive', 12),
#  ('strides', 12),
#  ('sweden', 12),
#  ('throw', 12),
#  ('edges', 12),
#  ('seem', 12),
#  ('opposing', 12),
#  ('wrister', 12),
#  ('larger', 12),
#  ('technique', 12),
#  ('elusive', 12),
#  ('camp', 12),
#  ('continued', 12),
#  ('run', 12),
#  ('sets', 12),
#  ('radar', 12),
#  ('stickhandler', 12),
#  ('state', 12),
#  ('develops', 12),
#  ('asked', 12),
#  ('consistently', 12),
#  ('spaces', 12),
#  ('dominate', 12),
#  ('either', 12),
#  ('complete', 12),
#  ('considered', 12),
#  ('nations', 12),
#  ('opportunities', 12),
#  ('juniors', 12),
#  ('experience', 11),
#  ('sheet', 11),
#  ('bloodlines', 11),
#  ('upon', 11),
#  ('call', 11),
#  ('spots', 11),
#  ('bottom', 11),
#  ('catch', 11),
#  ('3rd', 11),
#  ('effectively', 11),
#  ('dangle', 11),
#  ('advance', 11),
#  ('footer', 11),
#  ('likes', 11),
#  ('fairly', 11),
#  ('learn', 11),
#  ('determined', 11),
#  ('fastest', 11),
#  ('winning', 11),
#  ('consistent', 11),
#  ('reflexes', 11),
#  ('finishes', 11),
#  ('stands', 11),
#  ('pursuit', 11),
#  ('read', 11),
#  ('attributes', 11),
#  ('deceptive', 11),
#  ('including', 11),
#  ('cool', 11),
#  ('coach', 11),
#  ('toolbox', 11),
#  ('elusiveness', 11),
#  ('base', 11),
#  ('gifted', 11),
#  ('free', 11),
#  ('watch', 11),
#  ('spot', 11),
#  ('stretch', 11),
#  ('pivot', 11),
#  ('added', 11),
#  ('provide', 11),
#  ('overly', 11),
#  ('outstanding', 11),
#  ('2012', 11),
#  ('dynamic', 11),
#  ('gritty', 11),
#  ('surprise', 11),
#  ('younger', 11),
#  ('western', 10),
#  ('mail', 10),
#  ('5', 10),
#  ('fall', 10),
#  ('veteran', 10),
#  ('turn', 10),
#  ('backline', 10),
#  ('handed', 10),
#  ('functional', 10),
#  ('enemy', 10),
#  ('sleeper', 10),
#  ('timer', 10),
#  ('hitter', 10),
#  ('rounder', 10),
#  ('speedy', 10),
#  ('behind', 10),
#  ('prototypical', 10),
#  ('height', 10),
#  ('shut', 10),
#  ('attacks', 10),
#  ('60', 10),
#  ('minute', 10),
#  ('confidence', 10),
#  ('scouts', 10),
#  ('native', 10),
#  ('intense', 10),
#  ('older', 10),
#  ('say', 10),
#  ('cannot', 10),
#  ('cut', 10),
#  ('em', 10),
#  ('rounds', 10),
#  ('dangerous', 10),
#  ('america', 10),
#  ('middle', 10),
#  ('swiss', 10),
#  ('deadly', 10),
#  ('remains', 10),
#  ('giant', 10),
#  ('reacts', 10),
#  ('understanding', 10),
#  ('display', 10),
#  ('number', 10),
#  ('distributes', 10),
#  ('contain', 10),
#  ('instinctive', 10),
#  ('snap', 10),
#  ('load', 10),
#  ('finish', 10),
#  ('sticks', 9),
#  ('unafraid', 9),
#  ('try', 9),
#  ('pivots', 9),
#  ('teammate', 9),
#  ('surprising', 9),
#  ('thought', 9),
#  ('competitive', 9),
#  ('lists', 9),
#  ('production', 9),
#  ('east', 9),
#  ('west', 9),
#  ('ladder', 9),
#  ('slick', 9),
#  ('strider', 9),
#  ('advanced', 9),
#  ('chl', 9),
#  ('notice', 9),
#  ('bring', 9),
#  ('slot', 9),
#  ('select', 9),
#  ('causes', 9),
#  ('generate', 9),
#  ('midget', 9),
#  ('qualities', 9),
#  ('sure', 9),
#  ('mark', 9),
#  ('leading', 9),
#  ('upward', 9),
#  ('options', 9),
#  ('inside', 9),
#  ('usually', 9),
#  ('sometimes', 9),
#  ('ahead', 9),
#  ('water', 9),
#  ('rough', 9),
#  ('corner', 9),
#  ('shooters', 9),
#  ('thicker', 9),
#  ('half', 9),
#  ('biggest', 9),
#  ('went', 9),
#  ('mature', 9),
#  ('example', 9),
#  ('actually', 9),
#  ('fly', 9),
#  ('ever', 9),
#  ('circle', 9),
#  ('maker', 9),
#  ('helps', 9),
#  ('regularity', 9),
#  ('pounds', 9),
#  ('panic', 9),
#  ('character', 9),
#  ('excels', 8),
#  ('option', 8),
#  ('slow', 8),
#  ('us', 8),
#  ('angles', 8),
#  ('hope', 8),
#  ('fits', 8),
#  ('expect', 8),
#  ('puts', 8),
#  ('regular', 8),
#  ('ago', 8),
#  ('probably', 8),
#  ('ushl', 8),
#  ('stature', 8),
#  ('rearguard', 8),
#  ('allow', 8),
#  ('shooting', 8),
#  ('12', 8),
#  ('training', 8),
#  ('key', 8),
#  ('playoff', 8),
#  ('paint', 8),
#  ('happen', 8),
#  ('hone', 8),
#  ('motor', 8),
#  ('mean', 8),
#  ('bad', 8),
#  ('pads', 8),
#  ('basically', 8),
#  ('reading', 8),
#  ('match', 8),
#  ('16', 8),
#  ('brother', 8),
#  ('job', 8),
#  ('took', 8),
#  ('blocks', 8),
#  ('jumps', 8),
#  ('50', 8),
#  ('lacking', 8),
#  ('within', 8),
#  ('fills', 8),
#  ('led', 8),
#  ('couple', 8),
#  ('combined', 8),
#  ('elevated', 8),
#  ('november', 8),
#  ('pairing', 8),
#  ('rounded', 8),
#  ('drafts', 8),
#  ('needed', 8),
#  ('deceptively', 8),
#  ('ten', 8),
#  ('saw', 8),
#  ('comfortable', 8),
#  ('edgy', 8),
#  ('finn', 8),
#  ('defensemen', 8),
#  ('capable', 8),
#  ('russia', 8),
#  ('cannon', 8),
#  ('keeping', 7),
#  ('flight', 7),
#  ('given', 7),
#  ('coordination', 7),
#  ('gifts', 7),
#  ('quietly', 7),
#  ('built', 7),
#  ('clear', 7),
#  ('hurt', 7),
#  ('nuances', 7),
#  ('especially', 7),
#  ('projected', 7),
#  ('extra', 7),
#  ('day', 7),
#  ('presently', 7),
#  ('care', 7),
#  ('thinks', 7),
#  ('skinny', 7),
#  ('fireplug', 7),
#  ('bulk', 7),
#  ('adjust', 7),
#  ('championship', 7),
#  ('kill', 7),
#  ('maintains', 7),
#  ('quebec', 7),
#  ('feisty', 7),
#  ('want', 7),
#  ('30', 7),
#  ('appears', 7),
#  ('positional', 7),
#  ('wonder', 7),
#  ('hopefully', 7),
#  ('legged', 7),
#  ('brings', 7),
#  ('attempt', 7),
#  ('weak', 7),
#  ('decide', 7),
#  ('injuries', 7),
#  ('afraid', 7),
#  ('nose', 7),
#  ('august', 7),
#  ('night', 7),
#  ('ways', 7),
#  ('picks', 7),
#  ('unselfish', 7),
#  ('competes', 7),
#  ('disciplined', 7),
#  ('performance', 7),
#  ('effortless', 7),
#  ('aware', 7),
#  ('versatile', 7),
#  ('started', 7),
#  ('promising', 7),
#  ('aggressively', 7),
#  ('opponent', 7),
#  ('aspects', 7),
#  ('fearlessly', 7),
#  ('others', 7),
#  ('climb', 7),
#  ('tougher', 7),
#  ('mover', 7),
#  ('age', 7),
#  ('motion', 7),
#  ('anyone', 7),
#  ('london', 7),
#  ('together', 7),
#  ('pins', 7),
#  ('special', 7),
#  ('distributor', 7),
#  ('lost', 7),
#  ('faster', 7),
#  ('pond', 7),
#  ('granted', 7),
#  ('completely', 7),
#  ('undrafted', 6),
#  ('clears', 6),
#  ('places', 6),
#  ('checking', 6),
#  ('quality', 6),
#  ('boots', 6),
#  ('defend', 6),
#  ('issue', 6),
#  ('footed', 6),
#  ('outlets', 6),
#  ('ratio', 6),
#  ('contributor', 6),
#  ('forechecking', 6),
#  ('stood', 6),
#  ('selecting', 6),
#  ('competitiveness', 6),
#  ('diagnoses', 6),
#  ('activate', 6),
#  ('increase', 6),
#  ('covers', 6),
#  ('polish', 6),
#  ('anywhere', 6),
#  ('mitts', 6),
#  ('composure', 6),
#  ('fluidity', 6),
#  ('general', 6),
#  ('slide', 6),
#  ('across', 6),
#  ('dot', 6),
#  ('stickhandling', 6),
#  ('taken', 6),
#  ('except', 6),
#  ('13', 6),
#  ('whole', 6),
#  ('grinder', 6),
#  ('problem', 6),
#  ('summer', 6),
#  ('scout', 6),
#  ('moment', 6),
#  ('guys', 6),
#  ('considerable', 6),
#  ('butterfly', 6),
#  ('viewed', 6),
#  ('republic', 6),
#  ('ones', 6)]

# %%
word_features = [w[0] for w in words_filtered.most_common(1000)]

def document_features(document):
    document_words = set(document)
    features = {}
    for word in word_features:
        features['contains({})'.format(word)] = word in document_words
    return features

# %%
random.shuffle(documents_filtered)
featuresets_filtered = [(document_features(d),c) for (d,c) in documents_filtered]
train_filtered,test_filtered = featuresets_filtered[818:],featuresets_filtered[:100]
classifier_filtered = nltk.NaiveBayesClassifier.train(train_filtered)
nltk.classify.accuracy(classifier_filtered,test_filtered)
# Out:
# 0.58

# %%
classifier_filtered.show_most_informative_features(100)
# Out:
# Most Informative Features
#            contains(get) = True             true : false  =      6.0 : 1.0
#           contains(high) = True             true : false  =      5.2 : 1.0
#          contains(shows) = True             true : false  =      5.2 : 1.0
#           contains(like) = True             true : false  =      4.7 : 1.0
#      contains(defenders) = True             true : false  =      4.7 : 1.0
#         contains(upside) = True             true : false  =      4.3 : 1.0
#           contains(much) = True             true : false  =      3.9 : 1.0
#           contains(jump) = True             true : false  =      3.9 : 1.0
#          contains(stick) = True             true : false  =      3.8 : 1.0
#          contains(hands) = True             true : false  =      3.8 : 1.0
#          contains(named) = True            false : true   =      3.8 : 1.0
#        contains(package) = True            false : true   =      3.8 : 1.0
#     contains(tremendous) = True            false : true   =      3.8 : 1.0
#        contains(western) = True            false : true   =      3.8 : 1.0
#            contains(nhl) = True             true : false  =      3.5 : 1.0
#           contains(back) = True             true : false  =      3.5 : 1.0
#        contains(release) = True             true : false  =      3.5 : 1.0
#          contains(first) = True             true : false  =      3.5 : 1.0
#            contains(due) = True             true : false  =      3.5 : 1.0
#         contains(skater) = True             true : false  =      3.3 : 1.0
#            contains(end) = True             true : false  =      3.3 : 1.0
#           contains(best) = True             true : false  =      3.1 : 1.0
#            contains(top) = True             true : false  =      3.1 : 1.0
#           contains(side) = True             true : false  =      3.1 : 1.0
#          contains(tough) = True            false : true   =      3.0 : 1.0
#            contains(ice) = True             true : false  =      2.9 : 1.0
#        contains(corners) = True            false : true   =      2.9 : 1.0
#        contains(smaller) = True            false : true   =      2.9 : 1.0
#          contains(pucks) = True            false : true   =      2.9 : 1.0
#          contains(cycle) = True            false : true   =      2.7 : 1.0
#    contains(physicality) = True            false : true   =      2.7 : 1.0
#      contains(versatile) = True            false : true   =      2.7 : 1.0
#            contains(dub) = True            false : true   =      2.7 : 1.0
#     contains(fearlessly) = True            false : true   =      2.7 : 1.0
#      contains(potential) = True            false : true   =      2.7 : 1.0
#      contains(improving) = True            false : true   =      2.7 : 1.0
#         contains(drives) = True            false : true   =      2.7 : 1.0
#       contains(anywhere) = True            false : true   =      2.7 : 1.0
#      contains(challenge) = True            false : true   =      2.7 : 1.0
#         contains(brings) = True            false : true   =      2.7 : 1.0
#         contains(canada) = True            false : true   =      2.7 : 1.0
#           contains(born) = True            false : true   =      2.7 : 1.0
#      contains(toughness) = True            false : true   =      2.7 : 1.0
#      contains(possesses) = True            false : true   =      2.7 : 1.0
#          contains(board) = True            false : true   =      2.7 : 1.0
#     contains(aggression) = True            false : true   =      2.7 : 1.0
#         contains(goalie) = True            false : true   =      2.7 : 1.0
#          contains(third) = True            false : true   =      2.7 : 1.0
#         contains(stride) = True             true : false  =      2.7 : 1.0
#       contains(selected) = True             true : false  =      2.7 : 1.0
#         contains(center) = True             true : false  =      2.7 : 1.0
#           contains(foot) = True             true : false  =      2.7 : 1.0
#           contains(pass) = True             true : false  =      2.7 : 1.0
#           contains(shot) = True             true : false  =      2.7 : 1.0
#       contains(physical) = True             true : false  =      2.7 : 1.0
#         contains(passes) = True             true : false  =      2.6 : 1.0
#          contains(great) = True             true : false  =      2.6 : 1.0
#        contains(scoring) = True             true : false  =      2.4 : 1.0
#            contains(guy) = True             true : false  =      2.4 : 1.0
#  contains(developmental) = True            false : true   =      2.3 : 1.0
#        contains(project) = True            false : true   =      2.3 : 1.0
#          contains(seems) = True             true : false  =      2.3 : 1.0
#        contains(develop) = True             true : false  =      2.3 : 1.0
#           contains(many) = True             true : false  =      2.3 : 1.0
#      contains(quickness) = True             true : false  =      2.3 : 1.0
#           contains(look) = True             true : false  =      2.3 : 1.0
#         contains(better) = True             true : false  =      2.3 : 1.0
#    contains(improvement) = True             true : false  =      2.3 : 1.0
#            contains(pro) = True             true : false  =      2.3 : 1.0
#          contains(april) = True             true : false  =      2.3 : 1.0
#           contains(soft) = True             true : false  =      2.3 : 1.0
#       contains(position) = True            false : true   =      2.3 : 1.0
#           contains(also) = True            false : true   =      2.3 : 1.0
#         contains(longer) = True            false : true   =      2.3 : 1.0
#         contains(outlet) = True            false : true   =      2.3 : 1.0
#    contains(development) = True            false : true   =      2.3 : 1.0
#          contains(teams) = True            false : true   =      2.3 : 1.0
#           contains(work) = True             true : false  =      2.2 : 1.0
#           contains(year) = True             true : false  =      2.1 : 1.0
#           contains(line) = True             true : false  =      2.1 : 1.0
#     contains(opposition) = True             true : false  =      2.1 : 1.0
#         contains(roster) = True             true : false  =      2.1 : 1.0
#        contains(chances) = True             true : false  =      2.1 : 1.0
#          contains(along) = True            false : true   =      2.1 : 1.0
#           contains(term) = True            false : true   =      2.0 : 1.0
#            contains(one) = True             true : false  =      2.0 : 1.0
#         contains(around) = True             true : false  =      2.0 : 1.0
#          contains(quick) = True             true : false  =      2.0 : 1.0
#           contains(size) = True            false : true   =      1.9 : 1.0
#           contains(wall) = True            false : true   =      1.9 : 1.0
#          contains(front) = True             true : false  =      1.9 : 1.0
#          contains(might) = True             true : false  =      1.9 : 1.0
#        contains(already) = True             true : false  =      1.9 : 1.0
#      contains(offensive) = True             true : false  =      1.9 : 1.0
#         contains(player) = True             true : false  =      1.9 : 1.0
#        contains(passing) = True             true : false  =      1.9 : 1.0
#           contains(head) = True             true : false  =      1.9 : 1.0
#          contains(looks) = True             true : false  =      1.9 : 1.0
#      contains(continues) = True             true : false  =      1.9 : 1.0
#   contains(acceleration) = True             true : false  =      1.9 : 1.0

# %%
# Overall most important features
nb_filtered = nltk.NaiveBayesClassifier.train(featuresets_filtered)
nb_filtered.show_most_informative_features(1000)
# Out:
# Most Informative Features
#        contains(juniors) = True             true : false  =      6.6 : 1.0
#        contains(without) = True             true : false  =      6.0 : 1.0
#        contains(dynamic) = True             true : false  =      6.0 : 1.0
#       contains(dominant) = True             true : false  =      5.7 : 1.0
#            contains(say) = True             true : false  =      5.5 : 1.0
#         contains(reacts) = True             true : false  =      5.5 : 1.0
#           contains(turn) = True             true : false  =      5.5 : 1.0
#         contains(finish) = True             true : false  =      5.5 : 1.0
#           contains(pace) = True             true : false  =      5.1 : 1.0
#          contains(panic) = True             true : false  =      4.9 : 1.0
#        contains(options) = True             true : false  =      4.9 : 1.0
#          contains(rough) = True             true : false  =      4.9 : 1.0
#     contains(defensemen) = True             true : false  =      4.3 : 1.0
#       contains(involved) = True             true : false  =      4.3 : 1.0
#      contains(linemates) = True             true : false  =      4.3 : 1.0
#         contains(corner) = True             true : false  =      4.3 : 1.0
#            contains(ten) = True             true : false  =      4.3 : 1.0
#             contains(12) = True             true : false  =      4.3 : 1.0
#         contains(sticks) = True             true : false  =      4.3 : 1.0
#       contains(elevated) = True             true : false  =      4.3 : 1.0
#         contains(needed) = True             true : false  =      4.3 : 1.0
#          contains(paint) = True             true : false  =      4.3 : 1.0
#       contains(republic) = True            false : true   =      4.3 : 1.0
#         contains(decide) = True            false : true   =      4.3 : 1.0
#       contains(fluidity) = True            false : true   =      4.3 : 1.0
#         contains(school) = True            false : true   =      4.1 : 1.0
#         contains(father) = True             true : false  =      4.1 : 1.0
#            contains(raw) = True            false : true   =      4.0 : 1.0
#      contains(necessary) = True             true : false  =      4.0 : 1.0
#           contains(2013) = True             true : false  =      4.0 : 1.0
#            contains(ups) = True             true : false  =      4.0 : 1.0
#          contains(space) = True             true : false  =      3.9 : 1.0
#           contains(lets) = True             true : false  =      3.8 : 1.0
#       contains(shutdown) = True            false : true   =      3.8 : 1.0
#        contains(aspects) = True             true : false  =      3.7 : 1.0
#           contains(pond) = True             true : false  =      3.7 : 1.0
#        contains(pairing) = True             true : false  =      3.7 : 1.0
#            contains(age) = True             true : false  =      3.7 : 1.0
#           contains(nose) = True             true : false  =      3.7 : 1.0
#          contains(aware) = True             true : false  =      3.7 : 1.0
#          contains(picks) = True             true : false  =      3.7 : 1.0
#        contains(attempt) = True             true : false  =      3.7 : 1.0
#          contains(night) = True             true : false  =      3.7 : 1.0
#     contains(completely) = True             true : false  =      3.7 : 1.0
#         contains(wonder) = True             true : false  =      3.7 : 1.0
#        contains(special) = True             true : false  =      3.7 : 1.0
#       contains(actually) = True             true : false  =      3.7 : 1.0
#        contains(tourney) = True             true : false  =      3.7 : 1.0
#           contains(keep) = True             true : false  =      3.6 : 1.0
#           contains(push) = True             true : false  =      3.6 : 1.0
#  contains(consideration) = True             true : false  =      3.6 : 1.0
#    contains(offensively) = True             true : false  =      3.6 : 1.0
#         contains(easily) = True             true : false  =      3.6 : 1.0
#          contains(nhler) = True             true : false  =      3.6 : 1.0
#     contains(goaltender) = True            false : true   =      3.5 : 1.0
#          contains(class) = True             true : false  =      3.4 : 1.0
#         contains(impact) = True             true : false  =      3.4 : 1.0
#       contains(dominate) = True             true : false  =      3.3 : 1.0
#       contains(surprise) = True             true : false  =      3.3 : 1.0
#    contains(outstanding) = True             true : false  =      3.3 : 1.0
#   contains(consistently) = True             true : false  =      3.3 : 1.0
#     contains(determined) = True             true : false  =      3.3 : 1.0
#        contains(younger) = True             true : false  =      3.3 : 1.0
#      contains(deceptive) = True             true : false  =      3.3 : 1.0
#          contains(extra) = True             true : false  =      3.2 : 1.0
#         contains(viewed) = True             true : false  =      3.2 : 1.0
#            contains(day) = True             true : false  =      3.2 : 1.0
#         contains(moment) = True             true : false  =      3.2 : 1.0
#         contains(clears) = True             true : false  =      3.2 : 1.0
#           contains(guys) = True             true : false  =      3.2 : 1.0
#        contains(appears) = True             true : false  =      3.2 : 1.0
#      contains(butterfly) = True             true : false  =      3.2 : 1.0
#          contains(stood) = True             true : false  =      3.2 : 1.0
#           contains(ones) = True             true : false  =      3.2 : 1.0
#        contains(granted) = True             true : false  =      3.2 : 1.0
#         contains(defend) = True             true : false  =      3.2 : 1.0
#      contains(wisconsin) = True            false : true   =      3.1 : 1.0
#  contains(opportunistic) = True             true : false  =      3.1 : 1.0
#          contains(young) = True             true : false  =      3.1 : 1.0
#          contains(using) = True             true : false  =      3.1 : 1.0
#       contains(accurate) = True             true : false  =      3.0 : 1.0
#         contains(scorer) = True             true : false  =      3.0 : 1.0
#       contains(straight) = True             true : false  =      3.0 : 1.0
#       contains(creative) = True             true : false  =      3.0 : 1.0
#           contains(many) = True             true : false  =      2.9 : 1.0
#          contains(older) = True             true : false  =      2.9 : 1.0
#           contains(spot) = True             true : false  =      2.9 : 1.0
#        contains(attacks) = True             true : false  =      2.9 : 1.0
#         contains(member) = True             true : false  =      2.9 : 1.0
#     contains(functional) = True             true : false  =      2.9 : 1.0
#           contains(load) = True             true : false  =      2.9 : 1.0
#    contains(responsible) = True             true : false  =      2.9 : 1.0
#          contains(shift) = True             true : false  =      2.9 : 1.0
#       contains(finisher) = True             true : false  =      2.8 : 1.0
#           contains(easy) = True             true : false  =      2.8 : 1.0
#        contains(stretch) = True            false : true   =      2.8 : 1.0
#             contains(20) = True             true : false  =      2.8 : 1.0
#           contains(must) = True            false : true   =      2.7 : 1.0
#          contains(small) = True             true : false  =      2.7 : 1.0
#        contains(getting) = True             true : false  =      2.7 : 1.0
#           contains(area) = True             true : false  =      2.7 : 1.0
#           contains(able) = True             true : false  =      2.7 : 1.0
#           contains(line) = True             true : false  =      2.6 : 1.0
#    contains(instinctive) = True             true : false  =      2.6 : 1.0
#        contains(america) = True             true : false  =      2.6 : 1.0
#        contains(thicker) = True             true : false  =      2.6 : 1.0
#            contains(cut) = True             true : false  =      2.6 : 1.0
#         contains(shoots) = True             true : false  =      2.6 : 1.0
#        contains(strider) = True             true : false  =      2.6 : 1.0
#           contains(half) = True             true : false  =      2.6 : 1.0
#           contains(fall) = True             true : false  =      2.6 : 1.0
#    contains(competitive) = True             true : false  =      2.6 : 1.0
#        contains(leading) = True             true : false  =      2.6 : 1.0
#           contains(went) = True             true : false  =      2.6 : 1.0
#          contains(slick) = True             true : false  =      2.6 : 1.0
#           contains(seen) = True             true : false  =      2.6 : 1.0
#            contains(try) = True             true : false  =      2.6 : 1.0
#           contains(sure) = True             true : false  =      2.6 : 1.0
#          contains(april) = True             true : false  =      2.6 : 1.0
#        contains(contain) = True             true : false  =      2.6 : 1.0
#          contains(ahead) = True             true : false  =      2.6 : 1.0
#         contains(deadly) = True             true : false  =      2.6 : 1.0
#       contains(teammate) = True             true : false  =      2.6 : 1.0
#          contains(board) = True             true : false  =      2.6 : 1.0
#        contains(biggest) = True             true : false  =      2.6 : 1.0
#      contains(turnovers) = True             true : false  =      2.6 : 1.0
#     contains(impressive) = True             true : false  =      2.6 : 1.0
#          contains(turns) = True             true : false  =      2.6 : 1.0
#       contains(athletic) = True             true : false  =      2.6 : 1.0
#         contains(coming) = True             true : false  =      2.6 : 1.0
#          contains(scout) = True             true : false  =      2.6 : 1.0
#         contains(edging) = True             true : false  =      2.6 : 1.0
#           contains(fine) = True             true : false  =      2.6 : 1.0
#         contains(worker) = True             true : false  =      2.6 : 1.0
#       contains(together) = True            false : true   =      2.6 : 1.0
#       contains(injuries) = True            false : true   =      2.6 : 1.0
#          contains(clear) = True            false : true   =      2.6 : 1.0
#          contains(gifts) = True            false : true   =      2.6 : 1.0
#      contains(defenders) = True             true : false  =      2.5 : 1.0
#          contains(early) = True             true : false  =      2.5 : 1.0
#        contains(despite) = True             true : false  =      2.5 : 1.0
#        contains(release) = True             true : false  =      2.5 : 1.0
#             contains(60) = True            false : true   =      2.5 : 1.0
#             contains(em) = True            false : true   =      2.5 : 1.0
#         contains(minute) = True            false : true   =      2.5 : 1.0
#        contains(biscuit) = True             true : false  =      2.5 : 1.0
#        contains(penalty) = True             true : false  =      2.5 : 1.0
#          contains(place) = True             true : false  =      2.4 : 1.0
#          contains(since) = True             true : false  =      2.4 : 1.0
#             contains(go) = True             true : false  =      2.4 : 1.0
#         contains(create) = True             true : false  =      2.4 : 1.0
#        contains(drafted) = True             true : false  =      2.4 : 1.0
#         contains(framed) = True             true : false  =      2.4 : 1.0
#       contains(selected) = True             true : false  =      2.4 : 1.0
#            contains(200) = True             true : false  =      2.4 : 1.0
#        contains(receive) = True             true : false  =      2.3 : 1.0
#  contains(opportunities) = True             true : false  =      2.3 : 1.0
#       contains(develops) = True             true : false  =      2.3 : 1.0
#        contains(elusive) = True             true : false  =      2.3 : 1.0
#        contains(players) = True             true : false  =      2.3 : 1.0
#         contains(showed) = True             true : false  =      2.3 : 1.0
#     contains(playmaking) = True             true : false  =      2.3 : 1.0
#             contains(iq) = True             true : false  =      2.3 : 1.0
#       contains(terrific) = True             true : false  =      2.3 : 1.0
#        contains(quickly) = True             true : false  =      2.3 : 1.0
#       contains(homeland) = True             true : false  =      2.3 : 1.0
#           contains(even) = True             true : false  =      2.3 : 1.0
#         contains(threat) = True             true : false  =      2.3 : 1.0
#      contains(playmaker) = True             true : false  =      2.3 : 1.0
#    contains(significant) = True             true : false  =      2.3 : 1.0
#          contains(draft) = True             true : false  =      2.3 : 1.0
#    contains(deceptively) = True             true : false  =      2.2 : 1.0
#          contains(fills) = True             true : false  =      2.2 : 1.0
#         contains(option) = True             true : false  =      2.2 : 1.0
#        contains(rounded) = True             true : false  =      2.2 : 1.0
#       contains(shooting) = True             true : false  =      2.2 : 1.0
#            contains(led) = True             true : false  =      2.2 : 1.0
#             contains(us) = True             true : false  =      2.2 : 1.0
#        contains(reading) = True             true : false  =      2.2 : 1.0
#         contains(couple) = True             true : false  =      2.2 : 1.0
#            contains(fly) = True             true : false  =      2.2 : 1.0
#         contains(circle) = True             true : false  =      2.2 : 1.0
#           contains(ushl) = True             true : false  =      2.2 : 1.0
#         contains(blocks) = True             true : false  =      2.2 : 1.0
#        contains(playoff) = True             true : false  =      2.2 : 1.0
#           contains(fits) = True             true : false  =      2.2 : 1.0
#           contains(edgy) = True             true : false  =      2.2 : 1.0
#         contains(drafts) = True             true : false  =      2.2 : 1.0
#          contains(every) = True             true : false  =      2.2 : 1.0
#         contains(crease) = True             true : false  =      2.2 : 1.0
#           contains(high) = True             true : false  =      2.2 : 1.0
#           contains(legs) = True            false : true   =      2.2 : 1.0
#     contains(aggression) = True            false : true   =      2.2 : 1.0
#           contains(look) = True             true : false  =      2.2 : 1.0
#          contains(elite) = True             true : false  =      2.2 : 1.0
#          contains(knows) = True             true : false  =      2.2 : 1.0
#       contains(demeanor) = True             true : false  =      2.2 : 1.0
#     contains(separation) = True             true : false  =      2.2 : 1.0
#             contains(qb) = True             true : false  =      2.2 : 1.0
#           contains(hold) = True             true : false  =      2.2 : 1.0
#            contains(kid) = True             true : false  =      2.2 : 1.0
#      contains(intensity) = True             true : false  =      2.2 : 1.0
#         contains(status) = True             true : false  =      2.2 : 1.0
#          contains(skate) = True             true : false  =      2.2 : 1.0
#           contains(best) = True             true : false  =      2.2 : 1.0
#        contains(rebound) = True            false : true   =      2.2 : 1.0
#        contains(carries) = True             true : false  =      2.2 : 1.0
#      contains(continues) = True             true : false  =      2.2 : 1.0
#      contains(advantage) = True             true : false  =      2.2 : 1.0
#       contains(question) = True             true : false  =      2.2 : 1.0
#            contains(net) = True             true : false  =      2.2 : 1.0
#             contains(18) = True             true : false  =      2.2 : 1.0
#         contains(checks) = True             true : false  =      2.2 : 1.0
#           contains(move) = True             true : false  =      2.2 : 1.0
#         contains(little) = True             true : false  =      2.2 : 1.0
#         contains(ladder) = True            false : true   =      2.2 : 1.0
#            contains(nhl) = True             true : false  =      2.1 : 1.0
#         contains(making) = True             true : false  =      2.1 : 1.0
#           contains(2014) = True             true : false  =      2.1 : 1.0
#            contains(pro) = True             true : false  =      2.1 : 1.0
#        contains(looking) = True             true : false  =      2.1 : 1.0
#          contains(world) = True             true : false  =      2.1 : 1.0
#           contains(read) = True             true : false  =      2.1 : 1.0
#           contains(2012) = True             true : false  =      2.1 : 1.0
#         contains(gifted) = True             true : false  =      2.1 : 1.0
#        contains(fastest) = True             true : false  =      2.1 : 1.0
#        contains(nations) = True             true : false  =      2.1 : 1.0
#          contains(pivot) = True             true : false  =      2.1 : 1.0
#      contains(including) = True             true : false  =      2.1 : 1.0
#          contains(edges) = True             true : false  =      2.1 : 1.0
#         contains(dangle) = True             true : false  =      2.1 : 1.0
#         contains(gritty) = True             true : false  =      2.1 : 1.0
#        contains(corners) = True            false : true   =      2.1 : 1.0
#         contains(polish) = True            false : true   =      2.1 : 1.0
#         contains(except) = True            false : true   =      2.1 : 1.0
#       contains(anywhere) = True            false : true   =      2.1 : 1.0
#         contains(summer) = True            false : true   =      2.1 : 1.0
#       contains(checking) = True            false : true   =      2.1 : 1.0
#       contains(increase) = True            false : true   =      2.1 : 1.0
#   contains(forechecking) = True            false : true   =      2.1 : 1.0
#          contains(wrist) = True             true : false  =      2.1 : 1.0
#        contains(another) = True             true : false  =      2.1 : 1.0
#          contains(tight) = True             true : false  =      2.1 : 1.0
#         contains(pretty) = True             true : false  =      2.1 : 1.0
#          contains(great) = True             true : false  =      2.0 : 1.0
#           contains(sees) = True             true : false  =      2.0 : 1.0
#            contains(one) = True             true : false  =      2.0 : 1.0
#         contains(junior) = True             true : false  =      2.0 : 1.0
#      contains(christmas) = True             true : false  =      2.0 : 1.0
#            contains(set) = True             true : false  =      2.0 : 1.0
#          contains(keeps) = True             true : false  =      2.0 : 1.0
#       contains(playoffs) = True             true : false  =      2.0 : 1.0
#            contains(ohl) = True             true : false  =      2.0 : 1.0
#           contains(hand) = True             true : false  =      2.0 : 1.0
#           contains(safe) = True             true : false  =      2.0 : 1.0
#         contains(engage) = True             true : false  =      2.0 : 1.0
#         contains(poised) = True             true : false  =      2.0 : 1.0
#      contains(opponents) = True             true : false  =      2.0 : 1.0
#      contains(perimeter) = True             true : false  =      2.0 : 1.0
#         contains(killer) = True             true : false  =      2.0 : 1.0
#           contains(part) = True             true : false  =      2.0 : 1.0
#           contains(rush) = True             true : false  =      2.0 : 1.0
#        contains(finnish) = True             true : false  =      2.0 : 1.0
#       contains(reliable) = True             true : false  =      2.0 : 1.0
#    contains(athleticism) = True            false : true   =      2.0 : 1.0
#         contains(vision) = True             true : false  =      2.0 : 1.0
#          contains(seems) = True             true : false  =      2.0 : 1.0
#          contains(touch) = True             true : false  =      2.0 : 1.0
#            contains(top) = True             true : false  =      2.0 : 1.0
#          contains(gears) = True             true : false  =      2.0 : 1.0
#        contains(patient) = True             true : false  =      2.0 : 1.0
#       contains(starting) = True             true : false  =      2.0 : 1.0
#          contains(snarl) = True             true : false  =      2.0 : 1.0
#          contains(moves) = True             true : false  =      2.0 : 1.0
#           contains(five) = True             true : false  =      2.0 : 1.0
#          contains(burst) = True             true : false  =      2.0 : 1.0
#          contains(super) = True             true : false  =      2.0 : 1.0
#      contains(lightning) = True             true : false  =      2.0 : 1.0
#     contains(relentless) = True             true : false  =      2.0 : 1.0
#      contains(decisions) = True             true : false  =      2.0 : 1.0
#           contains(goes) = True             true : false  =      2.0 : 1.0
#           contains(foot) = True             true : false  =      1.9 : 1.0
#        contains(agility) = True             true : false  =      1.9 : 1.0
#        contains(provide) = True            false : true   =      1.9 : 1.0
#      contains(technique) = True            false : true   =      1.9 : 1.0
#        contains(strides) = True            false : true   =      1.9 : 1.0
#               contains() = False           false : true   =      1.9 : 1.0
#          contains(would) = True             true : false  =      1.9 : 1.0
#         contains(future) = True             true : false  =      1.9 : 1.0
#         contains(simply) = True             true : false  =      1.9 : 1.0
#           contains(full) = True             true : false  =      1.9 : 1.0
#         contains(though) = True             true : false  =      1.9 : 1.0
#          contains(leads) = True             true : false  =      1.9 : 1.0
#          contains(think) = True             true : false  =      1.9 : 1.0
#       contains(attacker) = True             true : false  =      1.9 : 1.0
#      contains(possesses) = True             true : false  =      1.9 : 1.0
#     contains(tournament) = True             true : false  =      1.9 : 1.0
#         contains(angles) = True             true : false  =      1.9 : 1.0
#          contains(motor) = True             true : false  =      1.9 : 1.0
#      contains(promising) = True             true : false  =      1.9 : 1.0
#     contains(fearlessly) = True             true : false  =      1.9 : 1.0
#         contains(skinny) = True             true : false  =      1.9 : 1.0
#         contains(others) = True             true : false  =      1.9 : 1.0
#        contains(brother) = True             true : false  =      1.9 : 1.0
#     contains(positional) = True             true : false  =      1.9 : 1.0
#             contains(30) = True             true : false  =      1.9 : 1.0
#         contains(august) = True             true : false  =      1.9 : 1.0
#           contains(gear) = True             true : false  =      1.9 : 1.0
#    contains(exceptional) = True             true : false  =      1.9 : 1.0
#          contains(given) = True             true : false  =      1.9 : 1.0
#           contains(pins) = True             true : false  =      1.9 : 1.0
#           contains(kill) = True             true : false  =      1.9 : 1.0
#         contains(brings) = True             true : false  =      1.9 : 1.0
#         contains(hockey) = True             true : false  =      1.9 : 1.0
#           contains(lost) = True             true : false  =      1.9 : 1.0
#          contains(climb) = True             true : false  =      1.9 : 1.0
#         contains(faster) = True             true : false  =      1.9 : 1.0
#           contains(ways) = True             true : false  =      1.9 : 1.0
#          contains(mover) = True             true : false  =      1.9 : 1.0
#          contains(goals) = True             true : false  =      1.9 : 1.0
#        contains(chances) = True             true : false  =      1.9 : 1.0
#          contains(reads) = True             true : false  =      1.9 : 1.0
#          contains(whose) = True             true : false  =      1.9 : 1.0
#        contains(offense) = True             true : false  =      1.9 : 1.0
#          contains(lanes) = True            false : true   =      1.9 : 1.0
#     contains(developing) = True            false : true   =      1.9 : 1.0
#            contains(due) = True             true : false  =      1.9 : 1.0
#      contains(forecheck) = True             true : false  =      1.9 : 1.0
#         contains(always) = True             true : false  =      1.9 : 1.0
#            contains(end) = True             true : false  =      1.9 : 1.0
#        contains(rounder) = True             true : false  =      1.8 : 1.0
#           contains(snap) = True             true : false  =      1.8 : 1.0
#          contains(coach) = True             true : false  =      1.8 : 1.0
#          contains(timer) = True             true : false  =      1.8 : 1.0
#         contains(sweden) = True             true : false  =      1.8 : 1.0
#    contains(distributes) = True             true : false  =      1.8 : 1.0
#    contains(effectively) = True             true : false  =      1.8 : 1.0
#         contains(middle) = True             true : false  =      1.8 : 1.0
#          contains(glove) = True            false : true   =      1.8 : 1.0
#            contains(usa) = True            false : true   =      1.8 : 1.0
#         contains(skater) = True             true : false  =      1.8 : 1.0
#          contains(might) = True             true : false  =      1.8 : 1.0
#          contains(right) = True             true : false  =      1.8 : 1.0
#         contains(expect) = True            false : true   =      1.8 : 1.0
#    contains(positioning) = True            false : true   =      1.8 : 1.0
#        contains(lacking) = True            false : true   =      1.8 : 1.0
#           contains(slow) = True            false : true   =      1.8 : 1.0
#       contains(training) = True            false : true   =      1.8 : 1.0
#           contains(hone) = True            false : true   =      1.8 : 1.0
#        contains(regular) = True            false : true   =      1.8 : 1.0
#            contains(eye) = True             true : false  =      1.8 : 1.0
#         contains(bodied) = True             true : false  =      1.8 : 1.0
#        contains(trouble) = True             true : false  =      1.8 : 1.0
#              contains(q) = True             true : false  =      1.8 : 1.0
#         contains(growth) = True             true : false  =      1.8 : 1.0
#         contains(leader) = True             true : false  =      1.8 : 1.0
#        contains(skilled) = True             true : false  =      1.8 : 1.0
#       contains(rebounds) = True             true : false  =      1.8 : 1.0
#      contains(instincts) = True             true : false  =      1.8 : 1.0
#          contains(smart) = True             true : false  =      1.8 : 1.0
#          contains(zones) = True             true : false  =      1.8 : 1.0
#           contains(type) = True             true : false  =      1.8 : 1.0
#      contains(certainly) = True             true : false  =      1.8 : 1.0
#        contains(success) = True             true : false  =      1.8 : 1.0
#      contains(confident) = True             true : false  =      1.8 : 1.0
#         contains(wheels) = True             true : false  =      1.8 : 1.0
#              contains(6) = True             true : false  =      1.8 : 1.0
#        contains(outside) = True             true : false  =      1.8 : 1.0
#        contains(product) = True            false : true   =      1.8 : 1.0
#        contains(creates) = True             true : false  =      1.8 : 1.0
#           contains(role) = True             true : false  =      1.8 : 1.0
#           contains(late) = True             true : false  =      1.8 : 1.0
#         contains(attack) = True             true : false  =      1.8 : 1.0
#     contains(university) = True            false : true   =      1.8 : 1.0
#    contains(development) = True            false : true   =      1.8 : 1.0
#     contains(competitor) = True             true : false  =      1.8 : 1.0
#          contains(years) = True             true : false  =      1.8 : 1.0
#         contains(mobile) = True             true : false  =      1.8 : 1.0
#       contains(decision) = True             true : false  =      1.8 : 1.0
#          contains(score) = True             true : false  =      1.8 : 1.0
#         contains(become) = True             true : false  =      1.8 : 1.0
#      contains(minnesota) = True            false : true   =      1.8 : 1.0
#     contains(commitment) = True             true : false  =      1.8 : 1.0
#          contains(round) = True             true : false  =      1.8 : 1.0
#       contains(fearless) = True             true : false  =      1.8 : 1.0
#       contains(balanced) = True             true : false  =      1.8 : 1.0
#              contains(u) = True             true : false  =      1.8 : 1.0
#          contains(stick) = True             true : false  =      1.7 : 1.0
#          contains(tools) = True            false : true   =      1.7 : 1.0
#         contains(roster) = True             true : false  =      1.7 : 1.0
#          contains(level) = True             true : false  =      1.7 : 1.0
#          contains(cycle) = True            false : true   =      1.7 : 1.0
#         contains(longer) = True            false : true   =      1.7 : 1.0
#     contains(intriguing) = True            false : true   =      1.7 : 1.0
#          contains(speed) = True             true : false  =      1.7 : 1.0
#     contains(tremendous) = True             true : false  =      1.7 : 1.0
#           contains(grow) = True             true : false  =      1.7 : 1.0
#          contains(ready) = True             true : false  =      1.7 : 1.0
#    contains(willingness) = True             true : false  =      1.7 : 1.0
#           contains(mail) = True            false : true   =      1.7 : 1.0
#        contains(advance) = True            false : true   =      1.7 : 1.0
#         contains(native) = True            false : true   =      1.7 : 1.0
#        contains(sleeper) = True            false : true   =      1.7 : 1.0
#         contains(bottom) = True            false : true   =      1.7 : 1.0
#          contains(giant) = True            false : true   =      1.7 : 1.0
#        contains(display) = True            false : true   =      1.7 : 1.0
#        contains(shooter) = True             true : false  =      1.7 : 1.0
#      contains(extremely) = True             true : false  =      1.7 : 1.0
#      contains(displayed) = True             true : false  =      1.7 : 1.0
#          contains(short) = True             true : false  =      1.7 : 1.0
#           contains(jump) = True             true : false  =      1.7 : 1.0
#        contains(clearly) = True             true : false  =      1.7 : 1.0
#         contains(bigger) = True             true : false  =      1.6 : 1.0
#         contains(entire) = True             true : false  =      1.6 : 1.0
#             contains(17) = True             true : false  =      1.6 : 1.0
#           contains(know) = True             true : false  =      1.6 : 1.0
#          contains(sound) = True             true : false  =      1.6 : 1.0
#         contains(rookie) = True             true : false  =      1.6 : 1.0
#           contains(true) = True             true : false  =      1.6 : 1.0
#          contains(light) = True             true : false  =      1.6 : 1.0
#       contains(opposing) = True             true : false  =      1.6 : 1.0
#      contains(teammates) = True             true : false  =      1.6 : 1.0
#       contains(complete) = True             true : false  =      1.6 : 1.0
#           contains(sets) = True             true : false  =      1.6 : 1.0
#         contains(either) = True             true : false  =      1.6 : 1.0
#          contains(asked) = True             true : false  =      1.6 : 1.0
#      contains(punishing) = True             true : false  =      1.6 : 1.0
#          contains(later) = True             true : false  =      1.6 : 1.0
#          contains(quick) = True             true : false  =      1.6 : 1.0
#           contains(drop) = True            false : true   =      1.6 : 1.0
#          contains(three) = True             true : false  =      1.6 : 1.0
#          contains(north) = True             true : false  =      1.6 : 1.0
#           contains(team) = True             true : false  =      1.6 : 1.0
#           contains(stop) = True             true : false  =      1.6 : 1.0
#      contains(excellent) = True             true : false  =      1.6 : 1.0
#  contains(developmental) = True            false : true   =      1.6 : 1.0
#           contains(grit) = True             true : false  =      1.6 : 1.0
#         contains(upward) = True             true : false  =      1.6 : 1.0
#          contains(lists) = True             true : false  =      1.6 : 1.0
#        contains(thought) = True             true : false  =      1.6 : 1.0
#           contains(slot) = True             true : false  =      1.6 : 1.0
#     contains(production) = True             true : false  =      1.6 : 1.0
#        contains(usually) = True             true : false  =      1.6 : 1.0
#          contains(maker) = True             true : false  =      1.6 : 1.0
#            contains(chl) = True             true : false  =      1.6 : 1.0
#         contains(pivots) = True             true : false  =      1.6 : 1.0
#      contains(sometimes) = True             true : false  =      1.6 : 1.0
#       contains(shooters) = True             true : false  =      1.6 : 1.0
#          contains(bring) = True             true : false  =      1.6 : 1.0
#         contains(height) = True             true : false  =      1.6 : 1.0
#          contains(helps) = True             true : false  =      1.6 : 1.0
#         contains(notice) = True             true : false  =      1.6 : 1.0
#     contains(regularity) = True             true : false  =      1.6 : 1.0
#         contains(causes) = True             true : false  =      1.6 : 1.0
#       contains(generate) = True             true : false  =      1.6 : 1.0
#            contains(get) = True             true : false  =      1.6 : 1.0
#        contains(scoring) = True             true : false  =      1.6 : 1.0
#     contains(possession) = True             true : false  =      1.6 : 1.0
#       contains(improved) = True             true : false  =      1.6 : 1.0
#          contains(shows) = True             true : false  =      1.6 : 1.0
#        contains(passing) = True             true : false  =      1.6 : 1.0
#        contains(wrister) = True            false : true   =      1.6 : 1.0
#         contains(sniper) = True            false : true   =      1.6 : 1.0
#         contains(larger) = True            false : true   =      1.6 : 1.0
#          contains(lines) = True            false : true   =      1.6 : 1.0
#          contains(looks) = True             true : false  =      1.6 : 1.0
#        contains(willing) = True             true : false  =      1.6 : 1.0
#         contains(upside) = True             true : false  =      1.6 : 1.0
#         contains(scored) = True             true : false  =      1.6 : 1.0
#            contains(low) = True             true : false  =      1.6 : 1.0
#          contains(taken) = True             true : false  =      1.6 : 1.0
#          contains(ratio) = True             true : false  =      1.6 : 1.0
#          contains(dirty) = True             true : false  =      1.6 : 1.0
#        contains(package) = True             true : false  =      1.6 : 1.0
#          contains(wants) = True             true : false  =      1.6 : 1.0
#   contains(considerable) = True             true : false  =      1.6 : 1.0
#      contains(diagnoses) = True             true : false  =      1.6 : 1.0
#           contains(hurt) = True             true : false  =      1.6 : 1.0
#         contains(places) = True             true : false  =      1.6 : 1.0
#             contains(50) = True             true : false  =      1.6 : 1.0
#      contains(selecting) = True             true : false  =      1.6 : 1.0
#          contains(comes) = True             true : false  =      1.6 : 1.0
#  contains(stickhandling) = True             true : false  =      1.6 : 1.0
#          contains(slide) = True             true : false  =      1.6 : 1.0
#          contains(large) = True             true : false  =      1.6 : 1.0
#        contains(quality) = True             true : false  =      1.6 : 1.0
#    contains(contributor) = True             true : false  =      1.6 : 1.0
#    contains(distributor) = True             true : false  =      1.6 : 1.0
#           contains(four) = True             true : false  =      1.6 : 1.0
#         contains(taking) = True             true : false  =      1.6 : 1.0
#      contains(undrafted) = True             true : false  =      1.6 : 1.0
#         contains(across) = True             true : false  =      1.6 : 1.0
#           contains(term) = True            false : true   =      1.5 : 1.0
#    contains(improvement) = True             true : false  =      1.5 : 1.0
#       contains(presence) = True             true : false  =      1.5 : 1.0
#          contains(could) = True             true : false  =      1.5 : 1.0
#      contains(challenge) = True            false : true   =      1.5 : 1.0
#         contains(stride) = True             true : false  =      1.5 : 1.0
#         contains(starts) = True             true : false  =      1.5 : 1.0
#          contains(sense) = True             true : false  =      1.5 : 1.0
#    contains(forechecker) = True             true : false  =      1.5 : 1.0
#         contains(centre) = True             true : false  =      1.5 : 1.0
#          contains(games) = True             true : false  =      1.5 : 1.0
#           contains(away) = True             true : false  =      1.5 : 1.0
#           contains(real) = True            false : true   =      1.5 : 1.0
#         contains(really) = True             true : false  =      1.5 : 1.0
#           contains(make) = True             true : false  =      1.5 : 1.0
#     contains(undersized) = True             true : false  =      1.5 : 1.0
#           contains(play) = True             true : false  =      1.5 : 1.0
#            contains(see) = True             true : false  =      1.5 : 1.0
#         contains(center) = True             true : false  =      1.5 : 1.0
#        contains(handles) = True             true : false  =      1.5 : 1.0
#      contains(selection) = True             true : false  =      1.5 : 1.0
#           contains(lack) = True             true : false  =      1.5 : 1.0
#          contains(carry) = True             true : false  =      1.5 : 1.0
#          contains(works) = True             true : false  =      1.5 : 1.0
#       contains(fireplug) = True            false : true   =      1.5 : 1.0
#      contains(maintains) = True            false : true   =      1.5 : 1.0
#   contains(aggressively) = True            false : true   =      1.5 : 1.0
#         contains(legged) = True            false : true   =      1.5 : 1.0
#      contains(presently) = True            false : true   =      1.5 : 1.0
#        contains(started) = True            false : true   =      1.5 : 1.0
#      contains(hopefully) = True            false : true   =      1.5 : 1.0
#           contains(care) = True            false : true   =      1.5 : 1.0
#         contains(flight) = True            false : true   =      1.5 : 1.0
#   contains(championship) = True            false : true   =      1.5 : 1.0
#         contains(goalie) = True            false : true   =      1.5 : 1.0
#    contains(disciplined) = True            false : true   =      1.5 : 1.0
#        contains(besides) = True             true : false  =      1.5 : 1.0
#          contains(steps) = True             true : false  =      1.5 : 1.0
#         contains(allows) = True             true : false  =      1.5 : 1.0
#          contains(gives) = True             true : false  =      1.5 : 1.0
#          contains(stays) = True             true : false  =      1.5 : 1.0
#            contains(old) = True             true : false  =      1.5 : 1.0
#         contains(almost) = True             true : false  =      1.5 : 1.0
#          contains(lacks) = True             true : false  =      1.5 : 1.0
#            contains(ice) = True             true : false  =      1.5 : 1.0
#         contains(player) = True             true : false  =      1.5 : 1.0
#      contains(difficult) = True             true : false  =      1.5 : 1.0
#          contains(shots) = True             true : false  =      1.5 : 1.0
#        contains(playing) = True             true : false  =      1.5 : 1.0
#          contains(pucks) = True             true : false  =      1.5 : 1.0
#            contains(six) = True             true : false  =      1.5 : 1.0
#          contains(reach) = True             true : false  =      1.5 : 1.0
#   contains(acceleration) = True             true : false  =      1.5 : 1.0
#           contains(shot) = True             true : false  =      1.5 : 1.0
#             contains(pk) = True             true : false  =      1.5 : 1.0
#           contains(face) = True             true : false  =      1.5 : 1.0
#            contains(put) = True             true : false  =      1.5 : 1.0
#    contains(competition) = True             true : false  =      1.5 : 1.0
#          contains(sized) = True            false : true   =      1.5 : 1.0
#    contains(consistency) = True            false : true   =      1.5 : 1.0
#           contains(club) = True            false : true   =      1.5 : 1.0
#          contains(stand) = True            false : true   =      1.5 : 1.0
#           contains(pass) = True             true : false  =      1.5 : 1.0
#        contains(prowess) = True            false : true   =      1.5 : 1.0
#          contains(teams) = True             true : false  =      1.5 : 1.0
#         contains(smarts) = True             true : false  =      1.5 : 1.0
#      contains(improving) = True            false : true   =      1.5 : 1.0
#            contains(man) = True             true : false  =      1.5 : 1.0
#            contains(may) = True             true : false  =      1.4 : 1.0
#          contains(agile) = True             true : false  =      1.4 : 1.0
#           contains(fact) = True             true : false  =      1.4 : 1.0
#           contains(find) = True             true : false  =      1.4 : 1.0
#        contains(average) = True             true : false  =      1.4 : 1.0
#           contains(feel) = True             true : false  =      1.4 : 1.0
#           contains(pick) = True             true : false  =      1.4 : 1.0
#     contains(bloodlines) = True             true : false  =      1.4 : 1.0
#          contains(sheet) = True             true : false  =      1.4 : 1.0
#          contains(along) = True             true : false  =      1.4 : 1.0
#      contains(positions) = True             true : false  =      1.4 : 1.0
#         contains(overly) = True             true : false  =      1.4 : 1.0
#       contains(polished) = True             true : false  =      1.4 : 1.0
#           contains(free) = True             true : false  =      1.4 : 1.0
#          contains(watch) = True             true : false  =      1.4 : 1.0
#    contains(elusiveness) = True             true : false  =      1.4 : 1.0
#           contains(upon) = True             true : false  =      1.4 : 1.0
#           contains(base) = True             true : false  =      1.4 : 1.0
#         contains(footer) = True             true : false  =      1.4 : 1.0
#   contains(positionally) = True             true : false  =      1.4 : 1.0
#          contains(czech) = True            false : true   =      1.4 : 1.0
#         contains(season) = True             true : false  =      1.4 : 1.0
#          contains(hands) = True             true : false  =      1.4 : 1.0
#        contains(traffic) = True             true : false  =      1.4 : 1.0
#      contains(quickness) = True             true : false  =      1.4 : 1.0
#       contains(advanced) = True            false : true   =      1.4 : 1.0
#        contains(example) = True            false : true   =      1.4 : 1.0
#           contains(west) = True            false : true   =      1.4 : 1.0
#           contains(east) = True            false : true   =      1.4 : 1.0
#     contains(surprising) = True            false : true   =      1.4 : 1.0
#        contains(lateral) = True             true : false  =      1.4 : 1.0
#    contains(defensively) = True             true : false  =      1.4 : 1.0
#        contains(skating) = True             true : false  =      1.4 : 1.0
#     contains(aggressive) = True             true : false  =      1.4 : 1.0
#          contains(third) = True             true : false  =      1.4 : 1.0
#           contains(open) = True             true : false  =      1.4 : 1.0
#       contains(juncture) = True            false : true   =      1.4 : 1.0
#          contains(heavy) = True             true : false  =      1.4 : 1.0
#         contains(plenty) = True            false : true   =      1.4 : 1.0
#         contains(simple) = True             true : false  =      1.4 : 1.0
#            contains(men) = True             true : false  =      1.4 : 1.0
#          contains(ethic) = True             true : false  =      1.4 : 1.0
#           contains(past) = True             true : false  =      1.4 : 1.0
#          contains(first) = True             true : false  =      1.4 : 1.0
#         contains(chance) = True             true : false  =      1.4 : 1.0
#        contains(ability) = True             true : false  =      1.4 : 1.0
#         contains(outlet) = True             true : false  =      1.4 : 1.0
#       contains(carrying) = True             true : false  =      1.4 : 1.0
#         contains(points) = True             true : false  =      1.4 : 1.0
#           contains(well) = True             true : false  =      1.4 : 1.0
#          contains(power) = True             true : false  =      1.4 : 1.0
#        contains(growing) = True            false : true   =      1.4 : 1.0
#       contains(possible) = True            false : true   =      1.4 : 1.0
#         contains(strong) = True             true : false  =      1.4 : 1.0
#           contains(calm) = True             true : false  =      1.4 : 1.0
#           contains(back) = True             true : false  =      1.4 : 1.0
#           contains(soft) = True             true : false  =      1.4 : 1.0
#         contains(fairly) = True            false : true   =      1.4 : 1.0
#          contains(catch) = True            false : true   =      1.4 : 1.0
#            contains(run) = True            false : true   =      1.4 : 1.0
#            contains(3rd) = True            false : true   =      1.4 : 1.0
#          contains(learn) = True            false : true   =      1.4 : 1.0
#     contains(experience) = True            false : true   =      1.4 : 1.0
#       contains(reflexes) = True            false : true   =      1.4 : 1.0
#           contains(call) = True            false : true   =      1.4 : 1.0
#        contains(pursuit) = True            false : true   =      1.4 : 1.0
#          contains(added) = True            false : true   =      1.4 : 1.0
#        contains(present) = True             true : false  =      1.4 : 1.0
#         contains(talent) = True             true : false  =      1.4 : 1.0
#    contains(understands) = True             true : false  =      1.4 : 1.0
#      contains(generator) = True             true : false  =      1.4 : 1.0
#         contains(superb) = True             true : false  =      1.4 : 1.0
#          contains(skill) = True             true : false  =      1.4 : 1.0
#       contains(movement) = True            false : true   =      1.4 : 1.0
#           contains(give) = True             true : false  =      1.4 : 1.0
#            contains(son) = True             true : false  =      1.4 : 1.0
#          contains(areas) = True             true : false  =      1.4 : 1.0
#      contains(basically) = True             true : false  =      1.4 : 1.0
#           contains(puts) = True             true : false  =      1.4 : 1.0
# ...
#           contains(time) = True             true : false  =      1.2 : 1.0
#          contains(front) = True             true : false  =      1.2 : 1.0
#         contains(league) = True             true : false  =      1.2 : 1.0
#           contains(seem) = True             true : false  =      1.2 : 1.0
#   contains(stickhandler) = True             true : false  =      1.2 : 1.0
#     contains(considered) = True             true : false  =      1.2 : 1.0
#         contains(boston) = True             true : false  =      1.2 : 1.0
#      contains(continued) = True             true : false  =      1.2 : 1.0
#         contains(highly) = True             true : false  =      1.2 : 1.0
#          contains(throw) = True             true : false  =      1.2 : 1.0
#         contains(spaces) = True             true : false  =      1.2 : 1.0
#           contains(also) = True             true : false  =      1.2 : 1.0
#         contains(energy) = True             true : false  =      1.2 : 1.0
#      contains(toughness) = True             true : false  =      1.2 : 1.0
#           contains(fill) = True             true : false  =      1.2 : 1.0
#       contains(displays) = True             true : false  =      1.2 : 1.0
#         contains(closes) = True            false : true   =      1.2 : 1.0
#         contains(handed) = True            false : true   =      1.2 : 1.0
#           contains(hope) = True            false : true   =      1.2 : 1.0
#          contains(boots) = True            false : true   =      1.2 : 1.0
#        contains(winning) = True            false : true   =      1.2 : 1.0
#    contains(nonetheless) = True            false : true   =      1.2 : 1.0
#           contains(shut) = True            false : true   =      1.2 : 1.0
#          contains(issue) = True            false : true   =      1.2 : 1.0
#        contains(checker) = True            false : true   =      1.2 : 1.0
#         contains(london) = True            false : true   =      1.2 : 1.0
#        contains(veteran) = True            false : true   =      1.2 : 1.0
#          contains(mitts) = True            false : true   =      1.2 : 1.0
#      contains(rearguard) = True            false : true   =      1.2 : 1.0
#            contains(dub) = True            false : true   =      1.2 : 1.0
#      contains(centreman) = True            false : true   =      1.2 : 1.0
# contains(competitiveness) = True            false : true   =      1.2 : 1.0
#        contains(problem) = True            false : true   =      1.2 : 1.0
#       contains(michigan) = True            false : true   =      1.2 : 1.0
#        contains(general) = True            false : true   =      1.2 : 1.0
#         contains(hitter) = True            false : true   =      1.2 : 1.0
#          contains(enemy) = True            false : true   =      1.2 : 1.0
#         contains(rounds) = True            false : true   =      1.2 : 1.0
#        contains(grinder) = True            false : true   =      1.2 : 1.0
#          contains(state) = True            false : true   =      1.2 : 1.0
#         contains(covers) = True            false : true   =      1.2 : 1.0
#        contains(college) = True            false : true   =      1.2 : 1.0
#        contains(western) = True            false : true   =      1.2 : 1.0
#         contains(behind) = True            false : true   =      1.2 : 1.0
#      contains(composure) = True            false : true   =      1.2 : 1.0
#            contains(dee) = True            false : true   =      1.2 : 1.0
#        contains(remains) = True            false : true   =      1.2 : 1.0
#          contains(cause) = True            false : true   =      1.2 : 1.0
#       contains(combined) = True            false : true   =      1.2 : 1.0
#         contains(within) = True            false : true   =      1.2 : 1.0
#             contains(13) = True            false : true   =      1.2 : 1.0
#         contains(happen) = True            false : true   =      1.2 : 1.0
#          contains(allow) = True            false : true   =      1.2 : 1.0
#         contains(import) = True            false : true   =      1.2 : 1.0
#         contains(shifty) = True            false : true   =      1.2 : 1.0
#     contains(creativity) = True            false : true   =      1.2 : 1.0
#          contains(jumps) = True            false : true   =      1.2 : 1.0
#            contains(jam) = True            false : true   =      1.2 : 1.0
#          contains(radar) = True            false : true   =      1.2 : 1.0
#       contains(activate) = True            false : true   =      1.2 : 1.0
#         contains(footed) = True            false : true   =      1.2 : 1.0
#          contains(whole) = True            false : true   =      1.2 : 1.0
#         contains(quebec) = True            false : true   =      1.2 : 1.0
#              contains(5) = True            false : true   =      1.2 : 1.0
#        contains(handler) = True            false : true   =      1.2 : 1.0
#        contains(compete) = True            false : true   =      1.2 : 1.0
#          contains(finds) = True            false : true   =      1.2 : 1.0
#        contains(project) = True            false : true   =      1.2 : 1.0
#          contains(frame) = True            false : true   =      1.2 : 1.0
#            contains(leg) = True            false : true   =      1.2 : 1.0
#           contains(lead) = True            false : true   =      1.2 : 1.0
#           contains(nice) = True            false : true   =      1.2 : 1.0
#            contains(new) = True            false : true   =      1.2 : 1.0
#           contains(tall) = True            false : true   =      1.2 : 1.0
#           contains(born) = True            false : true   =      1.2 : 1.0
#      contains(excellent) = False           false : true   =      1.2 : 1.0
#            contains(way) = True             true : false  =      1.2 : 1.0
#           contains(play) = False           false : true   =      1.1 : 1.0
#           contains(high) = False           false : true   =      1.1 : 1.0
#         contains(junior) = False           false : true   =      1.1 : 1.0
#     contains(physically) = True             true : false  =      1.1 : 1.0
#      contains(prospects) = True             true : false  =      1.1 : 1.0
#            contains(win) = True             true : false  =      1.1 : 1.0
#          contains(speed) = False           false : true   =      1.1 : 1.0
#         contains(higher) = True             true : false  =      1.1 : 1.0
#          contains(world) = False           false : true   =      1.1 : 1.0
#      contains(attacking) = True             true : false  =      1.1 : 1.0
#          contains(poise) = True             true : false  =      1.1 : 1.0
#       contains(forwards) = True             true : false  =      1.1 : 1.0
#           contains(wait) = True             true : false  =      1.1 : 1.0
#         contains(enough) = True             true : false  =      1.1 : 1.0
#          contains(tough) = True             true : false  =      1.1 : 1.0
#       contains(patience) = True             true : false  =      1.1 : 1.0
#          contains(loves) = True             true : false  =      1.1 : 1.0
#         contains(canada) = True             true : false  =      1.1 : 1.0
#   contains(anticipation) = True             true : false  =      1.1 : 1.0
#       contains(footwork) = True             true : false  =      1.1 : 1.0
#          contains(great) = False           false : true   =      1.1 : 1.0
#           contains(team) = False           false : true   =      1.1 : 1.0
#           contains(shot) = False           false : true   =      1.1 : 1.0
#           contains(well) = False           false : true   =      1.1 : 1.0
#            contains(get) = False           false : true   =      1.1 : 1.0
#            contains(one) = False           false : true   =      1.1 : 1.0
#            contains(end) = False           false : true   =      1.1 : 1.0
#     contains(especially) = True             true : false  =      1.1 : 1.0
#         contains(afraid) = True             true : false  =      1.1 : 1.0
#           contains(want) = True             true : false  =      1.1 : 1.0
#          contains(built) = True             true : false  =      1.1 : 1.0
#     contains(effortless) = True             true : false  =      1.1 : 1.0
#      contains(projected) = True             true : false  =      1.1 : 1.0
#      contains(versatile) = True             true : false  =      1.1 : 1.0
#       contains(opponent) = True             true : false  =      1.1 : 1.0
#        contains(quietly) = True             true : false  =      1.1 : 1.0
#           contains(weak) = True             true : false  =      1.1 : 1.0
#       contains(competes) = True             true : false  =      1.1 : 1.0
#         contains(adjust) = True             true : false  =      1.1 : 1.0
#        contains(nuances) = True             true : false  =      1.1 : 1.0
#         contains(motion) = True             true : false  =      1.1 : 1.0
#            contains(job) = True             true : false  =      1.1 : 1.0
#         contains(anyone) = True             true : false  =      1.1 : 1.0
#      contains(unselfish) = True             true : false  =      1.1 : 1.0
#   contains(coordination) = True             true : false  =      1.1 : 1.0
#    contains(performance) = True             true : false  =      1.1 : 1.0
#        contains(tougher) = True             true : false  =      1.1 : 1.0
#        contains(keeping) = True             true : false  =      1.1 : 1.0
#         contains(thinks) = True             true : false  =      1.1 : 1.0
#           contains(bulk) = True             true : false  =      1.1 : 1.0
#         contains(feisty) = True             true : false  =      1.1 : 1.0
#       contains(prospect) = True            false : true   =      1.1 : 1.0
#          contains(quick) = False           false : true   =      1.1 : 1.0
#         contains(passes) = True             true : false  =      1.1 : 1.0
#         contains(attack) = False           false : true   =      1.1 : 1.0
#          contains(plays) = False           false : true   =      1.1 : 1.0
#        contains(battles) = True             true : false  =      1.1 : 1.0
#         contains(vision) = False           false : true   =      1.1 : 1.0
#          contains(needs) = True             true : false  =      1.1 : 1.0
#          contains(stick) = False           false : true   =      1.1 : 1.0
#            contains(top) = False           false : true   =      1.1 : 1.0
#            contains(ice) = False           false : true   =      1.1 : 1.0
#          contains(times) = True             true : false  =      1.1 : 1.0
#           contains(beat) = True             true : false  =      1.1 : 1.0
#         contains(weight) = True            false : true   =      1.1 : 1.0
#         contains(scorer) = False           false : true   =      1.1 : 1.0
#            contains(nhl) = False           false : true   =      1.1 : 1.0
#           contains(last) = True             true : false  =      1.1 : 1.0
#       contains(handling) = True             true : false  =      1.1 : 1.0
#       contains(mobility) = True             true : false  =      1.1 : 1.0
#             contains(18) = False           false : true   =      1.1 : 1.0
#        contains(improve) = True             true : false  =      1.1 : 1.0
#         contains(hockey) = False           false : true   =      1.1 : 1.0
#       contains(pressure) = True            false : true   =      1.1 : 1.0
#         contains(muscle) = True            false : true   =      1.1 : 1.0
#         contains(skater) = False           false : true   =      1.1 : 1.0
#          contains(hands) = False           false : true   =      1.1 : 1.0
#        contains(skating) = False           false : true   =      1.1 : 1.0
#           contains(work) = True             true : false  =      1.1 : 1.0
#         contains(active) = True            false : true   =      1.1 : 1.0
#           contains(many) = False           false : true   =      1.1 : 1.0
#             contains(go) = False           false : true   =      1.1 : 1.0
#            contains(may) = False           false : true   =      1.1 : 1.0
#          contains(draft) = False           false : true   =      1.1 : 1.0
#           contains(term) = False            true : false  =      1.1 : 1.0
#         contains(roster) = False           false : true   =      1.1 : 1.0
#       contains(selected) = False           false : true   =      1.1 : 1.0
#           contains(help) = True             true : false  =      1.1 : 1.0
#        contains(ability) = False           false : true   =      1.1 : 1.0
#            contains(set) = False           false : true   =      1.1 : 1.0
#        contains(release) = False           false : true   =      1.1 : 1.0
#         contains(upside) = False           false : true   =      1.1 : 1.0
#            contains(net) = False           false : true   =      1.1 : 1.0
#        contains(minutes) = True            false : true   =      1.1 : 1.0
#           contains(line) = False           false : true   =      1.1 : 1.0
#      contains(defenders) = False           false : true   =      1.1 : 1.0
#       contains(finished) = True             true : false  =      1.1 : 1.0
#           contains(less) = True             true : false  =      1.1 : 1.0
#        contains(natural) = True             true : false  =      1.1 : 1.0
#          contains(break) = True             true : false  =      1.1 : 1.0
#        contains(quicker) = True             true : false  =      1.1 : 1.0
#           contains(road) = True             true : false  =      1.1 : 1.0
#           contains(foot) = False           false : true   =      1.1 : 1.0
#          contains(april) = False           false : true   =      1.1 : 1.0
#           contains(wing) = True             true : false  =      1.1 : 1.0
#     contains(tournament) = False           false : true   =      1.1 : 1.0
#         contains(skills) = False           false : true   =      1.1 : 1.0
#        contains(working) = True             true : false  =      1.1 : 1.0
#          contains(girth) = True            false : true   =      1.1 : 1.0
#            contains(big) = True            false : true   =      1.1 : 1.0
#           contains(able) = False           false : true   =      1.1 : 1.0
#        contains(scoring) = False           false : true   =      1.1 : 1.0
#          contains(smart) = False           false : true   =      1.1 : 1.0
#        contains(players) = False           false : true   =      1.1 : 1.0
#      contains(offensive) = True             true : false  =      1.1 : 1.0
#        contains(balance) = True            false : true   =      1.1 : 1.0
#           contains(even) = False           false : true   =      1.1 : 1.0
#           contains(step) = True             true : false  =      1.1 : 1.0
#       contains(physical) = True             true : false  =      1.1 : 1.0
#         contains(inside) = True             true : false  =      1.1 : 1.0
#         contains(pounds) = True             true : false  =      1.1 : 1.0
#        contains(intense) = True             true : false  =      1.1 : 1.0
#          contains(water) = True             true : false  =      1.1 : 1.0
#         contains(select) = True             true : false  =      1.1 : 1.0
#           contains(ever) = True             true : false  =      1.1 : 1.0
#       contains(unafraid) = True             true : false  =      1.1 : 1.0
#      contains(qualities) = True             true : false  =      1.1 : 1.0
#           contains(tape) = True             true : false  =      1.1 : 1.0
#           contains(mark) = True             true : false  =      1.1 : 1.0
#           contains(post) = True             true : false  =      1.1 : 1.0
#         contains(cannot) = True             true : false  =      1.1 : 1.0
#            contains(pro) = False           false : true   =      1.1 : 1.0
#           contains(make) = False           false : true   =      1.1 : 1.0
#     contains(university) = False            true : false  =      1.1 : 1.0
#           contains(size) = True            false : true   =      1.1 : 1.0
#         contains(centre) = False           false : true   =      1.0 : 1.0

# %%
nltk.classify.accuracy(nb_filtered,featuresets_filtered)
# Out:
# 0.7145969498910676

# %%
save_classifier = open('..\classifiers\\nltk_nb_filter.pickle','wb')
pickle.dump(nb_filtered,save_classifier)
save_classifier.close()

# %% [markdown]
# # ==========Sklearn Classifiers==========

# %%
from nltk.classify.scikitlearn import SklearnClassifier
from sklearn.naive_bayes import GaussianNB,MultinomialNB,BernoulliNB
from sklearn.svm import LinearSVC

# %%
SVC_classifier = SklearnClassifier(LinearSVC())
random.shuffle(documents_filtered)
featuresets_filtered = [(document_features(d),c) for (d,c) in documents_filtered]
train_filtered,test_filtered = featuresets_filtered[818:],featuresets_filtered[:100]
SVC_classifier.train(train_filtered)
nltk.classify.accuracy(SVC_classifier,featuresets_filtered)
# Out:
# 0.5904139433551199

# %%
MN_classifier = SklearnClassifier(MultinomialNB())
random.shuffle(documents_filtered)
featuresets_filtered = [(document_features(d),c) for (d,c) in documents_filtered]
train_filtered,test_filtered = featuresets_filtered[818:],featuresets_filtered[:100]
MN_classifier.train(train_filtered)
nltk.classify.accuracy(MN_classifier,featuresets_filtered)
# Out:
# 0.6176470588235294

# %%
BN_classifier = SklearnClassifier(BernoulliNB())
random.shuffle(documents_filtered)
featuresets_filtered = [(document_features(d),c) for (d,c) in documents_filtered]
train_filtered,test_filtered = featuresets_filtered[818:],featuresets_filtered[:100]
BN_classifier.train(train_filtered)
nltk.classify.accuracy(BN_classifier,featuresets_filtered)
# Out:
# 0.5958605664488017
